# %%
from bs4 import BeautifulSoup
import requests

from IPython.core.display import display, HTML

import pandas as pd

import re

import numpy as np

import datetime

# %%
#Retrieve breakdown of games from october to end of march

urlList = [
    'https://www.basketball-reference.com/leagues/NBA_2019_games-october.html',
    'https://www.basketball-reference.com/leagues/NBA_2019_games-november.html',
    'https://www.basketball-reference.com/leagues/NBA_2019_games-december.html',
    'https://www.basketball-reference.com/leagues/NBA_2019_games-january.html',
    'https://www.basketball-reference.com/leagues/NBA_2019_games-february.html',
    'https://www.basketball-reference.com/leagues/NBA_2019_games-march.html'
]
soupList = []
for url in urlList:
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    soupList.append(soup)
[soup1,soup2,soup3,soup4,soup5,soup6] = soupList

# %%
headerData = soup1.find(class_ = 'overthrow table_container').find_all('tr')[0].find_all('th')

# %%
column_headers = []

#get headers
for header in headerData:
    column_headers.append(header['data-stat'])
column_headers
# Out:
# ['date_game',
#  'game_start_time',
#  'visitor_team_name',
#  'visitor_pts',
#  'home_team_name',
#  'home_pts',
#  'box_score_text',
#  'overtimes',
#  'attendance',
#  'game_remarks']

# %%
fullDataList = []

for soup in soupList:
    cellData = soup.find(class_ = 'overthrow table_container').find_all('tr')
    for row in range(1,len(cellData)):
        rowList = []
        for cell in cellData[row].find_all(lambda tag: tag.name == 'td' or tag.name == 'th'):
            if cell.contents == []:
                value = ''
            elif cell.contents[0].name == 'a':
                if cell.contents[0].contents[0] == 'Box Score':
                    value = 'https://www.basketball-reference.com'+ cell.contents[0]['href']
                else:
                    value = cell.contents[0].contents[0]
            else:
                value = cell.contents[0]
            rowList.append(value)
        fullDataList.append(rowList)

cleanCellData = [x for x in fullDataList if x != []]

cleanCellData
# Out:
# [['Tue, Oct 16, 2018',
#   '8:00p',
#   'Philadelphia 76ers',
#   '87',
#   'Boston Celtics',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201810160BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Tue, Oct 16, 2018',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '100',
#   'Golden State Warriors',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201810160GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '7:00p',
#   'Milwaukee Bucks',
#   '113',
#   'Charlotte Hornets',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810170CHO.html',
#   '',
#   '17,889',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '7:00p',
#   'Brooklyn Nets',
#   '100',
#   'Detroit Pistons',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201810170DET.html',
#   '',
#   '20,332',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '7:00p',
#   'Memphis Grizzlies',
#   '83',
#   'Indiana Pacers',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201810170IND.html',
#   '',
#   '17,923',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '7:00p',
#   'Miami Heat',
#   '101',
#   'Orlando Magic',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201810170ORL.html',
#   '',
#   '19,191',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '7:30p',
#   'Atlanta Hawks',
#   '107',
#   'New York Knicks',
#   '126',
#   'https://www.basketball-reference.com/boxscores/201810170NYK.html',
#   '',
#   '18,249',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '7:30p',
#   'Cleveland Cavaliers',
#   '104',
#   'Toronto Raptors',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810170TOR.html',
#   '',
#   '19,915',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '8:00p',
#   'New Orleans Pelicans',
#   '131',
#   'Houston Rockets',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810170HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '8:30p',
#   'Minnesota Timberwolves',
#   '108',
#   'San Antonio Spurs',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810170SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '10:00p',
#   'Utah Jazz',
#   '123',
#   'Sacramento Kings',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201810170SAC.html',
#   '',
#   '17,583',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '10:30p',
#   'Denver Nuggets',
#   '107',
#   'Los Angeles Clippers',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201810170LAC.html',
#   '',
#   '19,068',
#   ''],
#  ['Wed, Oct 17, 2018',
#   '10:30p',
#   'Dallas Mavericks',
#   '100',
#   'Phoenix Suns',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201810170PHO.html',
#   '',
#   '18,055',
#   ''],
#  ['Thu, Oct 18, 2018',
#   '8:00p',
#   'Chicago Bulls',
#   '108',
#   'Philadelphia 76ers',
#   '127',
#   'https://www.basketball-reference.com/boxscores/201810180PHI.html',
#   '',
#   '20,302',
#   ''],
#  ['Thu, Oct 18, 2018',
#   '8:00p',
#   'Miami Heat',
#   '113',
#   'Washington Wizards',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810180WAS.html',
#   '',
#   '20,409',
#   ''],
#  ['Thu, Oct 18, 2018',
#   '10:30p',
#   'Los Angeles Lakers',
#   '119',
#   'Portland Trail Blazers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201810180POR.html',
#   '',
#   '19,996',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '7:00p',
#   'Charlotte Hornets',
#   '120',
#   'Orlando Magic',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201810190ORL.html',
#   '',
#   '17,668',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '7:30p',
#   'New York Knicks',
#   '105',
#   'Brooklyn Nets',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201810190BRK.html',
#   '',
#   '17,732',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '8:00p',
#   'Atlanta Hawks',
#   '117',
#   'Memphis Grizzlies',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201810190MEM.html',
#   '',
#   '17,019',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '8:00p',
#   'Cleveland Cavaliers',
#   '123',
#   'Minnesota Timberwolves',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201810190MIN.html',
#   '',
#   '18,978',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '8:00p',
#   'Sacramento Kings',
#   '129',
#   'New Orleans Pelicans',
#   '149',
#   'https://www.basketball-reference.com/boxscores/201810190NOP.html',
#   '',
#   '18,337',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '8:00p',
#   'Boston Celtics',
#   '101',
#   'Toronto Raptors',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810190TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '8:30p',
#   'Indiana Pacers',
#   '101',
#   'Milwaukee Bucks',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201810190MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '92',
#   'Los Angeles Clippers',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201810190LAC.html',
#   '',
#   '14,816',
#   ''],
#  ['Fri, Oct 19, 2018',
#   '10:30p',
#   'Golden State Warriors',
#   '124',
#   'Utah Jazz',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201810190UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '7:00p',
#   'Brooklyn Nets',
#   '112',
#   'Indiana Pacers',
#   '132',
#   'https://www.basketball-reference.com/boxscores/201810200IND.html',
#   '',
#   '17,007',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '7:00p',
#   'Toronto Raptors',
#   '117',
#   'Washington Wizards',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810200WAS.html',
#   '',
#   '16,185',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '7:30p',
#   'Boston Celtics',
#   '103',
#   'New York Knicks',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201810200NYK.html',
#   '',
#   '19,427',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '7:30p',
#   'Orlando Magic',
#   '115',
#   'Philadelphia 76ers',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810200PHI.html',
#   '',
#   '20,300',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '8:00p',
#   'Detroit Pistons',
#   '118',
#   'Chicago Bulls',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810200CHI.html',
#   '',
#   '21,289',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '8:00p',
#   'Charlotte Hornets',
#   '113',
#   'Miami Heat',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810200MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '8:30p',
#   'Minnesota Timberwolves',
#   '136',
#   'Dallas Mavericks',
#   '140',
#   'https://www.basketball-reference.com/boxscores/201810200DAL.html',
#   '',
#   '20,205',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '9:00p',
#   'Phoenix Suns',
#   '91',
#   'Denver Nuggets',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201810200DEN.html',
#   '',
#   '19,592',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '10:00p',
#   'San Antonio Spurs',
#   '108',
#   'Portland Trail Blazers',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201810200POR.html',
#   '',
#   '19,461',
#   ''],
#  ['Sat, Oct 20, 2018',
#   '10:30p',
#   'Houston Rockets',
#   '124',
#   'Los Angeles Lakers',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201810200LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Sun, Oct 21, 2018',
#   '6:00p',
#   'Atlanta Hawks',
#   '133',
#   'Cleveland Cavaliers',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201810210CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Sun, Oct 21, 2018',
#   '7:00p',
#   'Sacramento Kings',
#   '131',
#   'Oklahoma City Thunder',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201810210OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sun, Oct 21, 2018',
#   '8:00p',
#   'Golden State Warriors',
#   '98',
#   'Denver Nuggets',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201810210DEN.html',
#   '',
#   '19,520',
#   ''],
#  ['Sun, Oct 21, 2018',
#   '9:00p',
#   'Houston Rockets',
#   '112',
#   'Los Angeles Clippers',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201810210LAC.html',
#   '',
#   '16,149',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '7:30p',
#   'Orlando Magic',
#   '93',
#   'Boston Celtics',
#   '90',
#   'https://www.basketball-reference.com/boxscores/201810220BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '7:30p',
#   'Charlotte Hornets',
#   '106',
#   'Toronto Raptors',
#   '127',
#   'https://www.basketball-reference.com/boxscores/201810220TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '8:00p',
#   'New York Knicks',
#   '113',
#   'Milwaukee Bucks',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201810220MIL.html',
#   '',
#   '16,228',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '8:00p',
#   'Indiana Pacers',
#   '91',
#   'Minnesota Timberwolves',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201810220MIN.html',
#   '',
#   '10,371',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '8:30p',
#   'Chicago Bulls',
#   '109',
#   'Dallas Mavericks',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201810220DAL.html',
#   '',
#   '19,291',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '9:00p',
#   'Memphis Grizzlies',
#   '92',
#   'Utah Jazz',
#   '84',
#   'https://www.basketball-reference.com/boxscores/201810220UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '10:00p',
#   'Washington Wizards',
#   '125',
#   'Portland Trail Blazers',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201810220POR.html',
#   'OT',
#   '19,187',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '10:30p',
#   'Phoenix Suns',
#   '103',
#   'Golden State Warriors',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201810220GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Mon, Oct 22, 2018',
#   '10:30p',
#   'San Antonio Spurs',
#   '143',
#   'Los Angeles Lakers',
#   '142',
#   'https://www.basketball-reference.com/boxscores/201810220LAL.html',
#   'OT',
#   '18,997',
#   ''],
#  ['Tue, Oct 23, 2018',
#   '7:00p',
#   'Philadelphia 76ers',
#   '132',
#   'Detroit Pistons',
#   '133',
#   'https://www.basketball-reference.com/boxscores/201810230DET.html',
#   'OT',
#   '14,418',
#   ''],
#  ['Tue, Oct 23, 2018',
#   '8:00p',
#   'Los Angeles Clippers',
#   '109',
#   'New Orleans Pelicans',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810230NOP.html',
#   '',
#   '14,625',
#   ''],
#  ['Tue, Oct 23, 2018',
#   '9:00p',
#   'Sacramento Kings',
#   '112',
#   'Denver Nuggets',
#   '126',
#   'https://www.basketball-reference.com/boxscores/201810230DEN.html',
#   '',
#   '13,214',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '7:00p',
#   'Dallas Mavericks',
#   '104',
#   'Atlanta Hawks',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201810240ATL.html',
#   '',
#   '16,705',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '7:00p',
#   'Brooklyn Nets',
#   '102',
#   'Cleveland Cavaliers',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201810240CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '7:30p',
#   'New York Knicks',
#   '87',
#   'Miami Heat',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201810240MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '7:30p',
#   'Minnesota Timberwolves',
#   '105',
#   'Toronto Raptors',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810240TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '8:00p',
#   'Charlotte Hornets',
#   '110',
#   'Chicago Bulls',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201810240CHI.html',
#   '',
#   '19,170',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '8:00p',
#   'Utah Jazz',
#   '100',
#   'Houston Rockets',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201810240HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '8:30p',
#   'Indiana Pacers',
#   '116',
#   'San Antonio Spurs',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201810240SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '9:30p',
#   'Philadelphia 76ers',
#   '108',
#   'Milwaukee Bucks',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201810240MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '10:00p',
#   'Los Angeles Lakers',
#   '131',
#   'Phoenix Suns',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810240PHO.html',
#   '',
#   '18,055',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '10:00p',
#   'Memphis Grizzlies',
#   '92',
#   'Sacramento Kings',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201810240SAC.html',
#   '',
#   '14,198',
#   ''],
#  ['Wed, Oct 24, 2018',
#   '10:30p',
#   'Washington Wizards',
#   '122',
#   'Golden State Warriors',
#   '144',
#   'https://www.basketball-reference.com/boxscores/201810240GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Thu, Oct 25, 2018',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '103',
#   'Detroit Pistons',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201810250DET.html',
#   '',
#   '15,896',
#   ''],
#  ['Thu, Oct 25, 2018',
#   '7:00p',
#   'Portland Trail Blazers',
#   '128',
#   'Orlando Magic',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201810250ORL.html',
#   '',
#   '15,114',
#   ''],
#  ['Thu, Oct 25, 2018',
#   '8:00p',
#   'Boston Celtics',
#   '101',
#   'Oklahoma City Thunder',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201810250OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Thu, Oct 25, 2018',
#   '10:30p',
#   'Denver Nuggets',
#   '114',
#   'Los Angeles Lakers',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201810250LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '7:00p',
#   'Chicago Bulls',
#   '106',
#   'Charlotte Hornets',
#   '135',
#   'https://www.basketball-reference.com/boxscores/201810260CHO.html',
#   '',
#   '15,220',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '7:30p',
#   'Golden State Warriors',
#   '128',
#   'New York Knicks',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201810260NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '7:30p',
#   'Dallas Mavericks',
#   '107',
#   'Toronto Raptors',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810260TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '8:00p',
#   'Los Angeles Clippers',
#   '133',
#   'Houston Rockets',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810260HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '8:00p',
#   'Milwaukee Bucks',
#   '125',
#   'Minnesota Timberwolves',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201810260MIN.html',
#   '',
#   '16,334',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '8:00p',
#   'Brooklyn Nets',
#   '115',
#   'New Orleans Pelicans',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201810260NOP.html',
#   '',
#   '15,272',
#   ''],
#  ['Fri, Oct 26, 2018',
#   '10:00p',
#   'Washington Wizards',
#   '112',
#   'Sacramento Kings',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810260SAC.html',
#   '',
#   '14,101',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '7:00p',
#   'Boston Celtics',
#   '109',
#   'Detroit Pistons',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201810270DET.html',
#   '',
#   '18,120',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '7:00p',
#   'Utah Jazz',
#   '132',
#   'New Orleans Pelicans',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201810270NOP.html',
#   '',
#   '16,373',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '7:30p',
#   'Chicago Bulls',
#   '97',
#   'Atlanta Hawks',
#   '85',
#   'https://www.basketball-reference.com/boxscores/201810270ATL.html',
#   '',
#   '15,549',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '7:30p',
#   'Indiana Pacers',
#   '119',
#   'Cleveland Cavaliers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201810270CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '7:30p',
#   'Charlotte Hornets',
#   '103',
#   'Philadelphia 76ers',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201810270PHI.html',
#   '',
#   '20,203',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '8:00p',
#   'Phoenix Suns',
#   '96',
#   'Memphis Grizzlies',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201810270MEM.html',
#   '',
#   '15,926',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '8:00p',
#   'Portland Trail Blazers',
#   '111',
#   'Miami Heat',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201810270MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '8:30p',
#   'Orlando Magic',
#   '91',
#   'Milwaukee Bucks',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810270MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Sat, Oct 27, 2018',
#   '8:30p',
#   'Los Angeles Lakers',
#   '106',
#   'San Antonio Spurs',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201810270SAS.html',
#   '',
#   '18,589',
#   ''],
#  ['Sun, Oct 28, 2018',
#   '5:00p',
#   'Golden State Warriors',
#   '120',
#   'Brooklyn Nets',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201810280BRK.html',
#   '',
#   '17,732',
#   ''],
#  ['Sun, Oct 28, 2018',
#   '7:00p',
#   'Utah Jazz',
#   '113',
#   'Dallas Mavericks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201810280DAL.html',
#   '',
#   '19,571',
#   ''],
#  ['Sun, Oct 28, 2018',
#   '7:00p',
#   'Phoenix Suns',
#   '110',
#   'Oklahoma City Thunder',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201810280OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sun, Oct 28, 2018',
#   '9:30p',
#   'Washington Wizards',
#   '104',
#   'Los Angeles Clippers',
#   '136',
#   'https://www.basketball-reference.com/boxscores/201810280LAC.html',
#   '',
#   '16,491',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '7:00p',
#   'Portland Trail Blazers',
#   '103',
#   'Indiana Pacers',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201810290IND.html',
#   '',
#   '15,788',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '7:00p',
#   'Atlanta Hawks',
#   '92',
#   'Philadelphia 76ers',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810290PHI.html',
#   '',
#   '20,269',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '7:30p',
#   'Sacramento Kings',
#   '123',
#   'Miami Heat',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810290MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '7:30p',
#   'Brooklyn Nets',
#   '96',
#   'New York Knicks',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201810290NYK.html',
#   '',
#   '19,221',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '8:00p',
#   'Golden State Warriors',
#   '149',
#   'Chicago Bulls',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201810290CHI.html',
#   '',
#   '21,076',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '8:00p',
#   'Toronto Raptors',
#   '109',
#   'Milwaukee Bucks',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201810290MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '8:00p',
#   'Los Angeles Lakers',
#   '120',
#   'Minnesota Timberwolves',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201810290MIN.html',
#   '',
#   '18,978',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '8:30p',
#   'Dallas Mavericks',
#   '108',
#   'San Antonio Spurs',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201810290SAS.html',
#   'OT',
#   '18,354',
#   ''],
#  ['Mon, Oct 29, 2018',
#   '9:00p',
#   'New Orleans Pelicans',
#   '111',
#   'Denver Nuggets',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201810290DEN.html',
#   '',
#   '15,217',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '7:00p',
#   'Miami Heat',
#   '113',
#   'Charlotte Hornets',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201810300CHO.html',
#   '',
#   '14,117',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '7:00p',
#   'Atlanta Hawks',
#   '114',
#   'Cleveland Cavaliers',
#   '136',
#   'https://www.basketball-reference.com/boxscores/201810300CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '7:00p',
#   'Sacramento Kings',
#   '107',
#   'Orlando Magic',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201810300ORL.html',
#   '',
#   '15,074',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '7:30p',
#   'Detroit Pistons',
#   '105',
#   'Boston Celtics',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201810300BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '7:30p',
#   'Philadelphia 76ers',
#   '112',
#   'Toronto Raptors',
#   '129',
#   'https://www.basketball-reference.com/boxscores/201810300TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '8:00p',
#   'Portland Trail Blazers',
#   '104',
#   'Houston Rockets',
#   '85',
#   'https://www.basketball-reference.com/boxscores/201810300HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '8:00p',
#   'Washington Wizards',
#   '95',
#   'Memphis Grizzlies',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201810300MEM.html',
#   '',
#   '14,106',
#   ''],
#  ['Tue, Oct 30, 2018',
#   '8:00p',
#   'Los Angeles Clippers',
#   '110',
#   'Oklahoma City Thunder',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201810300OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '7:30p',
#   'Detroit Pistons',
#   '119',
#   'Brooklyn Nets',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201810310BRK.html',
#   'OT',
#   '12,862',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '8:00p',
#   'Denver Nuggets',
#   '108',
#   'Chicago Bulls',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201810310CHI.html',
#   'OT',
#   '19,027',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '8:00p',
#   'Utah Jazz',
#   '125',
#   'Minnesota Timberwolves',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201810310MIN.html',
#   '',
#   '10,079',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '8:00p',
#   'Indiana Pacers',
#   '107',
#   'New York Knicks',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201810310NYK.html',
#   '',
#   '18,295',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '10:30p',
#   'New Orleans Pelicans',
#   '121',
#   'Golden State Warriors',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201810310GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '10:30p',
#   'Dallas Mavericks',
#   '113',
#   'Los Angeles Lakers',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201810310LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Wed, Oct 31, 2018',
#   '10:30p',
#   'San Antonio Spurs',
#   '120',
#   'Phoenix Suns',
#   '90',
#   'https://www.basketball-reference.com/boxscores/201810310PHO.html',
#   '',
#   '12,328',
#   ''],
#  ['Thu, Nov 1, 2018',
#   '7:00p',
#   'Oklahoma City Thunder',
#   '111',
#   'Charlotte Hornets',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811010CHO.html',
#   '',
#   '14,583',
#   ''],
#  ['Thu, Nov 1, 2018',
#   '7:00p',
#   'Denver Nuggets',
#   '110',
#   'Cleveland Cavaliers',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201811010CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Thu, Nov 1, 2018',
#   '7:00p',
#   'Los Angeles Clippers',
#   '113',
#   'Philadelphia 76ers',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201811010PHI.html',
#   '',
#   '20,246',
#   ''],
#  ['Thu, Nov 1, 2018',
#   '7:30p',
#   'Sacramento Kings',
#   '146',
#   'Atlanta Hawks',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201811010ATL.html',
#   '',
#   '12,095',
#   ''],
#  ['Thu, Nov 1, 2018',
#   '8:00p',
#   'Milwaukee Bucks',
#   '113',
#   'Boston Celtics',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811010BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Thu, Nov 1, 2018',
#   '10:30p',
#   'New Orleans Pelicans',
#   '119',
#   'Portland Trail Blazers',
#   '132',
#   'https://www.basketball-reference.com/boxscores/201811010POR.html',
#   '',
#   '18,921',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '7:00p',
#   'Los Angeles Clippers',
#   '120',
#   'Orlando Magic',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201811020ORL.html',
#   '',
#   '15,953',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '7:30p',
#   'Houston Rockets',
#   '119',
#   'Brooklyn Nets',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811020BRK.html',
#   '',
#   '14,013',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '8:00p',
#   'Indiana Pacers',
#   '107',
#   'Chicago Bulls',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201811020CHI.html',
#   '',
#   '19,704',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '8:00p',
#   'Oklahoma City Thunder',
#   '134',
#   'Washington Wizards',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811020WAS.html',
#   '',
#   '20,409',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '8:30p',
#   'New York Knicks',
#   '118',
#   'Dallas Mavericks',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201811020DAL.html',
#   '',
#   '20,008',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '9:00p',
#   'Memphis Grizzlies',
#   '110',
#   'Utah Jazz',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201811020UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '10:00p',
#   'Toronto Raptors',
#   '107',
#   'Phoenix Suns',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201811020PHO.html',
#   '',
#   '15,843',
#   ''],
#  ['Fri, Nov 2, 2018',
#   '10:30p',
#   'Minnesota Timberwolves',
#   '99',
#   'Golden State Warriors',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201811020GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '1:00p',
#   'Detroit Pistons',
#   '99',
#   'Philadelphia 76ers',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201811030PHI.html',
#   '',
#   '20,289',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '94',
#   'Charlotte Hornets',
#   '126',
#   'https://www.basketball-reference.com/boxscores/201811030CHO.html',
#   '',
#   '16,221',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '7:00p',
#   'Boston Celtics',
#   '101',
#   'Indiana Pacers',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201811030IND.html',
#   '',
#   '17,505',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '7:30p',
#   'Miami Heat',
#   '118',
#   'Atlanta Hawks',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201811030ATL.html',
#   '',
#   '16,303',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '8:00p',
#   'Houston Rockets',
#   '96',
#   'Chicago Bulls',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201811030CHI.html',
#   '',
#   '20,505',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '8:30p',
#   'New Orleans Pelicans',
#   '95',
#   'San Antonio Spurs',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201811030SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '9:00p',
#   'Utah Jazz',
#   '88',
#   'Denver Nuggets',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201811030DEN.html',
#   '',
#   '19,520',
#   ''],
#  ['Sat, Nov 3, 2018',
#   '10:00p',
#   'Los Angeles Lakers',
#   '114',
#   'Portland Trail Blazers',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201811030POR.html',
#   '',
#   '19,848',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '3:30p',
#   'Sacramento Kings',
#   '109',
#   'Milwaukee Bucks',
#   '144',
#   'https://www.basketball-reference.com/boxscores/201811040MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '6:00p',
#   'Philadelphia 76ers',
#   '97',
#   'Brooklyn Nets',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201811040BRK.html',
#   '',
#   '12,826',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '6:00p',
#   'New York Knicks',
#   '95',
#   'Washington Wizards',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201811040WAS.html',
#   '',
#   '16,679',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '7:00p',
#   'Orlando Magic',
#   '117',
#   'San Antonio Spurs',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201811040SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '8:00p',
#   'Memphis Grizzlies',
#   '100',
#   'Phoenix Suns',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201811040PHO.html',
#   '',
#   '13,074',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '9:00p',
#   'Minnesota Timberwolves',
#   '81',
#   'Portland Trail Blazers',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811040POR.html',
#   '',
#   '19,522',
#   ''],
#  ['Sun, Nov 4, 2018',
#   '9:30p',
#   'Toronto Raptors',
#   '121',
#   'Los Angeles Lakers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811040LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '7:00p',
#   'Miami Heat',
#   '120',
#   'Detroit Pistons',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201811050DET.html',
#   'OT',
#   '14,148',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '7:00p',
#   'Houston Rockets',
#   '98',
#   'Indiana Pacers',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201811050IND.html',
#   '',
#   '14,735',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '100',
#   'Orlando Magic',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201811050ORL.html',
#   '',
#   '15,009',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '7:30p',
#   'Chicago Bulls',
#   '116',
#   'New York Knicks',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201811050NYK.html',
#   '2OT',
#   '19,812',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '8:00p',
#   'New Orleans Pelicans',
#   '116',
#   'Oklahoma City Thunder',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201811050OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '9:00p',
#   'Boston Celtics',
#   '107',
#   'Denver Nuggets',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201811050DEN.html',
#   '',
#   '19,520',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '9:00p',
#   'Toronto Raptors',
#   '124',
#   'Utah Jazz',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811050UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '10:30p',
#   'Memphis Grizzlies',
#   '101',
#   'Golden State Warriors',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811050GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Mon, Nov 5, 2018',
#   '10:30p',
#   'Minnesota Timberwolves',
#   '109',
#   'Los Angeles Clippers',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201811050LAC.html',
#   '',
#   '16,564',
#   ''],
#  ['Tue, Nov 6, 2018',
#   '7:00p',
#   'Atlanta Hawks',
#   '102',
#   'Charlotte Hornets',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201811060CHO.html',
#   '',
#   '13,955',
#   ''],
#  ['Tue, Nov 6, 2018',
#   '8:30p',
#   'Washington Wizards',
#   '100',
#   'Dallas Mavericks',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811060DAL.html',
#   '',
#   '19,234',
#   ''],
#  ['Tue, Nov 6, 2018',
#   '9:00p',
#   'Brooklyn Nets',
#   '104',
#   'Phoenix Suns',
#   '82',
#   'https://www.basketball-reference.com/boxscores/201811060PHO.html',
#   '',
#   '14,205',
#   ''],
#  ['Tue, Nov 6, 2018',
#   '10:00p',
#   'Milwaukee Bucks',
#   '103',
#   'Portland Trail Blazers',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201811060POR.html',
#   '',
#   '19,512',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '7:00p',
#   'Oklahoma City Thunder',
#   '95',
#   'Cleveland Cavaliers',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201811070CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '7:00p',
#   'Detroit Pistons',
#   '103',
#   'Orlando Magic',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201811070ORL.html',
#   '',
#   '16,103',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '7:30p',
#   'New York Knicks',
#   '112',
#   'Atlanta Hawks',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811070ATL.html',
#   '',
#   '12,412',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '7:30p',
#   'San Antonio Spurs',
#   '88',
#   'Miami Heat',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201811070MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '8:00p',
#   'Philadelphia 76ers',
#   '100',
#   'Indiana Pacers',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201811070IND.html',
#   '',
#   '16,434',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '8:00p',
#   'Denver Nuggets',
#   '87',
#   'Memphis Grizzlies',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201811070MEM.html',
#   '',
#   '15,832',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '8:00p',
#   'Chicago Bulls',
#   '98',
#   'New Orleans Pelicans',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811070NOP.html',
#   '',
#   '15,514',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '9:00p',
#   'Dallas Mavericks',
#   '102',
#   'Utah Jazz',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811070UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '10:00p',
#   'Toronto Raptors',
#   '114',
#   'Sacramento Kings',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201811070SAC.html',
#   '',
#   '17,583',
#   ''],
#  ['Wed, Nov 7, 2018',
#   '10:30p',
#   'Minnesota Timberwolves',
#   '110',
#   'Los Angeles Lakers',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201811070LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Thu, Nov 8, 2018',
#   '8:00p',
#   'Houston Rockets',
#   '80',
#   'Oklahoma City Thunder',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201811080OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Thu, Nov 8, 2018',
#   '9:00p',
#   'Boston Celtics',
#   '116',
#   'Phoenix Suns',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201811080PHO.html',
#   'OT',
#   '17,359',
#   ''],
#  ['Thu, Nov 8, 2018',
#   '10:00p',
#   'Los Angeles Clippers',
#   '105',
#   'Portland Trail Blazers',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201811080POR.html',
#   '',
#   '19,170',
#   ''],
#  ['Thu, Nov 8, 2018',
#   '10:30p',
#   'Milwaukee Bucks',
#   '134',
#   'Golden State Warriors',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811080GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '7:00p',
#   'Washington Wizards',
#   '108',
#   'Orlando Magic',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811090ORL.html',
#   '',
#   '16,562',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '7:00p',
#   'Charlotte Hornets',
#   '132',
#   'Philadelphia 76ers',
#   '133',
#   'https://www.basketball-reference.com/boxscores/201811090PHI.html',
#   'OT',
#   '20,424',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '7:30p',
#   'Detroit Pistons',
#   '124',
#   'Atlanta Hawks',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201811090ATL.html',
#   '',
#   '14,759',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '8:00p',
#   'Indiana Pacers',
#   '110',
#   'Miami Heat',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201811090MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '9:00p',
#   'Brooklyn Nets',
#   '112',
#   'Denver Nuggets',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201811090DEN.html',
#   '',
#   '19,520',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '9:30p',
#   'Boston Celtics',
#   '115',
#   'Utah Jazz',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201811090UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Fri, Nov 9, 2018',
#   '10:00p',
#   'Minnesota Timberwolves',
#   '110',
#   'Sacramento Kings',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201811090SAC.html',
#   '',
#   '17,583',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '3:00p',
#   'New York Knicks',
#   '112',
#   'Toronto Raptors',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201811100TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '3:30p',
#   'Milwaukee Bucks',
#   '126',
#   'Los Angeles Clippers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201811100LAC.html',
#   'OT',
#   '17,486',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '7:00p',
#   'Phoenix Suns',
#   '99',
#   'New Orleans Pelicans',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811100NOP.html',
#   '',
#   '15,222',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '8:00p',
#   'Cleveland Cavaliers',
#   '98',
#   'Chicago Bulls',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201811100CHI.html',
#   '',
#   '21,506',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '8:00p',
#   'Philadelphia 76ers',
#   '106',
#   'Memphis Grizzlies',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201811100MEM.html',
#   'OT',
#   '16,904',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '8:00p',
#   'Washington Wizards',
#   '116',
#   'Miami Heat',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201811100MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '8:30p',
#   'Brooklyn Nets',
#   '100',
#   'Golden State Warriors',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201811100GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '8:30p',
#   'Houston Rockets',
#   '89',
#   'San Antonio Spurs',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201811100SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '9:00p',
#   'Oklahoma City Thunder',
#   '96',
#   'Dallas Mavericks',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811100DAL.html',
#   '',
#   '19,818',
#   ''],
#  ['Sat, Nov 10, 2018',
#   '10:00p',
#   'Los Angeles Lakers',
#   '101',
#   'Sacramento Kings',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201811100SAC.html',
#   '',
#   '17,583',
#   ''],
#  ['Sun, Nov 11, 2018',
#   '3:30p',
#   'Charlotte Hornets',
#   '113',
#   'Detroit Pistons',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201811110DET.html',
#   '',
#   '15,133',
#   ''],
#  ['Sun, Nov 11, 2018',
#   '7:00p',
#   'Indiana Pacers',
#   '103',
#   'Houston Rockets',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201811110HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Sun, Nov 11, 2018',
#   '7:30p',
#   'Orlando Magic',
#   '115',
#   'New York Knicks',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201811110NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Sun, Nov 11, 2018',
#   '8:00p',
#   'Milwaukee Bucks',
#   '121',
#   'Denver Nuggets',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201811110DEN.html',
#   '',
#   '19,520',
#   ''],
#  ['Sun, Nov 11, 2018',
#   '9:00p',
#   'Boston Celtics',
#   '94',
#   'Portland Trail Blazers',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201811110POR.html',
#   '',
#   '19,712',
#   ''],
#  ['Sun, Nov 11, 2018',
#   '9:30p',
#   'Atlanta Hawks',
#   '106',
#   'Los Angeles Lakers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811110LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '7:00p',
#   'Orlando Magic',
#   '109',
#   'Washington Wizards',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811120WAS.html',
#   '',
#   '15,346',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '7:30p',
#   'Philadelphia 76ers',
#   '124',
#   'Miami Heat',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201811120MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '7:30p',
#   'New Orleans Pelicans',
#   '126',
#   'Toronto Raptors',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201811120TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '8:00p',
#   'Dallas Mavericks',
#   '103',
#   'Chicago Bulls',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201811120CHI.html',
#   '',
#   '19,012',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '8:00p',
#   'Utah Jazz',
#   '96',
#   'Memphis Grizzlies',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201811120MEM.html',
#   '',
#   '13,477',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '8:00p',
#   'Brooklyn Nets',
#   '113',
#   'Minnesota Timberwolves',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201811120MIN.html',
#   '',
#   '10,186',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '8:00p',
#   'Phoenix Suns',
#   '101',
#   'Oklahoma City Thunder',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201811120OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '10:00p',
#   'San Antonio Spurs',
#   '99',
#   'Sacramento Kings',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201811120SAC.html',
#   '',
#   '15,500',
#   ''],
#  ['Mon, Nov 12, 2018',
#   '10:30p',
#   'Golden State Warriors',
#   '116',
#   'Los Angeles Clippers',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201811120LAC.html',
#   'OT',
#   '19,068',
#   ''],
#  ['Tue, Nov 13, 2018',
#   '7:00p',
#   'Charlotte Hornets',
#   '89',
#   'Cleveland Cavaliers',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201811130CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Tue, Nov 13, 2018',
#   '9:00p',
#   'Houston Rockets',
#   '109',
#   'Denver Nuggets',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201811130DEN.html',
#   '',
#   '16,741',
#   ''],
#  ['Tue, Nov 13, 2018',
#   '10:30p',
#   'Atlanta Hawks',
#   '103',
#   'Golden State Warriors',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201811130GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '7:00p',
#   'Philadelphia 76ers',
#   '106',
#   'Orlando Magic',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811140ORL.html',
#   '',
#   '15,921',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '95',
#   'Washington Wizards',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811140WAS.html',
#   '',
#   '14,537',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '7:30p',
#   'Chicago Bulls',
#   '82',
#   'Boston Celtics',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201811140BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '7:30p',
#   'Miami Heat',
#   '120',
#   'Brooklyn Nets',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811140BRK.html',
#   '',
#   '13,317',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '7:30p',
#   'Detroit Pistons',
#   '106',
#   'Toronto Raptors',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201811140TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '8:00p',
#   'Memphis Grizzlies',
#   '116',
#   'Milwaukee Bucks',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201811140MIL.html',
#   '',
#   '16,817',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '8:00p',
#   'New Orleans Pelicans',
#   '100',
#   'Minnesota Timberwolves',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811140MIN.html',
#   '',
#   '11,636',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '8:00p',
#   'New York Knicks',
#   '103',
#   'Oklahoma City Thunder',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201811140OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '8:30p',
#   'Utah Jazz',
#   '68',
#   'Dallas Mavericks',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201811140DAL.html',
#   '',
#   '19,371',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '9:00p',
#   'San Antonio Spurs',
#   '96',
#   'Phoenix Suns',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201811140PHO.html',
#   '',
#   '14,532',
#   ''],
#  ['Wed, Nov 14, 2018',
#   '10:30p',
#   'Portland Trail Blazers',
#   '117',
#   'Los Angeles Lakers',
#   '126',
#   'https://www.basketball-reference.com/boxscores/201811140LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Thu, Nov 15, 2018',
#   '8:00p',
#   'Golden State Warriors',
#   '86',
#   'Houston Rockets',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201811150HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Thu, Nov 15, 2018',
#   '9:00p',
#   'Atlanta Hawks',
#   '93',
#   'Denver Nuggets',
#   '138',
#   'https://www.basketball-reference.com/boxscores/201811150DEN.html',
#   '',
#   '15,103',
#   ''],
#  ['Thu, Nov 15, 2018',
#   '10:30p',
#   'San Antonio Spurs',
#   '111',
#   'Los Angeles Clippers',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201811150LAC.html',
#   '',
#   '17,463',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '7:00p',
#   'Toronto Raptors',
#   '116',
#   'Boston Celtics',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201811160BOS.html',
#   'OT',
#   '18,624',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '7:00p',
#   'Miami Heat',
#   '91',
#   'Indiana Pacers',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201811160IND.html',
#   '',
#   '17,923',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '7:00p',
#   'Utah Jazz',
#   '107',
#   'Philadelphia 76ers',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201811160PHI.html',
#   '',
#   '20,485',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '7:00p',
#   'Brooklyn Nets',
#   '115',
#   'Washington Wizards',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201811160WAS.html',
#   '',
#   '15,102',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '8:00p',
#   'Sacramento Kings',
#   '104',
#   'Memphis Grizzlies',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201811160MEM.html',
#   '',
#   '13,811',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '8:00p',
#   'Portland Trail Blazers',
#   '96',
#   'Minnesota Timberwolves',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201811160MIN.html',
#   '',
#   '18,978',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '8:00p',
#   'New York Knicks',
#   '124',
#   'New Orleans Pelicans',
#   '129',
#   'https://www.basketball-reference.com/boxscores/201811160NOP.html',
#   '',
#   '14,717',
#   ''],
#  ['Fri, Nov 16, 2018',
#   '9:30p',
#   'Chicago Bulls',
#   '104',
#   'Milwaukee Bucks',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201811160MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '6:00p',
#   'Los Angeles Clippers',
#   '127',
#   'Brooklyn Nets',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811170BRK.html',
#   '',
#   '12,944',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '7:00p',
#   'Philadelphia 76ers',
#   '122',
#   'Charlotte Hornets',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811170CHO.html',
#   'OT',
#   '19,426',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '7:00p',
#   'Atlanta Hawks',
#   '89',
#   'Indiana Pacers',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201811170IND.html',
#   '',
#   '17,491',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '7:00p',
#   'Denver Nuggets',
#   '115',
#   'New Orleans Pelicans',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201811170NOP.html',
#   '',
#   '15,408',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '7:00p',
#   'Los Angeles Lakers',
#   '117',
#   'Orlando Magic',
#   '130',
#   'https://www.basketball-reference.com/boxscores/201811170ORL.html',
#   '',
#   '19,249',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '7:30p',
#   'Utah Jazz',
#   '98',
#   'Boston Celtics',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201811170BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '8:00p',
#   'Toronto Raptors',
#   '122',
#   'Chicago Bulls',
#   '83',
#   'https://www.basketball-reference.com/boxscores/201811170CHI.html',
#   '',
#   '21,263',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '8:00p',
#   'Sacramento Kings',
#   '112',
#   'Houston Rockets',
#   '132',
#   'https://www.basketball-reference.com/boxscores/201811170HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '8:30p',
#   'Golden State Warriors',
#   '109',
#   'Dallas Mavericks',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201811170DAL.html',
#   '',
#   '20,260',
#   ''],
#  ['Sat, Nov 17, 2018',
#   '9:00p',
#   'Oklahoma City Thunder',
#   '110',
#   'Phoenix Suns',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201811170PHO.html',
#   '',
#   '16,376',
#   ''],
#  ['Sun, Nov 18, 2018',
#   '3:30p',
#   'Memphis Grizzlies',
#   '100',
#   'Minnesota Timberwolves',
#   '87',
#   'https://www.basketball-reference.com/boxscores/201811180MIN.html',
#   '',
#   '13,179',
#   ''],
#  ['Sun, Nov 18, 2018',
#   '6:00p',
#   'Los Angeles Lakers',
#   '113',
#   'Miami Heat',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201811180MIA.html',
#   '',
#   '19,686',
#   ''],
#  ['Sun, Nov 18, 2018',
#   '6:00p',
#   'New York Knicks',
#   '117',
#   'Orlando Magic',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201811180ORL.html',
#   '',
#   '15,898',
#   ''],
#  ['Sun, Nov 18, 2018',
#   '6:00p',
#   'Portland Trail Blazers',
#   '119',
#   'Washington Wizards',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201811180WAS.html',
#   '',
#   '16,647',
#   ''],
#  ['Sun, Nov 18, 2018',
#   '7:00p',
#   'Golden State Warriors',
#   '92',
#   'San Antonio Spurs',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201811180SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '7:00p',
#   'Boston Celtics',
#   '112',
#   'Charlotte Hornets',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811190CHO.html',
#   '',
#   '18,040',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '102',
#   'Detroit Pistons',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201811190DET.html',
#   '',
#   '15,769',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '7:00p',
#   'Utah Jazz',
#   '94',
#   'Indiana Pacers',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201811190IND.html',
#   '',
#   '17,000',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '7:00p',
#   'Phoenix Suns',
#   '114',
#   'Philadelphia 76ers',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811190PHI.html',
#   '',
#   '20,459',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '7:30p',
#   'Los Angeles Clippers',
#   '127',
#   'Atlanta Hawks',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201811190ATL.html',
#   '',
#   '14,323',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '8:00p',
#   'Dallas Mavericks',
#   '88',
#   'Memphis Grizzlies',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201811190MEM.html',
#   '',
#   '15,997',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '8:00p',
#   'Denver Nuggets',
#   '98',
#   'Milwaukee Bucks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201811190MIL.html',
#   '',
#   '17,341',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '8:00p',
#   'San Antonio Spurs',
#   '126',
#   'New Orleans Pelicans',
#   '140',
#   'https://www.basketball-reference.com/boxscores/201811190NOP.html',
#   '',
#   '14,675',
#   ''],
#  ['Mon, Nov 19, 2018',
#   '10:00p',
#   'Oklahoma City Thunder',
#   '113',
#   'Sacramento Kings',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201811190SAC.html',
#   '',
#   '16,250',
#   ''],
#  ['Tue, Nov 20, 2018',
#   '7:00p',
#   'Toronto Raptors',
#   '93',
#   'Orlando Magic',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201811200ORL.html',
#   '',
#   '16,016',
#   ''],
#  ['Tue, Nov 20, 2018',
#   '7:00p',
#   'Los Angeles Clippers',
#   '118',
#   'Washington Wizards',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201811200WAS.html',
#   '',
#   '14,499',
#   ''],
#  ['Tue, Nov 20, 2018',
#   '7:30p',
#   'Brooklyn Nets',
#   '104',
#   'Miami Heat',
#   '92',
#   'https://www.basketball-reference.com/boxscores/201811200MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Tue, Nov 20, 2018',
#   '7:30p',
#   'Portland Trail Blazers',
#   '118',
#   'New York Knicks',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201811200NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Wed, Nov 21, 2018',
#   '7:00p',
#   'Indiana Pacers',
#   '109',
#   'Charlotte Hornets',
#   '127',
# ...
#   ''],
#  ['Wed, Feb 27, 2019',
#   '8:30p',
#   'Indiana Pacers',
#   '101',
#   'Dallas Mavericks',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201902270DAL.html',
#   '',
#   '19,978',
#   ''],
#  ['Wed, Feb 27, 2019',
#   '8:30p',
#   'Detroit Pistons',
#   '93',
#   'San Antonio Spurs',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201902270SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Wed, Feb 27, 2019',
#   '9:00p',
#   'Los Angeles Clippers',
#   '105',
#   'Utah Jazz',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201902270UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Wed, Feb 27, 2019',
#   '10:00p',
#   'Milwaukee Bucks',
#   '141',
#   'Sacramento Kings',
#   '140',
#   'https://www.basketball-reference.com/boxscores/201902270SAC.html',
#   'OT',
#   '17,583',
#   ''],
#  ['Wed, Feb 27, 2019',
#   '10:30p',
#   'New Orleans Pelicans',
#   '119',
#   'Los Angeles Lakers',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201902270LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Thu, Feb 28, 2019',
#   '7:00p',
#   'Minnesota Timberwolves',
#   '115',
#   'Indiana Pacers',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201902280IND.html',
#   '',
#   '17,003',
#   ''],
#  ['Thu, Feb 28, 2019',
#   '7:00p',
#   'Golden State Warriors',
#   '96',
#   'Orlando Magic',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201902280ORL.html',
#   '',
#   '18,846',
#   ''],
#  ['Thu, Feb 28, 2019',
#   '7:30p',
#   'Cleveland Cavaliers',
#   '125',
#   'New York Knicks',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201902280NYK.html',
#   '',
#   '17,573',
#   ''],
#  ['Thu, Feb 28, 2019',
#   '8:00p',
#   'Miami Heat',
#   '118',
#   'Houston Rockets',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201902280HOU.html',
#   '',
#   '18,119',
#   ''],
#  ['Thu, Feb 28, 2019',
#   '8:00p',
#   'Philadelphia 76ers',
#   '108',
#   'Oklahoma City Thunder',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201902280OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Thu, Feb 28, 2019',
#   '10:30p',
#   'Utah Jazz',
#   '111',
#   'Denver Nuggets',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201902280DEN.html',
#   '',
#   '19,520',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '7:30p',
#   'Chicago Bulls',
#   '168',
#   'Atlanta Hawks',
#   '161',
#   'https://www.basketball-reference.com/boxscores/201903010ATL.html',
#   '4OT',
#   '15,267',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '7:30p',
#   'Charlotte Hornets',
#   '123',
#   'Brooklyn Nets',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903010BRK.html',
#   '',
#   '15,578',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '8:00p',
#   'Washington Wizards',
#   '96',
#   'Boston Celtics',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201903010BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '8:00p',
#   'Portland Trail Blazers',
#   '117',
#   'Toronto Raptors',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201903010TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '9:00p',
#   'New Orleans Pelicans',
#   '130',
#   'Phoenix Suns',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201903010PHO.html',
#   '',
#   '14,123',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '10:00p',
#   'Los Angeles Clippers',
#   '116',
#   'Sacramento Kings',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201903010SAC.html',
#   '',
#   '17,583',
#   ''],
#  ['Fri, Mar 1, 2019',
#   '10:30p',
#   'Milwaukee Bucks',
#   '131',
#   'Los Angeles Lakers',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201903010LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '5:00p',
#   'Detroit Pistons',
#   '129',
#   'Cleveland Cavaliers',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201903020CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '7:00p',
#   'Orlando Magic',
#   '117',
#   'Indiana Pacers',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903020IND.html',
#   '',
#   '17,923',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '7:30p',
#   'Brooklyn Nets',
#   '88',
#   'Miami Heat',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201903020MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '8:30p',
#   'Memphis Grizzlies',
#   '111',
#   'Dallas Mavericks',
#   '81',
#   'https://www.basketball-reference.com/boxscores/201903020DAL.html',
#   '',
#   '20,233',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '8:30p',
#   'Golden State Warriors',
#   '120',
#   'Philadelphia 76ers',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201903020PHI.html',
#   '',
#   '20,624',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '8:30p',
#   'Oklahoma City Thunder',
#   '102',
#   'San Antonio Spurs',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201903020SAS.html',
#   '',
#   '18,439',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '9:00p',
#   'New Orleans Pelicans',
#   '120',
#   'Denver Nuggets',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903020DEN.html',
#   '',
#   '19,978',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '9:00p',
#   'Los Angeles Lakers',
#   '109',
#   'Phoenix Suns',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201903020PHO.html',
#   '',
#   '18,055',
#   ''],
#  ['Sat, Mar 2, 2019',
#   '9:00p',
#   'Milwaukee Bucks',
#   '111',
#   'Utah Jazz',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201903020UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '1:00p',
#   'Portland Trail Blazers',
#   '118',
#   'Charlotte Hornets',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201903030CHO.html',
#   '',
#   '18,355',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '3:30p',
#   'Houston Rockets',
#   '115',
#   'Boston Celtics',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903030BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '3:30p',
#   'Atlanta Hawks',
#   '123',
#   'Chicago Bulls',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201903030CHI.html',
#   '',
#   '20,526',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '3:30p',
#   'New York Knicks',
#   '107',
#   'Los Angeles Clippers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201903030LAC.html',
#   '',
#   '19,068',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '6:00p',
#   'Orlando Magic',
#   '93',
#   'Cleveland Cavaliers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201903030CLE.html',
#   '',
#   '19,432',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '6:00p',
#   'Toronto Raptors',
#   '107',
#   'Detroit Pistons',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903030DET.html',
#   'OT',
#   '19,161',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '6:00p',
#   'Minnesota Timberwolves',
#   '121',
#   'Washington Wizards',
#   '135',
#   'https://www.basketball-reference.com/boxscores/201903030WAS.html',
#   '',
#   '17,869',
#   ''],
#  ['Sun, Mar 3, 2019',
#   '7:00p',
#   'Memphis Grizzlies',
#   '95',
#   'Oklahoma City Thunder',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201903030OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '7:30p',
#   'Dallas Mavericks',
#   '88',
#   'Brooklyn Nets',
#   '127',
#   'https://www.basketball-reference.com/boxscores/201903040BRK.html',
#   '',
#   '17,064',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '7:30p',
#   'Atlanta Hawks',
#   '113',
#   'Miami Heat',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201903040MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '8:30p',
#   'Denver Nuggets',
#   '103',
#   'San Antonio Spurs',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903040SAS.html',
#   '',
#   '18,354',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '9:00p',
#   'Milwaukee Bucks',
#   '105',
#   'Phoenix Suns',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201903040PHO.html',
#   '',
#   '18,055',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '9:00p',
#   'New Orleans Pelicans',
#   '115',
#   'Utah Jazz',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903040UTA.html',
#   '',
#   '18,306',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '10:00p',
#   'New York Knicks',
#   '108',
#   'Sacramento Kings',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201903040SAC.html',
#   '',
#   '17,034',
#   ''],
#  ['Mon, Mar 4, 2019',
#   '10:30p',
#   'Los Angeles Clippers',
#   '113',
#   'Los Angeles Lakers',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201903040LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Tue, Mar 5, 2019',
#   '7:00p',
#   'Chicago Bulls',
#   '96',
#   'Indiana Pacers',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201903050IND.html',
#   '',
#   '15,753',
#   ''],
#  ['Tue, Mar 5, 2019',
#   '7:00p',
#   'Orlando Magic',
#   '106',
#   'Philadelphia 76ers',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201903050PHI.html',
#   '',
#   '20,379',
#   ''],
#  ['Tue, Mar 5, 2019',
#   '8:00p',
#   'Portland Trail Blazers',
#   '111',
#   'Memphis Grizzlies',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201903050MEM.html',
#   '',
#   '13,801',
#   ''],
#  ['Tue, Mar 5, 2019',
#   '8:00p',
#   'Oklahoma City Thunder',
#   '120',
#   'Minnesota Timberwolves',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201903050MIN.html',
#   '',
#   '15,728',
#   ''],
#  ['Tue, Mar 5, 2019',
#   '8:00p',
#   'Houston Rockets',
#   '107',
#   'Toronto Raptors',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201903050TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Tue, Mar 5, 2019',
#   '10:30p',
#   'Boston Celtics',
#   '128',
#   'Golden State Warriors',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201903050GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '7:00p',
#   'Miami Heat',
#   '91',
#   'Charlotte Hornets',
#   '84',
#   'https://www.basketball-reference.com/boxscores/201903060CHO.html',
#   '',
#   '18,137',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '7:00p',
#   'Minnesota Timberwolves',
#   '114',
#   'Detroit Pistons',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201903060DET.html',
#   '',
#   '15,240',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '7:00p',
#   'Dallas Mavericks',
#   '123',
#   'Washington Wizards',
#   '132',
#   'https://www.basketball-reference.com/boxscores/201903060WAS.html',
#   '',
#   '16,867',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '7:30p',
#   'San Antonio Spurs',
#   '111',
#   'Atlanta Hawks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903060ATL.html',
#   '',
#   '15,208',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '7:30p',
#   'Cleveland Cavaliers',
#   '107',
#   'Brooklyn Nets',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201903060BRK.html',
#   '',
#   '14,177',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '8:00p',
#   'Philadelphia 76ers',
#   '107',
#   'Chicago Bulls',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201903060CHI.html',
#   '',
#   '19,927',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '8:00p',
#   'Utah Jazz',
#   '114',
#   'New Orleans Pelicans',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903060NOP.html',
#   '',
#   '14,681',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '9:00p',
#   'New York Knicks',
#   '96',
#   'Phoenix Suns',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201903060PHO.html',
#   '',
#   '14,427',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '10:00p',
#   'Boston Celtics',
#   '111',
#   'Sacramento Kings',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201903060SAC.html',
#   '',
#   '17,583',
#   ''],
#  ['Wed, Mar 6, 2019',
#   '10:30p',
#   'Denver Nuggets',
#   '115',
#   'Los Angeles Lakers',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201903060LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Thu, Mar 7, 2019',
#   '8:00p',
#   'Indiana Pacers',
#   '98',
#   'Milwaukee Bucks',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201903070MIL.html',
#   '',
#   '17,884',
#   ''],
#  ['Thu, Mar 7, 2019',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '129',
#   'Portland Trail Blazers',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201903070POR.html',
#   'OT',
#   '20,037',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '7:00p',
#   'Washington Wizards',
#   '111',
#   'Charlotte Hornets',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903080CHO.html',
#   '',
#   '18,144',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '7:00p',
#   'Dallas Mavericks',
#   '106',
#   'Orlando Magic',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201903080ORL.html',
#   '',
#   '19,196',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '8:00p',
#   'Detroit Pistons',
#   '112',
#   'Chicago Bulls',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903080CHI.html',
#   '',
#   '21,048',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '8:00p',
#   'Philadelphia 76ers',
#   '91',
#   'Houston Rockets',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201903080HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '8:00p',
#   'Utah Jazz',
#   '104',
#   'Memphis Grizzlies',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201903080MEM.html',
#   '',
#   '15,407',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '8:00p',
#   'Cleveland Cavaliers',
#   '110',
#   'Miami Heat',
#   '126',
#   'https://www.basketball-reference.com/boxscores/201903080MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '8:00p',
#   'Toronto Raptors',
#   '127',
#   'New Orleans Pelicans',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903080NOP.html',
#   '',
#   '17,325',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '10:30p',
#   'Denver Nuggets',
#   '105',
#   'Golden State Warriors',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201903080GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Fri, Mar 8, 2019',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '110',
#   'Los Angeles Clippers',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201903080LAC.html',
#   '',
#   '17,915',
#   ''],
#  ['Sat, Mar 9, 2019',
#   '12:00p',
#   'Sacramento Kings',
#   '102',
#   'New York Knicks',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201903090NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Sat, Mar 9, 2019',
#   '7:00p',
#   'Brooklyn Nets',
#   '114',
#   'Atlanta Hawks',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201903090ATL.html',
#   '',
#   '16,527',
#   ''],
#  ['Sat, Mar 9, 2019',
#   '8:00p',
#   'Washington Wizards',
#   '130',
#   'Minnesota Timberwolves',
#   '135',
#   'https://www.basketball-reference.com/boxscores/201903090MIN.html',
#   'OT',
#   '14,381',
#   ''],
#  ['Sat, Mar 9, 2019',
#   '8:30p',
#   'Boston Celtics',
#   '120',
#   'Los Angeles Lakers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201903090LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Sat, Mar 9, 2019',
#   '9:00p',
#   'Charlotte Hornets',
#   '114',
#   'Milwaukee Bucks',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201903090MIL.html',
#   '',
#   '17,996',
#   ''],
#  ['Sat, Mar 9, 2019',
#   '10:00p',
#   'Phoenix Suns',
#   '120',
#   'Portland Trail Blazers',
#   '127',
#   'https://www.basketball-reference.com/boxscores/201903090POR.html',
#   '',
#   '19,851',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '12:00p',
#   'Chicago Bulls',
#   '108',
#   'Detroit Pistons',
#   '131',
#   'https://www.basketball-reference.com/boxscores/201903100DET.html',
#   '',
#   '19,356',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '3:30p',
#   'Toronto Raptors',
#   '125',
#   'Miami Heat',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201903100MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '3:30p',
#   'Indiana Pacers',
#   '89',
#   'Philadelphia 76ers',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201903100PHI.html',
#   '',
#   '20,636',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '6:00p',
#   'New Orleans Pelicans',
#   '116',
#   'Atlanta Hawks',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201903100ATL.html',
#   '',
#   '14,337',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '6:00p',
#   'Orlando Magic',
#   '97',
#   'Memphis Grizzlies',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201903100MEM.html',
#   '',
#   '16,627',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '7:00p',
#   'Houston Rockets',
#   '94',
#   'Dallas Mavericks',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201903100DAL.html',
#   '',
#   '20,423',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '8:00p',
#   'New York Knicks',
#   '92',
#   'Minnesota Timberwolves',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201903100MIN.html',
#   '',
#   '13,806',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '8:00p',
#   'Milwaukee Bucks',
#   '114',
#   'San Antonio Spurs',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201903100SAS.html',
#   '',
#   '18,594',
#   ''],
#  ['Sun, Mar 10, 2019',
#   '8:30p',
#   'Phoenix Suns',
#   '115',
#   'Golden State Warriors',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201903100GSW.html',
#   '',
#   '19,596',
#   ''],
#  ...]

# %%
#Combine Header and Data to create intiial DF

df = pd.DataFrame(cleanCellData,columns = column_headers)

# %%
def date_change(row):
    t = datetime.datetime.strptime(row['date_game'].replace(',',''), "%a %b %d %Y")
    convert_date = t.strftime('%m/%d/%Y')
    return(convert_date)

df['Date'] = pd.to_datetime(df.apply(date_change,axis = 1))

# %%
nbaDict = {
'Atlanta Hawks': 'ATL',
'Brooklyn Nets': 'BRK',
'Boston Celtics': 'BOS',
'Charlotte Hornets': 'CHO',
'Chicago Bulls': 'CHI',
'Cleveland Cavaliers': 'CLE',
'Dallas Mavericks': 'DAL',
'Denver Nuggets': 'DEN',
'Detroit Pistons': 'DET',
'Golden State Warriors': 'GSW',
'Houston Rockets': 'HOU',
'Indiana Pacers': 'IND',
'Los Angeles Clippers': 'LAC',
'Los Angeles Lakers': 'LAL',
'Memphis Grizzlies': 'MEM',
'Miami Heat': 'MIA',
'Milwaukee Bucks': 'MIL',
'Minnesota Timberwolves': 'MIN',
'New Orleans Pelicans': 'NOP',
'New York Knicks': 'NYK',
'Oklahoma City Thunder': 'OKC',
'Orlando Magic': 'ORL',
'Philadelphia 76ers': 'PHI',
'Phoenix Suns': 'PHO',
'Portland Trail Blazers': 'POR',
'Sacramento Kings': 'SAC',
'San Antonio Spurs': 'SAS',
'Toronto Raptors': 'TOR',
'Utah Jazz': 'UTA',
'Washington Wizards': 'WAS'}

# %%
statColumns = ['Team TS%','Team eFG%','Team ORtg','Opp TS%','Opp eFG%','Opp ORtg']

# %%
def statRecorder(row):
    url1 = row['box_score_text']
    response1 = requests.get(url1)
    page1 = response1.text
    soup1 = BeautifulSoup(page1, "lxml")
    team_list = [nbaDict[row['visitor_team_name']],nbaDict[row['home_team_name']]]
    print([row['visitor_team_name'],row['home_team_name']])
    statsList = []
    index = [1,2,-2]
    for team in team_list:
        boxScoreLink = "box-{}-game-advanced".format(team)
        totalStats = soup1.find('table', id =boxScoreLink).find_all('tr')[-1].find_all('td')
        for i in index:
            statsList.append(totalStats[i].contents[0])
    return(statsList)

# %%
#Create new stats list incrementally and then concatenate after
stats_list = []

# %%
firstBatch = df[0:1200].apply(statRecorder,axis = 1)
for i in firstBatch:
    stats_list.append(i)
# Out:
# ['Philadelphia 76ers', 'Boston Celtics']
# ['Oklahoma City Thunder', 'Golden State Warriors']
# ['Milwaukee Bucks', 'Charlotte Hornets']
# ['Brooklyn Nets', 'Detroit Pistons']
# ['Memphis Grizzlies', 'Indiana Pacers']
# ['Miami Heat', 'Orlando Magic']
# ['Atlanta Hawks', 'New York Knicks']
# ['Cleveland Cavaliers', 'Toronto Raptors']
# ['New Orleans Pelicans', 'Houston Rockets']
# ['Minnesota Timberwolves', 'San Antonio Spurs']
# ['Utah Jazz', 'Sacramento Kings']
# ['Denver Nuggets', 'Los Angeles Clippers']
# ['Dallas Mavericks', 'Phoenix Suns']
# ['Chicago Bulls', 'Philadelphia 76ers']
# ['Miami Heat', 'Washington Wizards']
# ['Los Angeles Lakers', 'Portland Trail Blazers']
# ['Charlotte Hornets', 'Orlando Magic']
# ['New York Knicks', 'Brooklyn Nets']
# ['Atlanta Hawks', 'Memphis Grizzlies']
# ['Cleveland Cavaliers', 'Minnesota Timberwolves']
# ['Sacramento Kings', 'New Orleans Pelicans']
# ['Boston Celtics', 'Toronto Raptors']
# ['Indiana Pacers', 'Milwaukee Bucks']
# ['Oklahoma City Thunder', 'Los Angeles Clippers']
# ['Golden State Warriors', 'Utah Jazz']
# ['Brooklyn Nets', 'Indiana Pacers']
# ['Toronto Raptors', 'Washington Wizards']
# ['Boston Celtics', 'New York Knicks']
# ['Orlando Magic', 'Philadelphia 76ers']
# ['Detroit Pistons', 'Chicago Bulls']
# ['Charlotte Hornets', 'Miami Heat']
# ['Minnesota Timberwolves', 'Dallas Mavericks']
# ['Phoenix Suns', 'Denver Nuggets']
# ['San Antonio Spurs', 'Portland Trail Blazers']
# ['Houston Rockets', 'Los Angeles Lakers']
# ['Atlanta Hawks', 'Cleveland Cavaliers']
# ['Sacramento Kings', 'Oklahoma City Thunder']
# ['Golden State Warriors', 'Denver Nuggets']
# ['Houston Rockets', 'Los Angeles Clippers']
# ['Orlando Magic', 'Boston Celtics']
# ['Charlotte Hornets', 'Toronto Raptors']
# ['New York Knicks', 'Milwaukee Bucks']
# ['Indiana Pacers', 'Minnesota Timberwolves']
# ['Chicago Bulls', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'Utah Jazz']
# ['Washington Wizards', 'Portland Trail Blazers']
# ['Phoenix Suns', 'Golden State Warriors']
# ['San Antonio Spurs', 'Los Angeles Lakers']
# ['Philadelphia 76ers', 'Detroit Pistons']
# ['Los Angeles Clippers', 'New Orleans Pelicans']
# ['Sacramento Kings', 'Denver Nuggets']
# ['Dallas Mavericks', 'Atlanta Hawks']
# ['Brooklyn Nets', 'Cleveland Cavaliers']
# ['New York Knicks', 'Miami Heat']
# ['Minnesota Timberwolves', 'Toronto Raptors']
# ['Charlotte Hornets', 'Chicago Bulls']
# ['Utah Jazz', 'Houston Rockets']
# ['Indiana Pacers', 'San Antonio Spurs']
# ['Philadelphia 76ers', 'Milwaukee Bucks']
# ['Los Angeles Lakers', 'Phoenix Suns']
# ['Memphis Grizzlies', 'Sacramento Kings']
# ['Washington Wizards', 'Golden State Warriors']
# ['Cleveland Cavaliers', 'Detroit Pistons']
# ['Portland Trail Blazers', 'Orlando Magic']
# ['Boston Celtics', 'Oklahoma City Thunder']
# ['Denver Nuggets', 'Los Angeles Lakers']
# ['Chicago Bulls', 'Charlotte Hornets']
# ['Golden State Warriors', 'New York Knicks']
# ['Dallas Mavericks', 'Toronto Raptors']
# ['Los Angeles Clippers', 'Houston Rockets']
# ['Milwaukee Bucks', 'Minnesota Timberwolves']
# ['Brooklyn Nets', 'New Orleans Pelicans']
# ['Washington Wizards', 'Sacramento Kings']
# ['Boston Celtics', 'Detroit Pistons']
# ['Utah Jazz', 'New Orleans Pelicans']
# ['Chicago Bulls', 'Atlanta Hawks']
# ['Indiana Pacers', 'Cleveland Cavaliers']
# ['Charlotte Hornets', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Memphis Grizzlies']
# ['Portland Trail Blazers', 'Miami Heat']
# ['Orlando Magic', 'Milwaukee Bucks']
# ['Los Angeles Lakers', 'San Antonio Spurs']
# ['Golden State Warriors', 'Brooklyn Nets']
# ['Utah Jazz', 'Dallas Mavericks']
# ['Phoenix Suns', 'Oklahoma City Thunder']
# ['Washington Wizards', 'Los Angeles Clippers']
# ['Portland Trail Blazers', 'Indiana Pacers']
# ['Atlanta Hawks', 'Philadelphia 76ers']
# ['Sacramento Kings', 'Miami Heat']
# ['Brooklyn Nets', 'New York Knicks']
# ['Golden State Warriors', 'Chicago Bulls']
# ['Toronto Raptors', 'Milwaukee Bucks']
# ['Los Angeles Lakers', 'Minnesota Timberwolves']
# ['Dallas Mavericks', 'San Antonio Spurs']
# ['New Orleans Pelicans', 'Denver Nuggets']
# ['Miami Heat', 'Charlotte Hornets']
# ['Atlanta Hawks', 'Cleveland Cavaliers']
# ['Sacramento Kings', 'Orlando Magic']
# ['Detroit Pistons', 'Boston Celtics']
# ['Philadelphia 76ers', 'Toronto Raptors']
# ['Portland Trail Blazers', 'Houston Rockets']
# ['Washington Wizards', 'Memphis Grizzlies']
# ['Los Angeles Clippers', 'Oklahoma City Thunder']
# ['Detroit Pistons', 'Brooklyn Nets']
# ['Denver Nuggets', 'Chicago Bulls']
# ['Utah Jazz', 'Minnesota Timberwolves']
# ['Indiana Pacers', 'New York Knicks']
# ['New Orleans Pelicans', 'Golden State Warriors']
# ['Dallas Mavericks', 'Los Angeles Lakers']
# ['San Antonio Spurs', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Charlotte Hornets']
# ['Denver Nuggets', 'Cleveland Cavaliers']
# ['Los Angeles Clippers', 'Philadelphia 76ers']
# ['Sacramento Kings', 'Atlanta Hawks']
# ['Milwaukee Bucks', 'Boston Celtics']
# ['New Orleans Pelicans', 'Portland Trail Blazers']
# ['Los Angeles Clippers', 'Orlando Magic']
# ['Houston Rockets', 'Brooklyn Nets']
# ['Indiana Pacers', 'Chicago Bulls']
# ['Oklahoma City Thunder', 'Washington Wizards']
# ['New York Knicks', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'Utah Jazz']
# ['Toronto Raptors', 'Phoenix Suns']
# ['Minnesota Timberwolves', 'Golden State Warriors']
# ['Detroit Pistons', 'Philadelphia 76ers']
# ['Cleveland Cavaliers', 'Charlotte Hornets']
# ['Boston Celtics', 'Indiana Pacers']
# ['Miami Heat', 'Atlanta Hawks']
# ['Houston Rockets', 'Chicago Bulls']
# ['New Orleans Pelicans', 'San Antonio Spurs']
# ['Utah Jazz', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Portland Trail Blazers']
# ['Sacramento Kings', 'Milwaukee Bucks']
# ['Philadelphia 76ers', 'Brooklyn Nets']
# ['New York Knicks', 'Washington Wizards']
# ['Orlando Magic', 'San Antonio Spurs']
# ['Memphis Grizzlies', 'Phoenix Suns']
# ['Minnesota Timberwolves', 'Portland Trail Blazers']
# ['Toronto Raptors', 'Los Angeles Lakers']
# ['Miami Heat', 'Detroit Pistons']
# ['Houston Rockets', 'Indiana Pacers']
# ['Cleveland Cavaliers', 'Orlando Magic']
# ['Chicago Bulls', 'New York Knicks']
# ['New Orleans Pelicans', 'Oklahoma City Thunder']
# ['Boston Celtics', 'Denver Nuggets']
# ['Toronto Raptors', 'Utah Jazz']
# ['Memphis Grizzlies', 'Golden State Warriors']
# ['Minnesota Timberwolves', 'Los Angeles Clippers']
# ['Atlanta Hawks', 'Charlotte Hornets']
# ['Washington Wizards', 'Dallas Mavericks']
# ['Brooklyn Nets', 'Phoenix Suns']
# ['Milwaukee Bucks', 'Portland Trail Blazers']
# ['Oklahoma City Thunder', 'Cleveland Cavaliers']
# ['Detroit Pistons', 'Orlando Magic']
# ['New York Knicks', 'Atlanta Hawks']
# ['San Antonio Spurs', 'Miami Heat']
# ['Philadelphia 76ers', 'Indiana Pacers']
# ['Denver Nuggets', 'Memphis Grizzlies']
# ['Chicago Bulls', 'New Orleans Pelicans']
# ['Dallas Mavericks', 'Utah Jazz']
# ['Toronto Raptors', 'Sacramento Kings']
# ['Minnesota Timberwolves', 'Los Angeles Lakers']
# ['Houston Rockets', 'Oklahoma City Thunder']
# ['Boston Celtics', 'Phoenix Suns']
# ['Los Angeles Clippers', 'Portland Trail Blazers']
# ['Milwaukee Bucks', 'Golden State Warriors']
# ['Washington Wizards', 'Orlando Magic']
# ['Charlotte Hornets', 'Philadelphia 76ers']
# ['Detroit Pistons', 'Atlanta Hawks']
# ['Indiana Pacers', 'Miami Heat']
# ['Brooklyn Nets', 'Denver Nuggets']
# ['Boston Celtics', 'Utah Jazz']
# ['Minnesota Timberwolves', 'Sacramento Kings']
# ['New York Knicks', 'Toronto Raptors']
# ['Milwaukee Bucks', 'Los Angeles Clippers']
# ['Phoenix Suns', 'New Orleans Pelicans']
# ['Cleveland Cavaliers', 'Chicago Bulls']
# ['Philadelphia 76ers', 'Memphis Grizzlies']
# ['Washington Wizards', 'Miami Heat']
# ['Brooklyn Nets', 'Golden State Warriors']
# ['Houston Rockets', 'San Antonio Spurs']
# ['Oklahoma City Thunder', 'Dallas Mavericks']
# ['Los Angeles Lakers', 'Sacramento Kings']
# ['Charlotte Hornets', 'Detroit Pistons']
# ['Indiana Pacers', 'Houston Rockets']
# ['Orlando Magic', 'New York Knicks']
# ['Milwaukee Bucks', 'Denver Nuggets']
# ['Boston Celtics', 'Portland Trail Blazers']
# ['Atlanta Hawks', 'Los Angeles Lakers']
# ['Orlando Magic', 'Washington Wizards']
# ['Philadelphia 76ers', 'Miami Heat']
# ['New Orleans Pelicans', 'Toronto Raptors']
# ['Dallas Mavericks', 'Chicago Bulls']
# ['Utah Jazz', 'Memphis Grizzlies']
# ['Brooklyn Nets', 'Minnesota Timberwolves']
# ['Phoenix Suns', 'Oklahoma City Thunder']
# ['San Antonio Spurs', 'Sacramento Kings']
# ['Golden State Warriors', 'Los Angeles Clippers']
# ['Charlotte Hornets', 'Cleveland Cavaliers']
# ['Houston Rockets', 'Denver Nuggets']
# ['Atlanta Hawks', 'Golden State Warriors']
# ['Philadelphia 76ers', 'Orlando Magic']
# ['Cleveland Cavaliers', 'Washington Wizards']
# ['Chicago Bulls', 'Boston Celtics']
# ['Miami Heat', 'Brooklyn Nets']
# ['Detroit Pistons', 'Toronto Raptors']
# ['Memphis Grizzlies', 'Milwaukee Bucks']
# ['New Orleans Pelicans', 'Minnesota Timberwolves']
# ['New York Knicks', 'Oklahoma City Thunder']
# ['Utah Jazz', 'Dallas Mavericks']
# ['San Antonio Spurs', 'Phoenix Suns']
# ['Portland Trail Blazers', 'Los Angeles Lakers']
# ['Golden State Warriors', 'Houston Rockets']
# ['Atlanta Hawks', 'Denver Nuggets']
# ['San Antonio Spurs', 'Los Angeles Clippers']
# ['Toronto Raptors', 'Boston Celtics']
# ['Miami Heat', 'Indiana Pacers']
# ['Utah Jazz', 'Philadelphia 76ers']
# ['Brooklyn Nets', 'Washington Wizards']
# ['Sacramento Kings', 'Memphis Grizzlies']
# ['Portland Trail Blazers', 'Minnesota Timberwolves']
# ['New York Knicks', 'New Orleans Pelicans']
# ['Chicago Bulls', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'Brooklyn Nets']
# ['Philadelphia 76ers', 'Charlotte Hornets']
# ['Atlanta Hawks', 'Indiana Pacers']
# ['Denver Nuggets', 'New Orleans Pelicans']
# ['Los Angeles Lakers', 'Orlando Magic']
# ['Utah Jazz', 'Boston Celtics']
# ['Toronto Raptors', 'Chicago Bulls']
# ['Sacramento Kings', 'Houston Rockets']
# ['Golden State Warriors', 'Dallas Mavericks']
# ['Oklahoma City Thunder', 'Phoenix Suns']
# ['Memphis Grizzlies', 'Minnesota Timberwolves']
# ['Los Angeles Lakers', 'Miami Heat']
# ['New York Knicks', 'Orlando Magic']
# ['Portland Trail Blazers', 'Washington Wizards']
# ['Golden State Warriors', 'San Antonio Spurs']
# ['Boston Celtics', 'Charlotte Hornets']
# ['Cleveland Cavaliers', 'Detroit Pistons']
# ['Utah Jazz', 'Indiana Pacers']
# ['Phoenix Suns', 'Philadelphia 76ers']
# ['Los Angeles Clippers', 'Atlanta Hawks']
# ['Dallas Mavericks', 'Memphis Grizzlies']
# ['Denver Nuggets', 'Milwaukee Bucks']
# ['San Antonio Spurs', 'New Orleans Pelicans']
# ['Oklahoma City Thunder', 'Sacramento Kings']
# ['Toronto Raptors', 'Orlando Magic']
# ['Los Angeles Clippers', 'Washington Wizards']
# ['Brooklyn Nets', 'Miami Heat']
# ['Portland Trail Blazers', 'New York Knicks']
# ['Indiana Pacers', 'Charlotte Hornets']
# ['New Orleans Pelicans', 'Philadelphia 76ers']
# ['Toronto Raptors', 'Atlanta Hawks']
# ['New York Knicks', 'Boston Celtics']
# ['Phoenix Suns', 'Chicago Bulls']
# ['Los Angeles Lakers', 'Cleveland Cavaliers']
# ['Detroit Pistons', 'Houston Rockets']
# ['Portland Trail Blazers', 'Milwaukee Bucks']
# ['Denver Nuggets', 'Minnesota Timberwolves']
# ['Brooklyn Nets', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'San Antonio Spurs']
# ['Sacramento Kings', 'Utah Jazz']
# ['Oklahoma City Thunder', 'Golden State Warriors']
# ['Minnesota Timberwolves', 'Brooklyn Nets']
# ['Memphis Grizzlies', 'Los Angeles Clippers']
# ['Houston Rockets', 'Detroit Pistons']
# ['Boston Celtics', 'Atlanta Hawks']
# ['New Orleans Pelicans', 'New York Knicks']
# ['Cleveland Cavaliers', 'Philadelphia 76ers']
# ['Washington Wizards', 'Toronto Raptors']
# ['Miami Heat', 'Chicago Bulls']
# ['San Antonio Spurs', 'Indiana Pacers']
# ['Charlotte Hornets', 'Oklahoma City Thunder']
# ['Phoenix Suns', 'Milwaukee Bucks']
# ['Orlando Magic', 'Denver Nuggets']
# ['Portland Trail Blazers', 'Golden State Warriors']
# ['Utah Jazz', 'Los Angeles Lakers']
# ['Houston Rockets', 'Cleveland Cavaliers']
# ['Chicago Bulls', 'Minnesota Timberwolves']
# ['Denver Nuggets', 'Oklahoma City Thunder']
# ['New Orleans Pelicans', 'Washington Wizards']
# ['Boston Celtics', 'Dallas Mavericks']
# ['Sacramento Kings', 'Golden State Warriors']
# ['San Antonio Spurs', 'Milwaukee Bucks']
# ['Orlando Magic', 'Los Angeles Lakers']
# ['Phoenix Suns', 'Detroit Pistons']
# ['Charlotte Hornets', 'Atlanta Hawks']
# ['Philadelphia 76ers', 'Brooklyn Nets']
# ['New York Knicks', 'Memphis Grizzlies']
# ['Miami Heat', 'Toronto Raptors']
# ['Utah Jazz', 'Sacramento Kings']
# ['Los Angeles Clippers', 'Portland Trail Blazers']
# ['Milwaukee Bucks', 'Charlotte Hornets']
# ['Minnesota Timberwolves', 'Cleveland Cavaliers']
# ['Houston Rockets', 'Washington Wizards']
# ['San Antonio Spurs', 'Chicago Bulls']
# ['Boston Celtics', 'New Orleans Pelicans']
# ['Indiana Pacers', 'Utah Jazz']
# ['Orlando Magic', 'Golden State Warriors']
# ['New York Knicks', 'Detroit Pistons']
# ['Atlanta Hawks', 'Miami Heat']
# ['Toronto Raptors', 'Memphis Grizzlies']
# ['Los Angeles Lakers', 'Denver Nuggets']
# ['Indiana Pacers', 'Phoenix Suns']
# ['Atlanta Hawks', 'Charlotte Hornets']
# ['New York Knicks', 'Philadelphia 76ers']
# ['Utah Jazz', 'Brooklyn Nets']
# ['Dallas Mavericks', 'Houston Rockets']
# ['Chicago Bulls', 'Milwaukee Bucks']
# ['San Antonio Spurs', 'Minnesota Timberwolves']
# ['Washington Wizards', 'New Orleans Pelicans']
# ['Cleveland Cavaliers', 'Oklahoma City Thunder']
# ['Orlando Magic', 'Portland Trail Blazers']
# ['Phoenix Suns', 'Los Angeles Clippers']
# ['Golden State Warriors', 'Toronto Raptors']
# ['Indiana Pacers', 'Los Angeles Lakers']
# ['Los Angeles Clippers', 'Sacramento Kings']
# ['Cleveland Cavaliers', 'Boston Celtics']
# ['Utah Jazz', 'Charlotte Hornets']
# ['Chicago Bulls', 'Detroit Pistons']
# ['Washington Wizards', 'Philadelphia 76ers']
# ['Memphis Grizzlies', 'Brooklyn Nets']
# ['New Orleans Pelicans', 'Miami Heat']
# ['Atlanta Hawks', 'Oklahoma City Thunder']
# ['Houston Rockets', 'San Antonio Spurs']
# ['Orlando Magic', 'Phoenix Suns']
# ['Dallas Mavericks', 'Los Angeles Lakers']
# ['Denver Nuggets', 'Portland Trail Blazers']
# ['Milwaukee Bucks', 'New York Knicks']
# ['Golden State Warriors', 'Detroit Pistons']
# ['Brooklyn Nets', 'Washington Wizards']
# ['Toronto Raptors', 'Cleveland Cavaliers']
# ['Chicago Bulls', 'Houston Rockets']
# ['Boston Celtics', 'Minnesota Timberwolves']
# ['Indiana Pacers', 'Sacramento Kings']
# ['Phoenix Suns', 'Los Angeles Lakers']
# ['New Orleans Pelicans', 'Charlotte Hornets']
# ['Utah Jazz', 'Miami Heat']
# ['Memphis Grizzlies', 'Philadelphia 76ers']
# ['Los Angeles Clippers', 'Dallas Mavericks']
# ['Portland Trail Blazers', 'San Antonio Spurs']
# ['Oklahoma City Thunder', 'Detroit Pistons']
# ['Golden State Warriors', 'Atlanta Hawks']
# ['Cleveland Cavaliers', 'Brooklyn Nets']
# ['Washington Wizards', 'New York Knicks']
# ['Denver Nuggets', 'Toronto Raptors']
# ['Houston Rockets', 'Minnesota Timberwolves']
# ['Los Angeles Clippers', 'New Orleans Pelicans']
# ['Chicago Bulls', 'Indiana Pacers']
# ['Orlando Magic', 'Miami Heat']
# ['Portland Trail Blazers', 'Dallas Mavericks']
# ['Sacramento Kings', 'Phoenix Suns']
# ['San Antonio Spurs', 'Utah Jazz']
# ['Golden State Warriors', 'Cleveland Cavaliers']
# ['Denver Nuggets', 'Orlando Magic']
# ['Washington Wizards', 'Atlanta Hawks']
# ['Oklahoma City Thunder', 'Brooklyn Nets']
# ['Los Angeles Clippers', 'Memphis Grizzlies']
# ['Detroit Pistons', 'Milwaukee Bucks']
# ['Charlotte Hornets', 'Minnesota Timberwolves']
# ['Dallas Mavericks', 'New Orleans Pelicans']
# ['Philadelphia 76ers', 'Toronto Raptors']
# ['San Antonio Spurs', 'Los Angeles Lakers']
# ['New York Knicks', 'Boston Celtics']
# ['Phoenix Suns', 'Portland Trail Blazers']
# ['Houston Rockets', 'Utah Jazz']
# ['Denver Nuggets', 'Charlotte Hornets']
# ['Philadelphia 76ers', 'Detroit Pistons']
# ['Indiana Pacers', 'Orlando Magic']
# ['Toronto Raptors', 'Brooklyn Nets']
# ['Sacramento Kings', 'Cleveland Cavaliers']
# ['Oklahoma City Thunder', 'Chicago Bulls']
# ['Memphis Grizzlies', 'New Orleans Pelicans']
# ['Los Angeles Lakers', 'San Antonio Spurs']
# ['Miami Heat', 'Phoenix Suns']
# ['Golden State Warriors', 'Milwaukee Bucks']
# ['Houston Rockets', 'Dallas Mavericks']
# ['Sacramento Kings', 'Indiana Pacers']
# ['Denver Nuggets', 'Atlanta Hawks']
# ['Washington Wizards', 'Cleveland Cavaliers']
# ['Brooklyn Nets', 'New York Knicks']
# ['Boston Celtics', 'Chicago Bulls']
# ['Los Angeles Lakers', 'Memphis Grizzlies']
# ['Minnesota Timberwolves', 'Portland Trail Blazers']
# ['Miami Heat', 'Los Angeles Clippers']
# ['New Orleans Pelicans', 'Detroit Pistons']
# ['Milwaukee Bucks', 'Toronto Raptors']
# ['Utah Jazz', 'San Antonio Spurs']
# ['Charlotte Hornets', 'New York Knicks']
# ['Washington Wizards', 'Indiana Pacers']
# ['Detroit Pistons', 'Philadelphia 76ers']
# ['New Orleans Pelicans', 'Boston Celtics']
# ['Sacramento Kings', 'Chicago Bulls']
# ['Cleveland Cavaliers', 'Milwaukee Bucks']
# ['Utah Jazz', 'Oklahoma City Thunder']
# ['Orlando Magic', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'Denver Nuggets']
# ['Los Angeles Clippers', 'Phoenix Suns']
# ['Minnesota Timberwolves', 'Golden State Warriors']
# ['Miami Heat', 'Los Angeles Lakers']
# ['Portland Trail Blazers', 'Houston Rockets']
# ['Phoenix Suns', 'San Antonio Spurs']
# ['Toronto Raptors', 'Los Angeles Clippers']
# ['Detroit Pistons', 'Charlotte Hornets']
# ['New York Knicks', 'Cleveland Cavaliers']
# ['Milwaukee Bucks', 'Indiana Pacers']
# ['Brooklyn Nets', 'Philadelphia 76ers']
# ['Boston Celtics', 'Washington Wizards']
# ['Portland Trail Blazers', 'Memphis Grizzlies']
# ['Oklahoma City Thunder', 'New Orleans Pelicans']
# ['Atlanta Hawks', 'Dallas Mavericks']
# ['Miami Heat', 'Utah Jazz']
# ['Minnesota Timberwolves', 'Sacramento Kings']
# ['Toronto Raptors', 'Golden State Warriors']
# ['Los Angeles Lakers', 'Houston Rockets']
# ['Los Angeles Clippers', 'San Antonio Spurs']
# ['Chicago Bulls', 'Orlando Magic']
# ['Dallas Mavericks', 'Phoenix Suns']
# ['Atlanta Hawks', 'Boston Celtics']
# ['New York Knicks', 'Charlotte Hornets']
# ['Washington Wizards', 'Brooklyn Nets']
# ['Milwaukee Bucks', 'Cleveland Cavaliers']
# ['Indiana Pacers', 'Philadelphia 76ers']
# ['Miami Heat', 'Memphis Grizzlies']
# ['Oklahoma City Thunder', 'Denver Nuggets']
# ['Toronto Raptors', 'Portland Trail Blazers']
# ['Golden State Warriors', 'Sacramento Kings']
# ['Utah Jazz', 'Orlando Magic']
# ['Los Angeles Lakers', 'Charlotte Hornets']
# ['Boston Celtics', 'Detroit Pistons']
# ['Houston Rockets', 'Memphis Grizzlies']
# ['Chicago Bulls', 'San Antonio Spurs']
# ['Los Angeles Clippers', 'Oklahoma City Thunder']
# ['Minnesota Timberwolves', 'Phoenix Suns']
# ['Atlanta Hawks', 'Brooklyn Nets']
# ['Philadelphia 76ers', 'Cleveland Cavaliers']
# ['New York Knicks', 'Indiana Pacers']
# ['Los Angeles Lakers', 'Washington Wizards']
# ['Sacramento Kings', 'Dallas Mavericks']
# ['Miami Heat', 'New Orleans Pelicans']
# ['Toronto Raptors', 'Denver Nuggets']
# ['Milwaukee Bucks', 'Detroit Pistons']
# ['Phoenix Suns', 'New York Knicks']
# ['Utah Jazz', 'Houston Rockets']
# ['Sacramento Kings', 'Minnesota Timberwolves']
# ['Chicago Bulls', 'Oklahoma City Thunder']
# ['Philadelphia 76ers', 'San Antonio Spurs']
# ['Memphis Grizzlies', 'Golden State Warriors']
# ['Portland Trail Blazers', 'Los Angeles Clippers']
# ['Cleveland Cavaliers', 'Indiana Pacers']
# ['Washington Wizards', 'Atlanta Hawks']
# ['Los Angeles Lakers', 'Brooklyn Nets']
# ['Dallas Mavericks', 'Denver Nuggets']
# ['Cleveland Cavaliers', 'Charlotte Hornets']
# ['San Antonio Spurs', 'Orlando Magic']
# ['New York Knicks', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Boston Celtics']
# ['Indiana Pacers', 'Toronto Raptors']
# ['Brooklyn Nets', 'Chicago Bulls']
# ['Washington Wizards', 'Houston Rockets']
# ['New Orleans Pelicans', 'Milwaukee Bucks']
# ['Detroit Pistons', 'Minnesota Timberwolves']
# ['Golden State Warriors', 'Utah Jazz']
# ['Memphis Grizzlies', 'Portland Trail Blazers']
# ['Oklahoma City Thunder', 'Sacramento Kings']
# ['Houston Rockets', 'Miami Heat']
# ['Dallas Mavericks', 'Los Angeles Clippers']
# ['Detroit Pistons', 'Charlotte Hornets']
# ['Cleveland Cavaliers', 'Toronto Raptors']
# ['Indiana Pacers', 'Brooklyn Nets']
# ['Atlanta Hawks', 'New York Knicks']
# ['Milwaukee Bucks', 'Boston Celtics']
# ['Orlando Magic', 'Chicago Bulls']
# ['Minnesota Timberwolves', 'San Antonio Spurs']
# ['Utah Jazz', 'Portland Trail Blazers']
# ['Memphis Grizzlies', 'Sacramento Kings']
# ['New Orleans Pelicans', 'Los Angeles Lakers']
# ['Denver Nuggets', 'Los Angeles Clippers']
# ['Phoenix Suns', 'Washington Wizards']
# ['Toronto Raptors', 'Philadelphia 76ers']
# ['San Antonio Spurs', 'Houston Rockets']
# ['Milwaukee Bucks', 'Miami Heat']
# ['Dallas Mavericks', 'Golden State Warriors']
# ['Oklahoma City Thunder', 'Utah Jazz']
# ['Atlanta Hawks', 'Detroit Pistons']
# ['Washington Wizards', 'Indiana Pacers']
# ['Charlotte Hornets', 'Boston Celtics']
# ['Phoenix Suns', 'Brooklyn Nets']
# ['Chicago Bulls', 'Cleveland Cavaliers']
# ['Miami Heat', 'Orlando Magic']
# ['New Orleans Pelicans', 'Sacramento Kings']
# ['Minnesota Timberwolves', 'Oklahoma City Thunder']
# ['Los Angeles Clippers', 'Golden State Warriors']
# ['Dallas Mavericks', 'Portland Trail Blazers']
# ['Memphis Grizzlies', 'Los Angeles Lakers']
# ['Milwaukee Bucks', 'New York Knicks']
# ['Oklahoma City Thunder', 'Houston Rockets']
# ['Philadelphia 76ers', 'Boston Celtics']
# ['Los Angeles Lakers', 'Golden State Warriors']
# ['Portland Trail Blazers', 'Utah Jazz']
# ['Washington Wizards', 'Detroit Pistons']
# ['Phoenix Suns', 'Orlando Magic']
# ['Indiana Pacers', 'Atlanta Hawks']
# ['Charlotte Hornets', 'Brooklyn Nets']
# ['Toronto Raptors', 'Miami Heat']
# ['Minnesota Timberwolves', 'Chicago Bulls']
# ['Cleveland Cavaliers', 'Memphis Grizzlies']
# ['New Orleans Pelicans', 'Dallas Mavericks']
# ['Denver Nuggets', 'San Antonio Spurs']
# ['Sacramento Kings', 'Los Angeles Clippers']
# ['Boston Celtics', 'Houston Rockets']
# ['New York Knicks', 'Milwaukee Bucks']
# ['Los Angeles Lakers', 'Sacramento Kings']
# ['Portland Trail Blazers', 'Golden State Warriors']
# ['Philadelphia 76ers', 'Utah Jazz']
# ['Brooklyn Nets', 'Charlotte Hornets']
# ['Detroit Pistons', 'Indiana Pacers']
# ['Toronto Raptors', 'Orlando Magic']
# ['Chicago Bulls', 'Washington Wizards']
# ['Cleveland Cavaliers', 'Miami Heat']
# ['Atlanta Hawks', 'Minnesota Timberwolves']
# ['Dallas Mavericks', 'New Orleans Pelicans']
# ['San Antonio Spurs', 'Denver Nuggets']
# ['Oklahoma City Thunder', 'Phoenix Suns']
# ['Los Angeles Clippers', 'Los Angeles Lakers']
# ['Brooklyn Nets', 'Milwaukee Bucks']
# ['Houston Rockets', 'New Orleans Pelicans']
# ['Charlotte Hornets', 'Washington Wizards']
# ['Cleveland Cavaliers', 'Atlanta Hawks']
# ['Boston Celtics', 'Memphis Grizzlies']
# ['New York Knicks', 'Utah Jazz']
# ['Denver Nuggets', 'Phoenix Suns']
# ['Golden State Warriors', 'Portland Trail Blazers']
# ['San Antonio Spurs', 'Los Angeles Clippers']
# ['Detroit Pistons', 'Orlando Magic']
# ['Minnesota Timberwolves', 'Miami Heat']
# ['Chicago Bulls', 'Toronto Raptors']
# ['Oklahoma City Thunder', 'Dallas Mavericks']
# ['Philadelphia 76ers', 'Portland Trail Blazers']
# ['Sacramento Kings', 'Los Angeles Lakers']
# ['Atlanta Hawks', 'Indiana Pacers']
# ['Orlando Magic', 'Charlotte Hornets']
# ['Memphis Grizzlies', 'Houston Rockets']
# ['Boston Celtics', 'San Antonio Spurs']
# ['Minnesota Timberwolves', 'New Orleans Pelicans']
# ['Dallas Mavericks', 'Oklahoma City Thunder']
# ['Golden State Warriors', 'Phoenix Suns']
# ['Utah Jazz', 'Toronto Raptors']
# ['Detroit Pistons', 'Milwaukee Bucks']
# ['New York Knicks', 'Denver Nuggets']
# ['Portland Trail Blazers', 'Sacramento Kings']
# ['Philadelphia 76ers', 'Los Angeles Clippers']
# ['Dallas Mavericks', 'Charlotte Hornets']
# ['Miami Heat', 'Cleveland Cavaliers']
# ['Atlanta Hawks', 'Washington Wizards']
# ['New Orleans Pelicans', 'Brooklyn Nets']
# ['Minnesota Timberwolves', 'Boston Celtics']
# ['Orlando Magic', 'Chicago Bulls']
# ['Detroit Pistons', 'Memphis Grizzlies']
# ['Philadelphia 76ers', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Los Angeles Lakers']
# ['Toronto Raptors', 'San Antonio Spurs']
# ['Denver Nuggets', 'Sacramento Kings']
# ['Houston Rockets', 'Golden State Warriors']
# ['Utah Jazz', 'Cleveland Cavaliers']
# ['Dallas Mavericks', 'Boston Celtics']
# ['Indiana Pacers', 'Chicago Bulls']
# ['Brooklyn Nets', 'Memphis Grizzlies']
# ['Washington Wizards', 'Miami Heat']
# ['Orlando Magic', 'Minnesota Timberwolves']
# ['Atlanta Hawks', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'Phoenix Suns']
# ['New York Knicks', 'Los Angeles Lakers']
# ['Oklahoma City Thunder', 'Portland Trail Blazers']
# ['Charlotte Hornets', 'Denver Nuggets']
# ['Utah Jazz', 'Detroit Pistons']
# ['Dallas Mavericks', 'Philadelphia 76ers']
# ['New Orleans Pelicans', 'Cleveland Cavaliers']
# ['Toronto Raptors', 'Milwaukee Bucks']
# ['Memphis Grizzlies', 'San Antonio Spurs']
# ['Houston Rockets', 'Portland Trail Blazers']
# ['Golden State Warriors', 'Sacramento Kings']
# ['Brooklyn Nets', 'Chicago Bulls']
# ['Orlando Magic', 'Los Angeles Clippers']
# ['Los Angeles Lakers', 'Minnesota Timberwolves']
# ['Miami Heat', 'Atlanta Hawks']
# ['Washington Wizards', 'Oklahoma City Thunder']
# ['Indiana Pacers', 'Toronto Raptors']
# ['Charlotte Hornets', 'Phoenix Suns']
# ['San Antonio Spurs', 'Detroit Pistons']
# ['Brooklyn Nets', 'Boston Celtics']
# ['Denver Nuggets', 'Houston Rockets']
# ['Utah Jazz', 'Milwaukee Bucks']
# ['Memphis Grizzlies', 'New Orleans Pelicans']
# ['Los Angeles Lakers', 'Dallas Mavericks']
# ['New York Knicks', 'Portland Trail Blazers']
# ['Orlando Magic', 'Sacramento Kings']
# ['Indiana Pacers', 'Cleveland Cavaliers']
# ['Washington Wizards', 'Philadelphia 76ers']
# ['Denver Nuggets', 'Miami Heat']
# ['Atlanta Hawks', 'Toronto Raptors']
# ['Minnesota Timberwolves', 'Oklahoma City Thunder']
# ['Sacramento Kings', 'Phoenix Suns']
# ['New York Knicks', 'Golden State Warriors']
# ['Charlotte Hornets', 'Los Angeles Clippers']
# ['Indiana Pacers', 'Boston Celtics']
# ['Philadelphia 76ers', 'Washington Wizards']
# ['Atlanta Hawks', 'Brooklyn Nets']
# ['Milwaukee Bucks', 'Houston Rockets']
# ['San Antonio Spurs', 'Memphis Grizzlies']
# ['Cleveland Cavaliers', 'New Orleans Pelicans']
# ['Phoenix Suns', 'Dallas Mavericks']
# ['Orlando Magic', 'Utah Jazz']
# ['Chicago Bulls', 'Portland Trail Blazers']
# ['Detroit Pistons', 'Los Angeles Lakers']
# ['Boston Celtics', 'Miami Heat']
# ['Los Angeles Clippers', 'Denver Nuggets']
# ['Oklahoma City Thunder', 'San Antonio Spurs']
# ['Detroit Pistons', 'Sacramento Kings']
# ['Atlanta Hawks', 'Philadelphia 76ers']
# ['Milwaukee Bucks', 'Washington Wizards']
# ['Indiana Pacers', 'New York Knicks']
# ['Brooklyn Nets', 'Toronto Raptors']
# ['Cleveland Cavaliers', 'Houston Rockets']
# ['Dallas Mavericks', 'Minnesota Timberwolves']
# ['Charlotte Hornets', 'Portland Trail Blazers']
# ['Los Angeles Lakers', 'Utah Jazz']
# ['Chicago Bulls', 'Golden State Warriors']
# ['Detroit Pistons', 'Los Angeles Clippers']
# ['Memphis Grizzlies', 'Miami Heat']
# ['Boston Celtics', 'Orlando Magic']
# ['New Orleans Pelicans', 'Minnesota Timberwolves']
# ['San Antonio Spurs', 'Oklahoma City Thunder']
# ['Denver Nuggets', 'Phoenix Suns']
# ['Charlotte Hornets', 'Sacramento Kings']
# ['Chicago Bulls', 'Utah Jazz']
# ['Philadelphia 76ers', 'New York Knicks']
# ['Toronto Raptors', 'Washington Wizards']
# ['Milwaukee Bucks', 'Atlanta Hawks']
# ['Houston Rockets', 'Orlando Magic']
# ['Golden State Warriors', 'Dallas Mavericks']
# ['Portland Trail Blazers', 'Denver Nuggets']
# ['Cleveland Cavaliers', 'Los Angeles Lakers']
# ['Boston Celtics', 'Brooklyn Nets']
# ['Memphis Grizzlies', 'Houston Rockets']
# ['Charlotte Hornets', 'San Antonio Spurs']
# ['Detroit Pistons', 'Utah Jazz']
# ['Portland Trail Blazers', 'Sacramento Kings']
# ['New Orleans Pelicans', 'Los Angeles Clippers']
# ['Phoenix Suns', 'Indiana Pacers']
# ['Minnesota Timberwolves', 'Philadelphia 76ers']
# ['Oklahoma City Thunder', 'Atlanta Hawks']
# ['Miami Heat', 'Milwaukee Bucks']
# ['Golden State Warriors', 'Denver Nuggets']
# ['Chicago Bulls', 'Los Angeles Lakers']
# ['Orlando Magic', 'Detroit Pistons']
# ['Toronto Raptors', 'Boston Celtics']
# ['Brooklyn Nets', 'Houston Rockets']
# ['Milwaukee Bucks', 'Memphis Grizzlies']
# ['San Antonio Spurs', 'Dallas Mavericks']
# ['Cleveland Cavaliers', 'Portland Trail Blazers']
# ['New Orleans Pelicans', 'Golden State Warriors']
# ['Utah Jazz', 'Los Angeles Clippers']
# ['New York Knicks', 'Washington Wizards']
# ['Sacramento Kings', 'Charlotte Hornets']
# ['Philadelphia 76ers', 'Indiana Pacers']
# ['Phoenix Suns', 'Toronto Raptors']
# ['Chicago Bulls', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Oklahoma City Thunder']
# ['Memphis Grizzlies', 'Boston Celtics']
# ['Miami Heat', 'Detroit Pistons']
# ['Brooklyn Nets', 'Orlando Magic']
# ['San Antonio Spurs', 'Minnesota Timberwolves']
# ['Cleveland Cavaliers', 'Utah Jazz']
# ['Golden State Warriors', 'Los Angeles Clippers']
# ['New Orleans Pelicans', 'Portland Trail Blazers']
# ['Oklahoma City Thunder', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Charlotte Hornets']
# ['Sacramento Kings', 'Detroit Pistons']
# ['Dallas Mavericks', 'Indiana Pacers']
# ['Milwaukee Bucks', 'Orlando Magic']
# ['Boston Celtics', 'Atlanta Hawks']
# ['Memphis Grizzlies', 'Toronto Raptors']
# ['Miami Heat', 'Chicago Bulls']
# ['Los Angeles Lakers', 'Houston Rockets']
# ['Cleveland Cavaliers', 'Denver Nuggets']
# ['Charlotte Hornets', 'Indiana Pacers']
# ['Phoenix Suns', 'Minnesota Timberwolves']
# ['Los Angeles Clippers', 'San Antonio Spurs']
# ['Oklahoma City Thunder', 'New York Knicks']
# ['Chicago Bulls', 'Cleveland Cavaliers']
# ['Dallas Mavericks', 'Milwaukee Bucks']
# ['Detroit Pistons', 'Washington Wizards']
# ['Orlando Magic', 'Atlanta Hawks']
# ['Sacramento Kings', 'Brooklyn Nets']
# ['New Orleans Pelicans', 'Memphis Grizzlies']
# ['Miami Heat', 'Boston Celtics']
# ['Houston Rockets', 'Philadelphia 76ers']
# ['Portland Trail Blazers', 'Utah Jazz']
# ['Golden State Warriors', 'Los Angeles Lakers']
# ['Sacramento Kings', 'Toronto Raptors']
# ['Portland Trail Blazers', 'Oklahoma City Thunder']
# ['Los Angeles Clippers', 'Dallas Mavericks']
# ['Minnesota Timberwolves', 'Phoenix Suns']
# ['Toronto Raptors', 'Indiana Pacers']
# ['Cleveland Cavaliers', 'Boston Celtics']
# ['Orlando Magic', 'Brooklyn Nets']
# ['Los Angeles Clippers', 'Miami Heat']
# ['Houston Rockets', 'New York Knicks']
# ['Atlanta Hawks', 'Chicago Bulls']
# ['Charlotte Hornets', 'Memphis Grizzlies']
# ['Detroit Pistons', 'New Orleans Pelicans']
# ['San Antonio Spurs', 'Philadelphia 76ers']
# ['Denver Nuggets', 'Utah Jazz']
# ['New Orleans Pelicans', 'Oklahoma City Thunder']
# ['Golden State Warriors', 'Washington Wizards']
# ['Portland Trail Blazers', 'Phoenix Suns']
# ['Minnesota Timberwolves', 'Los Angeles Lakers']
# ['Washington Wizards', 'Orlando Magic']
# ['New York Knicks', 'Brooklyn Nets']
# ['Miami Heat', 'Cleveland Cavaliers']
# ['Los Angeles Clippers', 'Chicago Bulls']
# ['Toronto Raptors', 'Houston Rockets']
# ['Sacramento Kings', 'Memphis Grizzlies']
# ['Detroit Pistons', 'Dallas Mavericks']
# ['Charlotte Hornets', 'Milwaukee Bucks']
# ['Phoenix Suns', 'Denver Nuggets']
# ['Minnesota Timberwolves', 'Utah Jazz']
# ['San Antonio Spurs', 'New Orleans Pelicans']
# ['Indiana Pacers', 'Memphis Grizzlies']
# ['Golden State Warriors', 'Boston Celtics']
# ['Philadelphia 76ers', 'Denver Nuggets']
# ['Atlanta Hawks', 'Portland Trail Blazers']
# ['Cleveland Cavaliers', 'Chicago Bulls']
# ['Sacramento Kings', 'Los Angeles Clippers']
# ['Milwaukee Bucks', 'Oklahoma City Thunder']
# ['Toronto Raptors', 'Dallas Mavericks']
# ['Orlando Magic', 'Houston Rockets']
# ['Utah Jazz', 'Minnesota Timberwolves']
# ['Washington Wizards', 'San Antonio Spurs']
# ['Miami Heat', 'New York Knicks']
# ['Phoenix Suns', 'Los Angeles Lakers']
# ['New York Knicks', 'Charlotte Hornets']
# ['Golden State Warriors', 'Indiana Pacers']
# ['Brooklyn Nets', 'Boston Celtics']
# ['Denver Nuggets', 'Memphis Grizzlies']
# ['Atlanta Hawks', 'Los Angeles Clippers']
# ['Washington Wizards', 'Cleveland Cavaliers']
# ['Milwaukee Bucks', 'Detroit Pistons']
# ['Oklahoma City Thunder', 'Orlando Magic']
# ['Chicago Bulls', 'Brooklyn Nets']
# ['New Orleans Pelicans', 'Houston Rockets']
# ['Phoenix Suns', 'San Antonio Spurs']
# ['Philadelphia 76ers', 'Los Angeles Lakers']
# ['Charlotte Hornets', 'Boston Celtics']
# ['Chicago Bulls', 'Miami Heat']
# ['Dallas Mavericks', 'New York Knicks']
# ['Memphis Grizzlies', 'Minnesota Timberwolves']
# ['Denver Nuggets', 'New Orleans Pelicans']
# ['Indiana Pacers', 'Washington Wizards']
# ['Atlanta Hawks', 'Sacramento Kings']
# ['Utah Jazz', 'Portland Trail Blazers']
# ['Dallas Mavericks', 'Detroit Pistons']
# ['Indiana Pacers', 'Orlando Magic']
# ['Milwaukee Bucks', 'Toronto Raptors']
# ['Brooklyn Nets', 'San Antonio Spurs']
# ['Philadelphia 76ers', 'Golden State Warriors']
# ['Los Angeles Lakers', 'Los Angeles Clippers']
# ['Memphis Grizzlies', 'Charlotte Hornets']
# ['Boston Celtics', 'New York Knicks']
# ['Oklahoma City Thunder', 'Miami Heat']
# ['Atlanta Hawks', 'Utah Jazz']
# ['Houston Rockets', 'Denver Nuggets']
# ['Los Angeles Clippers', 'Detroit Pistons']
# ['Chicago Bulls', 'Charlotte Hornets']
# ['Brooklyn Nets', 'Orlando Magic']
# ['Milwaukee Bucks', 'Washington Wizards']
# ['Dallas Mavericks', 'Cleveland Cavaliers']
# ['Indiana Pacers', 'Miami Heat']
# ['Los Angeles Lakers', 'Golden State Warriors']
# ['New Orleans Pelicans', 'San Antonio Spurs']
# ['Denver Nuggets', 'Minnesota Timberwolves']
# ['Atlanta Hawks', 'Phoenix Suns']
# ['Houston Rockets', 'Utah Jazz']
# ['Philadelphia 76ers', 'Sacramento Kings']
# ['Memphis Grizzlies', 'New York Knicks']
# ['Oklahoma City Thunder', 'Boston Celtics']
# ['Los Angeles Clippers', 'Toronto Raptors']
# ['Denver Nuggets', 'Detroit Pistons']
# ['Atlanta Hawks', 'Washington Wizards']
# ['Milwaukee Bucks', 'Brooklyn Nets']
# ['Indiana Pacers', 'New Orleans Pelicans']
# ['Houston Rockets', 'Phoenix Suns']
# ['San Antonio Spurs', 'Sacramento Kings']
# ['Los Angeles Clippers', 'Charlotte Hornets']
# ['Boston Celtics', 'Cleveland Cavaliers']
# ['Los Angeles Lakers', 'Indiana Pacers']
# ['Detroit Pistons', 'New York Knicks']
# ['Minnesota Timberwolves', 'Memphis Grizzlies']
# ['Orlando Magic', 'Oklahoma City Thunder']
# ['Toronto Raptors', 'Philadelphia 76ers']
# ['Miami Heat', 'Portland Trail Blazers']
# ['Denver Nuggets', 'Brooklyn Nets']
# ['New Orleans Pelicans', 'Chicago Bulls']
# ['Washington Wizards', 'Milwaukee Bucks']
# ['Charlotte Hornets', 'Dallas Mavericks']
# ['Phoenix Suns', 'Utah Jazz']
# ['Houston Rockets', 'Sacramento Kings']
# ['San Antonio Spurs', 'Golden State Warriors']
# ['Los Angeles Clippers', 'Indiana Pacers']
# ['Minnesota Timberwolves', 'Orlando Magic']
# ['Toronto Raptors', 'Atlanta Hawks']
# ['Los Angeles Lakers', 'Boston Celtics']
# ['Memphis Grizzlies', 'Oklahoma City Thunder']
# ['San Antonio Spurs', 'Portland Trail Blazers']
# ['New York Knicks', 'Detroit Pistons']
# ['Denver Nuggets', 'Philadelphia 76ers']
# ['Cleveland Cavaliers', 'Washington Wizards']
# ['Chicago Bulls', 'Brooklyn Nets']
# ['Milwaukee Bucks', 'Dallas Mavericks']
# ['Golden State Warriors', 'Phoenix Suns']
# ['Minnesota Timberwolves', 'New Orleans Pelicans']
# ['Miami Heat', 'Sacramento Kings']
# ['San Antonio Spurs', 'Utah Jazz']
# ['Cleveland Cavaliers', 'Indiana Pacers']
# ['Charlotte Hornets', 'Atlanta Hawks']
# ['Toronto Raptors', 'New York Knicks']
# ['Los Angeles Clippers', 'Boston Celtics']
# ['Washington Wizards', 'Chicago Bulls']
# ['New Orleans Pelicans', 'Memphis Grizzlies']
# ['Oklahoma City Thunder', 'Houston Rockets']
# ['Orlando Magic', 'Milwaukee Bucks']
# ['Portland Trail Blazers', 'Dallas Mavericks']
# ['Los Angeles Lakers', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Sacramento Kings']
# ['Orlando Magic', 'Atlanta Hawks']
# ['Miami Heat', 'Golden State Warriors']
# ['New York Knicks', 'Cleveland Cavaliers']
# ['Washington Wizards', 'Detroit Pistons']
# ['Charlotte Hornets', 'Indiana Pacers']
# ['Brooklyn Nets', 'Toronto Raptors']
# ['Milwaukee Bucks', 'Chicago Bulls']
# ['Dallas Mavericks', 'Houston Rockets']
# ['Los Angeles Clippers', 'Minnesota Timberwolves']
# ['Portland Trail Blazers', 'Oklahoma City Thunder']
# ['Miami Heat', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Atlanta Hawks']
# ['San Antonio Spurs', 'Memphis Grizzlies']
# ['Orlando Magic', 'New Orleans Pelicans']
# ['Boston Celtics', 'Philadelphia 76ers']
# ['Utah Jazz', 'Golden State Warriors']
# ['Brooklyn Nets', 'Cleveland Cavaliers']
# ['Milwaukee Bucks', 'Indiana Pacers']
# ['Detroit Pistons', 'Boston Celtics']
# ['Philadelphia 76ers', 'New York Knicks']
# ['Washington Wizards', 'Toronto Raptors']
# ['Memphis Grizzlies', 'Chicago Bulls']
# ['Houston Rockets', 'Minnesota Timberwolves']
# ['Miami Heat', 'Dallas Mavericks']
# ['Sacramento Kings', 'Denver Nuggets']
# ['Phoenix Suns', 'Los Angeles Clippers']
# ['Golden State Warriors', 'Portland Trail Blazers']
# ['Charlotte Hornets', 'Orlando Magic']
# ['New York Knicks', 'Atlanta Hawks']
# ['Oklahoma City Thunder', 'New Orleans Pelicans']
# ['Phoenix Suns', 'Cleveland Cavaliers']
# ['Miami Heat', 'Philadelphia 76ers']
# ['Portland Trail Blazers', 'Brooklyn Nets']
# ['Boston Celtics', 'Milwaukee Bucks']
# ['Sacramento Kings', 'Golden State Warriors']
# ['Houston Rockets', 'Los Angeles Lakers']
# ['Washington Wizards', 'Charlotte Hornets']
# ['New Orleans Pelicans', 'Indiana Pacers']
# ['Chicago Bulls', 'Orlando Magic']
# ['San Antonio Spurs', 'Toronto Raptors']
# ['Detroit Pistons', 'Atlanta Hawks']
# ['Minnesota Timberwolves', 'New York Knicks']
# ['Los Angeles Clippers', 'Memphis Grizzlies']
# ['Denver Nuggets', 'Dallas Mavericks']
# ['Utah Jazz', 'Oklahoma City Thunder']
# ['Portland Trail Blazers', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Atlanta Hawks']
# ['Brooklyn Nets', 'Charlotte Hornets']
# ['Memphis Grizzlies', 'Cleveland Cavaliers']
# ['Los Angeles Lakers', 'New Orleans Pelicans']
# ['Indiana Pacers', 'Washington Wizards']
# ['Detroit Pistons', 'Miami Heat']
# ['Boston Celtics', 'Chicago Bulls']
# ['Sacramento Kings', 'Oklahoma City Thunder']
# ['Houston Rockets', 'Golden State Warriors']
# ['Minnesota Timberwolves', 'Milwaukee Bucks']
# ['Dallas Mavericks', 'Utah Jazz']
# ['Orlando Magic', 'Toronto Raptors']
# ['Los Angeles Clippers', 'Denver Nuggets']
# ['San Antonio Spurs', 'New York Knicks']
# ['Golden State Warriors', 'Charlotte Hornets']
# ['Portland Trail Blazers', 'Cleveland Cavaliers']
# ['Indiana Pacers', 'Detroit Pistons']
# ['San Antonio Spurs', 'Brooklyn Nets']
# ['Phoenix Suns', 'Miami Heat']
# ['Milwaukee Bucks', 'Chicago Bulls']
# ['Atlanta Hawks', 'Houston Rockets']
# ['Los Angeles Lakers', 'Memphis Grizzlies']
# ['Sacramento Kings', 'Minnesota Timberwolves']
# ['Philadelphia 76ers', 'New Orleans Pelicans']
# ['Dallas Mavericks', 'Los Angeles Clippers']
# ['Orlando Magic', 'New York Knicks']
# ['Boston Celtics', 'Toronto Raptors']
# ['Oklahoma City Thunder', 'Denver Nuggets']
# ['Houston Rockets', 'Charlotte Hornets']
# ['Minnesota Timberwolves', 'Atlanta Hawks']
# ['Washington Wizards', 'Brooklyn Nets']
# ['Golden State Warriors', 'Miami Heat']
# ['Portland Trail Blazers', 'Boston Celtics']
# ['Chicago Bulls', 'Memphis Grizzlies']
# ['Indiana Pacers', 'Dallas Mavericks']
# ['Detroit Pistons', 'San Antonio Spurs']
# ['Los Angeles Clippers', 'Utah Jazz']
# ['Milwaukee Bucks', 'Sacramento Kings']
# ['New Orleans Pelicans', 'Los Angeles Lakers']
# ['Minnesota Timberwolves', 'Indiana Pacers']
# ['Golden State Warriors', 'Orlando Magic']
# ['Cleveland Cavaliers', 'New York Knicks']
# ['Miami Heat', 'Houston Rockets']
# ['Philadelphia 76ers', 'Oklahoma City Thunder']
# ['Utah Jazz', 'Denver Nuggets']
# ['Chicago Bulls', 'Atlanta Hawks']
# ['Charlotte Hornets', 'Brooklyn Nets']
# ['Washington Wizards', 'Boston Celtics']
# ['Portland Trail Blazers', 'Toronto Raptors']
# ['New Orleans Pelicans', 'Phoenix Suns']
# ['Los Angeles Clippers', 'Sacramento Kings']
# ['Milwaukee Bucks', 'Los Angeles Lakers']
# ['Detroit Pistons', 'Cleveland Cavaliers']
# ['Orlando Magic', 'Indiana Pacers']
# ['Brooklyn Nets', 'Miami Heat']
# ['Memphis Grizzlies', 'Dallas Mavericks']
# ['Golden State Warriors', 'Philadelphia 76ers']
# ['Oklahoma City Thunder', 'San Antonio Spurs']
# ['New Orleans Pelicans', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Phoenix Suns']
# ['Milwaukee Bucks', 'Utah Jazz']
# ['Portland Trail Blazers', 'Charlotte Hornets']
# ['Houston Rockets', 'Boston Celtics']
# ['Atlanta Hawks', 'Chicago Bulls']
# ['New York Knicks', 'Los Angeles Clippers']
# ['Orlando Magic', 'Cleveland Cavaliers']
# ['Toronto Raptors', 'Detroit Pistons']
# ['Minnesota Timberwolves', 'Washington Wizards']
# ['Memphis Grizzlies', 'Oklahoma City Thunder']
# ['Dallas Mavericks', 'Brooklyn Nets']
# ['Atlanta Hawks', 'Miami Heat']
# ['Denver Nuggets', 'San Antonio Spurs']
# ['Milwaukee Bucks', 'Phoenix Suns']
# ['New Orleans Pelicans', 'Utah Jazz']
# ['New York Knicks', 'Sacramento Kings']
# ['Los Angeles Clippers', 'Los Angeles Lakers']
# ['Chicago Bulls', 'Indiana Pacers']
# ['Orlando Magic', 'Philadelphia 76ers']
# ['Portland Trail Blazers', 'Memphis Grizzlies']
# ['Oklahoma City Thunder', 'Minnesota Timberwolves']
# ['Houston Rockets', 'Toronto Raptors']
# ['Boston Celtics', 'Golden State Warriors']
# ['Miami Heat', 'Charlotte Hornets']
# ['Minnesota Timberwolves', 'Detroit Pistons']
# ['Dallas Mavericks', 'Washington Wizards']
# ['San Antonio Spurs', 'Atlanta Hawks']
# ['Cleveland Cavaliers', 'Brooklyn Nets']
# ['Philadelphia 76ers', 'Chicago Bulls']
# ['Utah Jazz', 'New Orleans Pelicans']
# ['New York Knicks', 'Phoenix Suns']
# ['Boston Celtics', 'Sacramento Kings']
# ['Denver Nuggets', 'Los Angeles Lakers']
# ['Indiana Pacers', 'Milwaukee Bucks']
# ['Oklahoma City Thunder', 'Portland Trail Blazers']
# ['Washington Wizards', 'Charlotte Hornets']
# ['Dallas Mavericks', 'Orlando Magic']
# ['Detroit Pistons', 'Chicago Bulls']
# ['Philadelphia 76ers', 'Houston Rockets']
# ['Utah Jazz', 'Memphis Grizzlies']
# ['Cleveland Cavaliers', 'Miami Heat']
# ['Toronto Raptors', 'New Orleans Pelicans']
# ['Denver Nuggets', 'Golden State Warriors']
# ['Oklahoma City Thunder', 'Los Angeles Clippers']
# ['Sacramento Kings', 'New York Knicks']
# ['Brooklyn Nets', 'Atlanta Hawks']
# ['Washington Wizards', 'Minnesota Timberwolves']
# ['Boston Celtics', 'Los Angeles Lakers']
# ['Charlotte Hornets', 'Milwaukee Bucks']
# ['Phoenix Suns', 'Portland Trail Blazers']
# ['Chicago Bulls', 'Detroit Pistons']
# ['Toronto Raptors', 'Miami Heat']
# ['Indiana Pacers', 'Philadelphia 76ers']
# ['New Orleans Pelicans', 'Atlanta Hawks']
# ['Orlando Magic', 'Memphis Grizzlies']
# ['Houston Rockets', 'Dallas Mavericks']
# ['New York Knicks', 'Minnesota Timberwolves']
# ['Milwaukee Bucks', 'San Antonio Spurs']
# ['Phoenix Suns', 'Golden State Warriors']
# ['Toronto Raptors', 'Cleveland Cavaliers']
# ['Sacramento Kings', 'Washington Wizards']
# ['Detroit Pistons', 'Brooklyn Nets']
# ['Charlotte Hornets', 'Houston Rockets']
# ['Oklahoma City Thunder', 'Utah Jazz']
# ['Boston Celtics', 'Los Angeles Clippers']
# ['New York Knicks', 'Indiana Pacers']
# ['Cleveland Cavaliers', 'Philadelphia 76ers']
# ['Los Angeles Lakers', 'Chicago Bulls']
# ['San Antonio Spurs', 'Dallas Mavericks']
# ['Milwaukee Bucks', 'New Orleans Pelicans']
# ['Minnesota Timberwolves', 'Denver Nuggets']
# ['Portland Trail Blazers', 'Los Angeles Clippers']
# ['Brooklyn Nets', 'Oklahoma City Thunder']
# ['Orlando Magic', 'Washington Wizards']
# ['Memphis Grizzlies', 'Atlanta Hawks']
# ['Detroit Pistons', 'Miami Heat']
# ['Golden State Warriors', 'Houston Rockets']
# ['Utah Jazz', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Indiana Pacers']
# ['Cleveland Cavaliers', 'Orlando Magic']
# ['Sacramento Kings', 'Boston Celtics']
# ['Los Angeles Lakers', 'Toronto Raptors']
# ['Minnesota Timberwolves', 'Utah Jazz']
# ['Dallas Mavericks', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Detroit Pistons']
# ['Sacramento Kings', 'Philadelphia 76ers']
# ['Charlotte Hornets', 'Washington Wizards']
# ['Phoenix Suns', 'Houston Rockets']
# ['Milwaukee Bucks', 'Miami Heat']
# ['Portland Trail Blazers', 'New Orleans Pelicans']
# ['New York Knicks', 'San Antonio Spurs']
# ['Chicago Bulls', 'Los Angeles Clippers']
# ['Atlanta Hawks', 'Boston Celtics']
# ['Phoenix Suns', 'New Orleans Pelicans']
# ['Memphis Grizzlies', 'Washington Wizards']
# ['Cleveland Cavaliers', 'Dallas Mavericks']
# ['Golden State Warriors', 'Oklahoma City Thunder']
# ['Portland Trail Blazers', 'San Antonio Spurs']
# ['Indiana Pacers', 'Denver Nuggets']
# ['Brooklyn Nets', 'Utah Jazz']
# ['Los Angeles Lakers', 'New York Knicks']
# ['Charlotte Hornets', 'Miami Heat']
# ['Philadelphia 76ers', 'Milwaukee Bucks']
# ['Toronto Raptors', 'Detroit Pistons']
# ['Atlanta Hawks', 'Orlando Magic']
# ['Chicago Bulls', 'Sacramento Kings']
# ['Minnesota Timberwolves', 'Houston Rockets']
# ['Brooklyn Nets', 'Los Angeles Clippers']
# ['Detroit Pistons', 'Cleveland Cavaliers']
# ['Utah Jazz', 'Washington Wizards']
# ['Denver Nuggets', 'Boston Celtics']
# ['New York Knicks', 'Toronto Raptors']
# ['Miami Heat', 'Oklahoma City Thunder']
# ['Golden State Warriors', 'San Antonio Spurs']
# ['New Orleans Pelicans', 'Dallas Mavericks']
# ['Chicago Bulls', 'Phoenix Suns']
# ['Indiana Pacers', 'Portland Trail Blazers']
# ['Philadelphia 76ers', 'Charlotte Hornets']
# ['Houston Rockets', 'Atlanta Hawks']
# ['Los Angeles Lakers', 'Milwaukee Bucks']
# ['Golden State Warriors', 'Minnesota Timberwolves']
# ['Brooklyn Nets', 'Sacramento Kings']
# ['Indiana Pacers', 'Los Angeles Clippers']
# ['Milwaukee Bucks', 'Cleveland Cavaliers']
# ['New Orleans Pelicans', 'Orlando Magic']
# ['Boston Celtics', 'Philadelphia 76ers']
# ['Utah Jazz', 'New York Knicks']
# ['Washington Wizards', 'Chicago Bulls']
# ['Houston Rockets', 'Memphis Grizzlies']
# ['Miami Heat', 'San Antonio Spurs']
# ['Toronto Raptors', 'Oklahoma City Thunder']
# ['Dallas Mavericks', 'Portland Trail Blazers']
# ['Minnesota Timberwolves', 'Charlotte Hornets']
# ['Denver Nuggets', 'Washington Wizards']
# ['Utah Jazz', 'Atlanta Hawks']
# ['Detroit Pistons', 'Phoenix Suns']
# ['Dallas Mavericks', 'Sacramento Kings']
# ['Indiana Pacers', 'Golden State Warriors']
# ['Memphis Grizzlies', 'Orlando Magic']
# ['Los Angeles Clippers', 'Cleveland Cavaliers']
# ['Denver Nuggets', 'New York Knicks']
# ['Oklahoma City Thunder', 'Toronto Raptors']
# ['San Antonio Spurs', 'Houston Rockets']
# ['Miami Heat', 'Milwaukee Bucks']
# ['Brooklyn Nets', 'Los Angeles Lakers']
# ['Boston Celtics', 'Charlotte Hornets']
# ['Miami Heat', 'Washington Wizards']
# ['Philadelphia 76ers', 'Atlanta Hawks']
# ['Utah Jazz', 'Chicago Bulls']
# ['Minnesota Timberwolves', 'Memphis Grizzlies']
# ['Dallas Mavericks', 'Golden State Warriors']
# ['Detroit Pistons', 'Portland Trail Blazers']
# ['Phoenix Suns', 'Sacramento Kings']
# ['Los Angeles Clippers', 'New York Knicks']
# ['Cleveland Cavaliers', 'Milwaukee Bucks']
# ['Denver Nuggets', 'Indiana Pacers']
# ['Charlotte Hornets', 'Toronto Raptors']
# ['Houston Rockets', 'New Orleans Pelicans']
# ['San Antonio Spurs', 'Boston Celtics']
# ['Detroit Pistons', 'Golden State Warriors']
# ['Sacramento Kings', 'Los Angeles Lakers']
# ['Philadelphia 76ers', 'Orlando Magic']
# ['Oklahoma City Thunder', 'Memphis Grizzlies']
# ['Phoenix Suns', 'Utah Jazz']
# ['Brooklyn Nets', 'Portland Trail Blazers']
# ['San Antonio Spurs', 'Charlotte Hornets']
# ['Boston Celtics', 'Cleveland Cavaliers']
# ['Orlando Magic', 'Miami Heat']
# ['Chicago Bulls', 'Toronto Raptors']
# ['Houston Rockets', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'Minnesota Timberwolves']
# ['Atlanta Hawks', 'New Orleans Pelicans']
# ['Sacramento Kings', 'Dallas Mavericks']
# ['Detroit Pistons', 'Denver Nuggets']
# ['Washington Wizards', 'Los Angeles Lakers']
# ['Portland Trail Blazers', 'Chicago Bulls']
# ['Golden State Warriors', 'Memphis Grizzlies']
# ['Indiana Pacers', 'Oklahoma City Thunder']
# ['Washington Wizards', 'Phoenix Suns']
# ['Los Angeles Lakers', 'Utah Jazz']
# ['Orlando Magic', 'Detroit Pistons']
# ['Brooklyn Nets', 'Philadelphia 76ers']
# ['Dallas Mavericks', 'Miami Heat']
# ['Toronto Raptors', 'New York Knicks']
# ['Denver Nuggets', 'Houston Rockets']
# ['Los Angeles Clippers', 'Milwaukee Bucks']
# ['Sacramento Kings', 'New Orleans Pelicans']
# ['Cleveland Cavaliers', 'San Antonio Spurs']
# ['Indiana Pacers', 'Boston Celtics']
# ['Portland Trail Blazers', 'Atlanta Hawks']
# ['Golden State Warriors', 'Minnesota Timberwolves']
# ['Denver Nuggets', 'Oklahoma City Thunder']
# ['Washington Wizards', 'Utah Jazz']
# ['Charlotte Hornets', 'Los Angeles Lakers']
# ['Cleveland Cavaliers', 'Los Angeles Clippers']
# ['Boston Celtics', 'Brooklyn Nets']
# ['Sacramento Kings', 'Houston Rockets']
# ['Portland Trail Blazers', 'Detroit Pistons']
# ['Orlando Magic', 'Indiana Pacers']
# ['Miami Heat', 'New York Knicks']
# ['Toronto Raptors', 'Chicago Bulls']
# ['Philadelphia 76ers', 'Minnesota Timberwolves']
# ['Memphis Grizzlies', 'Phoenix Suns']
# ['Milwaukee Bucks', 'Atlanta Hawks']
# ['Dallas Mavericks', 'Oklahoma City Thunder']
# ['Los Angeles Lakers', 'New Orleans Pelicans']
# ['Sacramento Kings', 'San Antonio Spurs']
# ['Washington Wizards', 'Denver Nuggets']
# ['Charlotte Hornets', 'Golden State Warriors']
# ['Memphis Grizzlies', 'Los Angeles Clippers']

# %%
statsdf = pd.DataFrame(stats_list,columns = statColumns)

# %%
resultdf = pd.concat([df, statsdf], axis=1)
resultdf.head()
# Out:
#            date_game game_start_time      visitor_team_name visitor_pts  \
# 0  Tue, Oct 16, 2018           8:00p     Philadelphia 76ers          87
# 1  Tue, Oct 16, 2018          10:30p  Oklahoma City Thunder         100
# 2  Wed, Oct 17, 2018           7:00p        Milwaukee Bucks         113
# 3  Wed, Oct 17, 2018           7:00p          Brooklyn Nets         100
# 4  Wed, Oct 17, 2018           7:00p      Memphis Grizzlies          83
#
#           home_team_name home_pts  \
# 0         Boston Celtics      105
# 1  Golden State Warriors      108
# 2      Charlotte Hornets      112
# 3        Detroit Pistons      103
# 4         Indiana Pacers      111
#
#                                       box_score_text overtimes attendance  \
# 0  https://www.basketball-reference.com/boxscores...               18,624
# 1  https://www.basketball-reference.com/boxscores...               19,596
# 2  https://www.basketball-reference.com/boxscores...               17,889
# 3  https://www.basketball-reference.com/boxscores...               20,332
# 4  https://www.basketball-reference.com/boxscores...               17,923
#
#   game_remarks       Date Team TS% Team eFG% Team ORtg Opp TS% Opp eFG%  \
# 0              2018-10-16     .448      .420      83.4    .509     .490
# 1              2018-10-16     .466      .418      97.7    .525     .479
# 2              2018-10-17     .602      .576     110.2    .551     .533
# 3              2018-10-17     .545      .518     100.0    .506     .457
# 4              2018-10-17     .431      .357      88.8    .626     .627
#
#   Opp ORtg
# 0    100.7
# 1    105.6
# 2    109.2
# 3    103.0
# 4    118.7

# %%
#visitor stats
visitor_df = resultdf.iloc[:,np.r_[0:7,11:14]]
visitor_df.head()

#home stats
home_df = resultdf.iloc[:,np.r_[0:2,4:6,2:4,6,14:17]]
home_df.head()

visitor_df.head()
# Out:
#            date_game game_start_time      visitor_team_name visitor_pts  \
# 0  Tue, Oct 16, 2018           8:00p     Philadelphia 76ers          87
# 1  Tue, Oct 16, 2018          10:30p  Oklahoma City Thunder         100
# 2  Wed, Oct 17, 2018           7:00p        Milwaukee Bucks         113
# 3  Wed, Oct 17, 2018           7:00p          Brooklyn Nets         100
# 4  Wed, Oct 17, 2018           7:00p      Memphis Grizzlies          83
#
#           home_team_name home_pts  \
# 0         Boston Celtics      105
# 1  Golden State Warriors      108
# 2      Charlotte Hornets      112
# 3        Detroit Pistons      103
# 4         Indiana Pacers      111
#
#                                       box_score_text Team TS% Team eFG%  \
# 0  https://www.basketball-reference.com/boxscores...     .448      .420
# 1  https://www.basketball-reference.com/boxscores...     .466      .418
# 2  https://www.basketball-reference.com/boxscores...     .602      .576
# 3  https://www.basketball-reference.com/boxscores...     .545      .518
# 4  https://www.basketball-reference.com/boxscores...     .431      .357
#
#   Team ORtg
# 0      83.4
# 1      97.7
# 2     110.2
# 3     100.0
# 4      88.8

# %%
home_df.columns = ['date_game','game_start_time','team_name','team_pts','opposing_team','opposing_pts','box_score','TS%','eFG%','ORtg']

visitor_df.columns = ['date_game','game_start_time','team_name','team_pts','opposing_team','opposing_pts','box_score','TS%','eFG%','ORtg']

# %%
frames = [visitor_df, home_df]
agg_data = pd.concat(frames,ignore_index=True)

# %%
def date_change(row):
    t = datetime.datetime.strptime(row['date_game'].replace(',',''), "%a %b %d %Y")
    convert_date = t.strftime('%m/%d/%Y')
    return(convert_date)

agg_data['Date'] = pd.to_datetime(agg_data.apply(date_change,axis = 1))

# %%
agg_data['date_game'] = agg_data['Date']
del agg_data['Date']

# %%
ordered_agg_data = agg_data.sort_values(by = ['team_name','date_game']).reset_index()

# %%
rolling_stat_data = agg_data.sort_values(by = ['team_name','date_game'])

testdata_grouped_rolling = rolling_stat_data.groupby('team_name')[['TS%','eFG%','ORtg']].rolling(window=30, min_periods=1).mean().reset_index()

# %%
del testdata_grouped_rolling['level_1']
del testdata_grouped_rolling['team_name']

# %%
testdata_grouped_rolling.columns = ['TS1%','eFG1%','ORtg1']

# %%
full_stats_data = pd.concat([ordered_agg_data ,testdata_grouped_rolling], axis=1)

# %%
#Shift average stats so each row has the average of the games previously
full_stats_data[['TS%','eFG%','ORtg']] = full_stats_data.groupby('team_name')['TS1%','eFG1%','ORtg1'].apply(lambda grp: grp.shift(1))

# %%
#Deleted non-shifted columns

full_stats_data = full_stats_data.drop(['TS1%','eFG1%','ORtg1'],axis =1)

# %%
full_stats_data_2 = full_stats_data

# %%
newDf = pd.merge(full_stats_data_2,full_stats_data,left_on = ['date_game','team_name'],right_on = ['date_game','opposing_team'])

# %%
dedupe_new_df = newDf.drop_duplicates(subset = 'box_score_x',keep ='first')

# %%
dedupe_new_df.head()
# Out:
#    index_x  date_game game_start_time_x    team_name_x team_pts_x  \
# 0        6 2018-10-17             7:30p  Atlanta Hawks        107
# 1       18 2018-10-19             8:00p  Atlanta Hawks        117
# 2       35 2018-10-21             6:00p  Atlanta Hawks        133
# 3     1202 2018-10-24             7:00p  Atlanta Hawks        111
# 4     1226 2018-10-27             7:30p  Atlanta Hawks         85
#
#        opposing_team_x opposing_pts_x  \
# 0      New York Knicks            126
# 1    Memphis Grizzlies            131
# 2  Cleveland Cavaliers            111
# 3     Dallas Mavericks            104
# 4        Chicago Bulls             97
#
#                                          box_score_x     TS%_x    eFG%_x  ...  \
# 0  https://www.basketball-reference.com/boxscores...       NaN       NaN  ...
# 1  https://www.basketball-reference.com/boxscores...  0.546000  0.511000  ...
# 2  https://www.basketball-reference.com/boxscores...  0.569000  0.544500  ...
# 3  https://www.basketball-reference.com/boxscores...  0.587667  0.563667  ...
# 4  https://www.basketball-reference.com/boxscores...  0.573250  0.545000  ...
#
#    index_y  game_start_time_y          team_name_y team_pts_y opposing_team_y  \
# 0     1157              7:30p      New York Knicks        126   Atlanta Hawks
# 1     1169              8:00p    Memphis Grizzlies        131   Atlanta Hawks
# 2     1186              6:00p  Cleveland Cavaliers        111   Atlanta Hawks
# 3       51              7:00p     Dallas Mavericks        104   Atlanta Hawks
# 4       75              7:30p        Chicago Bulls         97   Atlanta Hawks
#
#   opposing_pts_y                                        box_score_y     TS%_y  \
# 0            107  https://www.basketball-reference.com/boxscores...       NaN
# 1            117  https://www.basketball-reference.com/boxscores...  0.431000
# 2            133  https://www.basketball-reference.com/boxscores...  0.545500
# 3            111  https://www.basketball-reference.com/boxscores...  0.566333
# 4             85  https://www.basketball-reference.com/boxscores...  0.574800
#
#    eFG%_y  ORtg_y
# 0     NaN     NaN
# 1  0.3570   88.80
# 2  0.4840  111.35
# 3  0.5290  117.70
# 4  0.5408  110.88
#
# [5 rows x 21 columns]

# %%
dedupe_new_df.columns
# Out:
# Index(['index_x', 'date_game', 'game_start_time_x', 'team_name_x',
#        'team_pts_x', 'opposing_team_x', 'opposing_pts_x', 'box_score_x',
#        'TS%_x', 'eFG%_x', 'ORtg_x', 'index_y', 'game_start_time_y',
#        'team_name_y', 'team_pts_y', 'opposing_team_y', 'opposing_pts_y',
#        'box_score_y', 'TS%_y', 'eFG%_y', 'ORtg_y'],
#       dtype='object')

# %%
allowed_df = dedupe_new_df[['date_game','team_name_x','opposing_team_x','TS%_x','eFG%_x', 'ORtg_x','TS%_y', 'eFG%_y', 'ORtg_y']]

allowed_df.columns = ['date_game','team_name','opposing_team','Team TS%','Team eFG%','Team ORtg','Opp TS%', 'Opp eFG%', 'Opp ORtg']

# %%
export_csv = allowed_df.to_csv (r'C:\Users\jeromerufin\Desktop\Metis\advstats_18_19.csv') #Don't forget to add '.csv' at the end of the path
