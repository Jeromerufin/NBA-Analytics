# %%
from bs4 import BeautifulSoup
import requests

from IPython.core.display import display, HTML

import pandas as pd

import re

import numpy as np

import datetime

# %%
#Retrieve breakdown of games from october to end of march

urlList = [
    'https://www.basketball-reference.com/leagues/NBA_2017_games-october.html',
    'https://www.basketball-reference.com/leagues/NBA_2017_games-november.html',
    'https://www.basketball-reference.com/leagues/NBA_2017_games-december.html',
    'https://www.basketball-reference.com/leagues/NBA_2017_games-january.html',
    'https://www.basketball-reference.com/leagues/NBA_2017_games-february.html',
    'https://www.basketball-reference.com/leagues/NBA_2017_games-march.html'
]
soupList = []
for url in urlList:
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    soupList.append(soup)
[soup1,soup2,soup3,soup4,soup5,soup6] = soupList

# %%
headerData = soup1.find(class_ = 'overthrow table_container').find_all('tr')[0].find_all('th')

# %%
column_headers = []

#get headers
for header in headerData:
    column_headers.append(header['data-stat'])
column_headers
# Out:
# ['date_game',
#  'game_start_time',
#  'visitor_team_name',
#  'visitor_pts',
#  'home_team_name',
#  'home_pts',
#  'box_score_text',
#  'overtimes',
#  'attendance',
#  'game_remarks']

# %%
fullDataList = []

for soup in soupList:
    cellData = soup.find(class_ = 'overthrow table_container').find_all('tr')
    for row in range(1,len(cellData)):
        rowList = []
        for cell in cellData[row].find_all(lambda tag: tag.name == 'td' or tag.name == 'th'):
            if cell.contents == []:
                value = ''
            elif cell.contents[0].name == 'a':
                if cell.contents[0].contents[0] == 'Box Score':
                    value = 'https://www.basketball-reference.com'+ cell.contents[0]['href']
                else:
                    value = cell.contents[0].contents[0]
            else:
                value = cell.contents[0]
            rowList.append(value)
        fullDataList.append(rowList)

cleanCellData = [x for x in fullDataList if x != []]

cleanCellData
# Out:
# [['Tue, Oct 25, 2016',
#   '7:30p',
#   'New York Knicks',
#   '88',
#   'Cleveland Cavaliers',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201610250CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Tue, Oct 25, 2016',
#   '10:00p',
#   'Utah Jazz',
#   '104',
#   'Portland Trail Blazers',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201610250POR.html',
#   '',
#   '19,446',
#   ''],
#  ['Tue, Oct 25, 2016',
#   '10:30p',
#   'San Antonio Spurs',
#   '129',
#   'Golden State Warriors',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201610250GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '7:00p',
#   'Dallas Mavericks',
#   '121',
#   'Indiana Pacers',
#   '130',
#   'https://www.basketball-reference.com/boxscores/201610260IND.html',
#   'OT',
#   '17,923',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '7:00p',
#   'Miami Heat',
#   '108',
#   'Orlando Magic',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201610260ORL.html',
#   '',
#   '19,298',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '7:30p',
#   'Brooklyn Nets',
#   '117',
#   'Boston Celtics',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201610260BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '7:30p',
#   'Detroit Pistons',
#   '91',
#   'Toronto Raptors',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201610260TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '8:00p',
#   'Denver Nuggets',
#   '107',
#   'New Orleans Pelicans',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201610260NOP.html',
#   '',
#   '15,869',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '8:00p',
#   'Charlotte Hornets',
#   '107',
#   'Milwaukee Bucks',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201610260MIL.html',
#   '',
#   '18,717',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '8:00p',
#   'Minnesota Timberwolves',
#   '98',
#   'Memphis Grizzlies',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201610260MEM.html',
#   '',
#   '18,119',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '8:00p',
#   'Oklahoma City Thunder',
#   '103',
#   'Philadelphia 76ers',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201610260PHI.html',
#   '',
#   '20,487',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '10:00p',
#   'Sacramento Kings',
#   '113',
#   'Phoenix Suns',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201610260PHO.html',
#   '',
#   '18,055',
#   ''],
#  ['Wed, Oct 26, 2016',
#   '10:30p',
#   'Houston Rockets',
#   '114',
#   'Los Angeles Lakers',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201610260LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Thu, Oct 27, 2016',
#   '7:30p',
#   'Washington Wizards',
#   '99',
#   'Atlanta Hawks',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201610270ATL.html',
#   '',
#   '19,049',
#   ''],
#  ['Thu, Oct 27, 2016',
#   '8:00p',
#   'Boston Celtics',
#   '99',
#   'Chicago Bulls',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201610270CHI.html',
#   '',
#   '21,501',
#   ''],
#  ['Thu, Oct 27, 2016',
#   '10:30p',
#   'Los Angeles Clippers',
#   '114',
#   'Portland Trail Blazers',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201610270POR.html',
#   '',
#   '19,500',
#   ''],
#  ['Thu, Oct 27, 2016',
#   '10:30p',
#   'San Antonio Spurs',
#   '102',
#   'Sacramento Kings',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201610270SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '94',
#   'Toronto Raptors',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201610280TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '7:30p',
#   'Indiana Pacers',
#   '94',
#   'Brooklyn Nets',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201610280BRK.html',
#   '',
#   '17,732',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '7:30p',
#   'Orlando Magic',
#   '82',
#   'Detroit Pistons',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201610280DET.html',
#   '',
#   '19,122',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '8:00p',
#   'Phoenix Suns',
#   '110',
#   'Oklahoma City Thunder',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201610280OKC.html',
#   'OT',
#   '18,203',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '8:00p',
#   'Charlotte Hornets',
#   '97',
#   'Miami Heat',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201610280MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '8:30p',
#   'Houston Rockets',
#   '106',
#   'Dallas Mavericks',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201610280DAL.html',
#   '',
#   '20,163',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '9:00p',
#   'Los Angeles Lakers',
#   '89',
#   'Utah Jazz',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201610280UTA.html',
#   '',
#   '19,911',
#   ''],
#  ['Fri, Oct 28, 2016',
#   '9:30p',
#   'Golden State Warriors',
#   '122',
#   'New Orleans Pelicans',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201610280NOP.html',
#   '',
#   '18,217',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '12:30p',
#   'Atlanta Hawks',
#   '104',
#   'Philadelphia 76ers',
#   '72',
#   'https://www.basketball-reference.com/boxscores/201610290PHI.html',
#   '',
#   '16,312',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '7:00p',
#   'Boston Celtics',
#   '104',
#   'Charlotte Hornets',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201610290CHO.html',
#   '',
#   '18,708',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '7:30p',
#   'Orlando Magic',
#   '99',
#   'Cleveland Cavaliers',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201610290CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '7:30p',
#   'Memphis Grizzlies',
#   '104',
#   'New York Knicks',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201610290NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '8:00p',
#   'New Orleans Pelicans',
#   '79',
#   'San Antonio Spurs',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201610290SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '8:00p',
#   'Brooklyn Nets',
#   '108',
#   'Milwaukee Bucks',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201610290MIL.html',
#   '',
#   '12,570',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '8:00p',
#   'Indiana Pacers',
#   '101',
#   'Chicago Bulls',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201610290CHI.html',
#   '',
#   '21,373',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '9:00p',
#   'Portland Trail Blazers',
#   '115',
#   'Denver Nuggets',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201610290DEN.html',
#   'OT',
#   '18,055',
#   ''],
#  ['Sat, Oct 29, 2016',
#   '10:30p',
#   'Minnesota Timberwolves',
#   '103',
#   'Sacramento Kings',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201610290SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '4:30p',
#   'Utah Jazz',
#   '75',
#   'Los Angeles Clippers',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201610300LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '6:00p',
#   'Milwaukee Bucks',
#   '83',
#   'Detroit Pistons',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201610300DET.html',
#   '',
#   '15,161',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '6:00p',
#   'Golden State Warriors',
#   '106',
#   'Phoenix Suns',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201610300PHO.html',
#   '',
#   '17,011',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '6:00p',
#   'San Antonio Spurs',
#   '106',
#   'Miami Heat',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201610300MIA.html',
#   '',
#   '19,678',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '7:00p',
#   'Los Angeles Lakers',
#   '96',
#   'Oklahoma City Thunder',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201610300OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '8:00p',
#   'Washington Wizards',
#   '103',
#   'Memphis Grizzlies',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201610300MEM.html',
#   'OT',
#   '15,573',
#   ''],
#  ['Sun, Oct 30, 2016',
#   '8:00p',
#   'Dallas Mavericks',
#   '92',
#   'Houston Rockets',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201610300HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Mon, Oct 31, 2016',
#   '7:30p',
#   'Sacramento Kings',
#   '95',
#   'Atlanta Hawks',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201610310ATL.html',
#   '',
#   '12,501',
#   ''],
#  ['Mon, Oct 31, 2016',
#   '7:30p',
#   'Chicago Bulls',
#   '118',
#   'Brooklyn Nets',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201610310BRK.html',
#   '',
#   '15,842',
#   ''],
#  ['Mon, Oct 31, 2016',
#   '7:30p',
#   'Denver Nuggets',
#   '102',
#   'Toronto Raptors',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201610310TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Mon, Oct 31, 2016',
#   '10:30p',
#   'Phoenix Suns',
#   '98',
#   'Los Angeles Clippers',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201610310LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '6:00p',
#   'Houston Rockets',
#   '120',
#   'Cleveland Cavaliers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201611010CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '7:00p',
#   'Los Angeles Lakers',
#   '108',
#   'Indiana Pacers',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201611010IND.html',
#   '',
#   '15,348',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '7:00p',
#   'Orlando Magic',
#   '103',
#   'Philadelphia 76ers',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201611010PHI.html',
#   '',
#   '12,529',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '7:30p',
#   'New York Knicks',
#   '89',
#   'Detroit Pistons',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611010DET.html',
#   '',
#   '13,087',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '7:30p',
#   'Sacramento Kings',
#   '96',
#   'Miami Heat',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611010MIA.html',
#   'OT',
#   '19,612',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '8:00p',
#   'Memphis Grizzlies',
#   '80',
#   'Minnesota Timberwolves',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201611010MIN.html',
#   '',
#   '14,774',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '8:00p',
#   'Milwaukee Bucks',
#   '117',
#   'New Orleans Pelicans',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201611010NOP.html',
#   '',
#   '15,515',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '8:30p',
#   'Utah Jazz',
#   '106',
#   'San Antonio Spurs',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611010SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Tue, Nov 1, 2016',
#   '10:00p',
#   'Golden State Warriors',
#   '127',
#   'Portland Trail Blazers',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611010POR.html',
#   '',
#   '19,393',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '7:00p',
#   'Philadelphia 76ers',
#   '93',
#   'Charlotte Hornets',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611020CHO.html',
#   '',
#   '15,275',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '7:00p',
#   'Toronto Raptors',
#   '113',
#   'Washington Wizards',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201611020WAS.html',
#   '',
#   '19,581',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '7:30p',
#   'Los Angeles Lakers',
#   '123',
#   'Atlanta Hawks',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201611020ATL.html',
#   '',
#   '13,800',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '7:30p',
#   'Detroit Pistons',
#   '101',
#   'Brooklyn Nets',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611020BRK.html',
#   '',
#   '13,650',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '7:30p',
#   'Houston Rockets',
#   '118',
#   'New York Knicks',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611020NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '8:00p',
#   'Chicago Bulls',
#   '100',
#   'Boston Celtics',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611020BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '8:00p',
#   'New Orleans Pelicans',
#   '83',
#   'Memphis Grizzlies',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201611020MEM.html',
#   'OT',
#   '15,881',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '9:00p',
#   'Dallas Mavericks',
#   '81',
#   'Utah Jazz',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201611020UTA.html',
#   '',
#   '19,318',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '10:00p',
#   'Portland Trail Blazers',
#   '115',
#   'Phoenix Suns',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201611020PHO.html',
#   'OT',
#   '17,284',
#   ''],
#  ['Wed, Nov 2, 2016',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '85',
#   'Los Angeles Clippers',
#   '83',
#   'https://www.basketball-reference.com/boxscores/201611020LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Thu, Nov 3, 2016',
#   '7:00p',
#   'Sacramento Kings',
#   '94',
#   'Orlando Magic',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611030ORL.html',
#   '',
#   '17,026',
#   ''],
#  ['Thu, Nov 3, 2016',
#   '8:00p',
#   'Boston Celtics',
#   '122',
#   'Cleveland Cavaliers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201611030CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Thu, Nov 3, 2016',
#   '8:00p',
#   'Indiana Pacers',
#   '107',
#   'Milwaukee Bucks',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201611030MIL.html',
#   '',
#   '11,374',
#   ''],
#  ['Thu, Nov 3, 2016',
#   '8:00p',
#   'Denver Nuggets',
#   '102',
#   'Minnesota Timberwolves',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611030MIN.html',
#   '',
#   '11,219',
#   ''],
#  ['Thu, Nov 3, 2016',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '96',
#   'Golden State Warriors',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201611030GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '7:00p',
#   'Atlanta Hawks',
#   '92',
#   'Washington Wizards',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611040WAS.html',
#   '',
#   '14,663',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '7:30p',
#   'Charlotte Hornets',
#   '99',
#   'Brooklyn Nets',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611040BRK.html',
#   '',
#   '15,775',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '7:30p',
#   'Miami Heat',
#   '87',
#   'Toronto Raptors',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611040TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '8:00p',
#   'New York Knicks',
#   '117',
#   'Chicago Bulls',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611040CHI.html',
#   '',
#   '22,376',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '8:00p',
#   'Los Angeles Clippers',
#   '99',
#   'Memphis Grizzlies',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201611040MEM.html',
#   '',
#   '17,115',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '8:00p',
#   'Phoenix Suns',
#   '112',
#   'New Orleans Pelicans',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611040NOP.html',
#   'OT',
#   '15,379',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '8:30p',
#   'Portland Trail Blazers',
#   '105',
#   'Dallas Mavericks',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611040DAL.html',
#   '',
#   '19,475',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '9:00p',
#   'San Antonio Spurs',
#   '100',
#   'Utah Jazz',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201611040UTA.html',
#   '',
#   '19,911',
#   ''],
#  ['Fri, Nov 4, 2016',
#   '10:30p',
#   'Golden State Warriors',
#   '97',
#   'Los Angeles Lakers',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201611040LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '6:00p',
#   'Minnesota Timberwolves',
#   '92',
#   'Oklahoma City Thunder',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201611050OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '7:00p',
#   'Denver Nuggets',
#   '86',
#   'Detroit Pistons',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201611050DET.html',
#   '',
#   '16,218',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '7:00p',
#   'Chicago Bulls',
#   '94',
#   'Indiana Pacers',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611050IND.html',
#   '',
#   '17,020',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '7:00p',
#   'Washington Wizards',
#   '86',
#   'Orlando Magic',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201611050ORL.html',
#   '',
#   '18,846',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '102',
#   'Philadelphia 76ers',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201611050PHI.html',
#   '',
#   '20,497',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '7:30p',
#   'Houston Rockets',
#   '97',
#   'Atlanta Hawks',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201611050ATL.html',
#   '',
#   '16,895',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '8:00p',
#   'Sacramento Kings',
#   '91',
#   'Milwaukee Bucks',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201611050MIL.html',
#   '',
#   '16,021',
#   ''],
#  ['Sat, Nov 5, 2016',
#   '8:30p',
#   'Los Angeles Clippers',
#   '116',
#   'San Antonio Spurs',
#   '92',
#   'https://www.basketball-reference.com/boxscores/201611050SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Sun, Nov 6, 2016',
#   '12:00p',
#   'Utah Jazz',
#   '114',
#   'New York Knicks',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611060NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Sun, Nov 6, 2016',
#   '3:30p',
#   'Portland Trail Blazers',
#   '100',
#   'Memphis Grizzlies',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201611060MEM.html',
#   '',
#   '16,233',
#   ''],
#  ['Sun, Nov 6, 2016',
#   '6:00p',
#   'Sacramento Kings',
#   '96',
#   'Toronto Raptors',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611060TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Sun, Nov 6, 2016',
#   '7:00p',
#   'Milwaukee Bucks',
#   '75',
#   'Dallas Mavericks',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201611060DAL.html',
#   'OT',
#   '19,345',
#   ''],
#  ['Sun, Nov 6, 2016',
#   '7:30p',
#   'Denver Nuggets',
#   '123',
#   'Boston Celtics',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611060BOS.html',
#   '',
#   '17,452',
#   ''],
#  ['Sun, Nov 6, 2016',
#   '9:30p',
#   'Phoenix Suns',
#   '108',
#   'Los Angeles Lakers',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201611060LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '7:00p',
#   'Indiana Pacers',
#   '100',
#   'Charlotte Hornets',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201611070CHO.html',
#   '',
#   '16,880',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '7:00p',
#   'Utah Jazz',
#   '109',
#   'Philadelphia 76ers',
#   '84',
#   'https://www.basketball-reference.com/boxscores/201611070PHI.html',
#   '',
#   '14,168',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '7:00p',
#   'Houston Rockets',
#   '114',
#   'Washington Wizards',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611070WAS.html',
#   '',
#   '13,173',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '8:00p',
#   'Orlando Magic',
#   '80',
#   'Chicago Bulls',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201611070CHI.html',
#   '',
#   '21,320',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '8:00p',
#   'Miami Heat',
#   '85',
#   'Oklahoma City Thunder',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201611070OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '10:30p',
#   'New Orleans Pelicans',
#   '106',
#   'Golden State Warriors',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201611070GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Mon, Nov 7, 2016',
#   '10:30p',
#   'Detroit Pistons',
#   '82',
#   'Los Angeles Clippers',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201611070LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Tue, Nov 8, 2016',
#   '7:00p',
#   'Atlanta Hawks',
#   '110',
#   'Cleveland Cavaliers',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611080CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Tue, Nov 8, 2016',
#   '7:30p',
#   'Minnesota Timberwolves',
#   '110',
#   'Brooklyn Nets',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201611080BRK.html',
#   '',
#   '13,610',
#   ''],
#  ['Tue, Nov 8, 2016',
#   '8:00p',
#   'Denver Nuggets',
#   '107',
#   'Memphis Grizzlies',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611080MEM.html',
#   '',
#   '15,109',
#   ''],
#  ['Tue, Nov 8, 2016',
#   '10:00p',
#   'Phoenix Suns',
#   '121',
#   'Portland Trail Blazers',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201611080POR.html',
#   '',
#   '19,239',
#   ''],
#  ['Tue, Nov 8, 2016',
#   '10:30p',
#   'Dallas Mavericks',
#   '109',
#   'Los Angeles Lakers',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201611080LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Tue, Nov 8, 2016',
#   '10:30p',
#   'New Orleans Pelicans',
#   '94',
#   'Sacramento Kings',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611080SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '7:00p',
#   'Utah Jazz',
#   '98',
#   'Charlotte Hornets',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611090CHO.html',
#   '',
#   '15,712',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '7:00p',
#   'Philadelphia 76ers',
#   '115',
#   'Indiana Pacers',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201611090IND.html',
#   'OT',
#   '15,360',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '7:00p',
#   'Brooklyn Nets',
#   '96',
#   'New York Knicks',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201611090NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '7:00p',
#   'Minnesota Timberwolves',
#   '123',
#   'Orlando Magic',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611090ORL.html',
#   '',
#   '17,102',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '7:00p',
#   'Boston Celtics',
#   '93',
#   'Washington Wizards',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201611090WAS.html',
#   '',
#   '12,675',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '7:30p',
#   'Chicago Bulls',
#   '107',
#   'Atlanta Hawks',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201611090ATL.html',
#   '',
#   '16,354',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '8:00p',
#   'Toronto Raptors',
#   '112',
#   'Oklahoma City Thunder',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611090OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '9:00p',
#   'Detroit Pistons',
#   '100',
#   'Phoenix Suns',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611090PHO.html',
#   '',
#   '16,719',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '9:30p',
#   'Houston Rockets',
#   '101',
#   'San Antonio Spurs',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611090SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '10:30p',
#   'Dallas Mavericks',
#   '95',
#   'Golden State Warriors',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201611090GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Nov 9, 2016',
#   '10:30p',
#   'Portland Trail Blazers',
#   '80',
#   'Los Angeles Clippers',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611090LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Thu, Nov 10, 2016',
#   '8:00p',
#   'Chicago Bulls',
#   '98',
#   'Miami Heat',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611100MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Thu, Nov 10, 2016',
#   '8:00p',
#   'New Orleans Pelicans',
#   '112',
#   'Milwaukee Bucks',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611100MIL.html',
#   '',
#   '12,159',
#   ''],
#  ['Thu, Nov 10, 2016',
#   '9:00p',
#   'Golden State Warriors',
#   '125',
#   'Denver Nuggets',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201611100DEN.html',
#   '',
#   '17,569',
#   ''],
#  ['Thu, Nov 10, 2016',
#   '10:30p',
#   'Los Angeles Lakers',
#   '101',
#   'Sacramento Kings',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611100SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '7:00p',
#   'Toronto Raptors',
#   '113',
#   'Charlotte Hornets',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611110CHO.html',
#   '',
#   '18,107',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '7:00p',
#   'Utah Jazz',
#   '87',
#   'Orlando Magic',
#   '74',
#   'https://www.basketball-reference.com/boxscores/201611110ORL.html',
#   '',
#   '18,846',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '7:00p',
#   'Indiana Pacers',
#   '105',
#   'Philadelphia 76ers',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611110PHI.html',
#   'OT',
#   '17,643',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '105',
#   'Washington Wizards',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201611110WAS.html',
#   '',
#   '20,356',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '7:30p',
#   'New York Knicks',
#   '87',
#   'Boston Celtics',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201611110BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '8:00p',
#   'Los Angeles Clippers',
#   '110',
#   'Oklahoma City Thunder',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611110OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '8:30p',
#   'Detroit Pistons',
#   '86',
#   'San Antonio Spurs',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611110SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Fri, Nov 11, 2016',
#   '10:00p',
#   'Sacramento Kings',
#   '120',
#   'Portland Trail Blazers',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201611110POR.html',
#   'OT',
#   '19,918',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '7:00p',
#   'Boston Celtics',
#   '105',
#   'Indiana Pacers',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611120IND.html',
#   '',
#   '17,923',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '7:00p',
#   'Los Angeles Lakers',
#   '126',
#   'New Orleans Pelicans',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611120NOP.html',
#   '',
#   '17,138',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '7:30p',
#   'Philadelphia 76ers',
#   '96',
#   'Atlanta Hawks',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201611120ATL.html',
#   '',
#   '17,399',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '7:30p',
#   'New York Knicks',
#   '107',
#   'Toronto Raptors',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201611120TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '8:00p',
#   'Washington Wizards',
#   '95',
#   'Chicago Bulls',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611120CHI.html',
#   '',
#   '21,962',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '8:00p',
#   'San Antonio Spurs',
#   '106',
#   'Houston Rockets',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201611120HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '8:00p',
#   'Utah Jazz',
#   '102',
#   'Miami Heat',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611120MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '8:00p',
#   'Los Angeles Clippers',
#   '119',
#   'Minnesota Timberwolves',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201611120MIN.html',
#   '',
#   '14,494',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '8:30p',
#   'Memphis Grizzlies',
#   '96',
#   'Milwaukee Bucks',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611120MIL.html',
#   '',
#   '14,327',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '9:00p',
#   'Detroit Pistons',
#   '106',
#   'Denver Nuggets',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611120DEN.html',
#   '',
#   '13,997',
#   ''],
#  ['Sat, Nov 12, 2016',
#   '9:00p',
#   'Brooklyn Nets',
#   '122',
#   'Phoenix Suns',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611120PHO.html',
#   '',
#   '17,126',
#   ''],
#  ['Sun, Nov 13, 2016',
#   '3:30p',
#   'Charlotte Hornets',
#   '93',
#   'Cleveland Cavaliers',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201611130CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Sun, Nov 13, 2016',
#   '7:00p',
#   'Los Angeles Lakers',
#   '99',
#   'Minnesota Timberwolves',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201611130MIN.html',
#   '',
#   '14,432',
#   ''],
#  ['Sun, Nov 13, 2016',
#   '7:00p',
#   'Orlando Magic',
#   '119',
#   'Oklahoma City Thunder',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201611130OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sun, Nov 13, 2016',
#   '8:00p',
#   'Phoenix Suns',
#   '120',
#   'Golden State Warriors',
#   '133',
#   'https://www.basketball-reference.com/boxscores/201611130GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Sun, Nov 13, 2016',
#   '9:00p',
#   'Denver Nuggets',
#   '105',
#   'Portland Trail Blazers',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201611130POR.html',
#   '',
#   '19,362',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '7:00p',
#   'Orlando Magic',
#   '69',
#   'Indiana Pacers',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201611140IND.html',
#   '',
#   '14,825',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '7:30p',
#   'Oklahoma City Thunder',
#   '88',
#   'Detroit Pistons',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611140DET.html',
#   '',
#   '14,172',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '7:30p',
#   'Dallas Mavericks',
#   '77',
#   'New York Knicks',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201611140NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '8:00p',
#   'Philadelphia 76ers',
#   '88',
#   'Houston Rockets',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201611140HOU.html',
#   '',
#   '13,183',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '8:00p',
#   'Boston Celtics',
#   '105',
#   'New Orleans Pelicans',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611140NOP.html',
#   '',
#   '15,001',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '8:30p',
#   'Miami Heat',
#   '90',
#   'San Antonio Spurs',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201611140SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '9:00p',
#   'Memphis Grizzlies',
#   '102',
#   'Utah Jazz',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611140UTA.html',
#   '',
#   '18,176',
#   ''],
#  ['Mon, Nov 14, 2016',
#   '10:30p',
#   'Brooklyn Nets',
#   '95',
#   'Los Angeles Clippers',
#   '127',
#   'https://www.basketball-reference.com/boxscores/201611140LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Tue, Nov 15, 2016',
#   '7:00p',
#   'Toronto Raptors',
#   '117',
#   'Cleveland Cavaliers',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201611150CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Tue, Nov 15, 2016',
#   '7:30p',
#   'Atlanta Hawks',
#   '93',
#   'Miami Heat',
#   '90',
#   'https://www.basketball-reference.com/boxscores/201611150MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Tue, Nov 15, 2016',
#   '8:00p',
#   'Charlotte Hornets',
#   '115',
#   'Minnesota Timberwolves',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611150MIN.html',
#   '',
#   '10,349',
#   ''],
#  ['Tue, Nov 15, 2016',
#   '10:00p',
#   'Chicago Bulls',
#   '113',
#   'Portland Trail Blazers',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201611150POR.html',
#   '',
#   '19,393',
#   ''],
#  ['Tue, Nov 15, 2016',
#   '10:30p',
#   'Brooklyn Nets',
#   '118',
#   'Los Angeles Lakers',
#   '125',
#   'https://www.basketball-reference.com/boxscores/201611150LAL.html',
#   '',
#   '18,426',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '93',
#   'Indiana Pacers',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201611160IND.html',
#   '',
#   '17,022',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '7:00p',
#   'New Orleans Pelicans',
#   '82',
#   'Orlando Magic',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201611160ORL.html',
#   '',
#   '16,127',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '7:00p',
#   'Washington Wizards',
#   '102',
#   'Philadelphia 76ers',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611160PHI.html',
#   '',
#   '14,863',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '7:30p',
#   'Milwaukee Bucks',
#   '100',
#   'Atlanta Hawks',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611160ATL.html',
#   '',
#   '14,656',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '7:30p',
#   'Dallas Mavericks',
#   '83',
#   'Boston Celtics',
#   '90',
#   'https://www.basketball-reference.com/boxscores/201611160BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '7:30p',
#   'Detroit Pistons',
#   '102',
#   'New York Knicks',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201611160NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '8:00p',
#   'Houston Rockets',
#   '103',
#   'Oklahoma City Thunder',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201611160OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '8:00p',
#   'Golden State Warriors',
#   '127',
#   'Toronto Raptors',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201611160TOR.html',
#   '',
#   '21,050',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '9:00p',
#   'Phoenix Suns',
#   '104',
#   'Denver Nuggets',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201611160DEN.html',
#   '',
#   '10,247',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '10:30p',
#   'Memphis Grizzlies',
#   '111',
#   'Los Angeles Clippers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611160LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Wed, Nov 16, 2016',
#   '10:30p',
#   'San Antonio Spurs',
#   '110',
#   'Sacramento Kings',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201611160SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Thu, Nov 17, 2016',
#   '7:00p',
#   'New York Knicks',
#   '112',
#   'Washington Wizards',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201611170WAS.html',
#   '',
#   '16,704',
#   ''],
#  ['Thu, Nov 17, 2016',
#   '7:30p',
#   'Milwaukee Bucks',
#   '73',
#   'Miami Heat',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611170MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Thu, Nov 17, 2016',
#   '8:00p',
#   'Portland Trail Blazers',
#   '109',
#   'Houston Rockets',
#   '126',
#   'https://www.basketball-reference.com/boxscores/201611170HOU.html',
#   '',
#   '15,550',
#   ''],
#  ['Thu, Nov 17, 2016',
#   '8:00p',
#   'Philadelphia 76ers',
#   '86',
#   'Minnesota Timberwolves',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201611170MIN.html',
#   '',
#   '16,866',
#   ''],
#  ['Thu, Nov 17, 2016',
#   '10:30p',
#   'Chicago Bulls',
#   '85',
#   'Utah Jazz',
#   '77',
#   'https://www.basketball-reference.com/boxscores/201611170UTA.html',
#   '',
#   '19,911',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '7:00p',
#   'Atlanta Hawks',
#   '96',
#   'Charlotte Hornets',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201611180CHO.html',
#   '',
#   '17,989',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '7:00p',
#   'Phoenix Suns',
#   '116',
#   'Indiana Pacers',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611180IND.html',
#   '',
#   '16,780',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '7:30p',
#   'Detroit Pistons',
#   '81',
#   'Cleveland Cavaliers',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611180CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '8:00p',
#   'Golden State Warriors',
#   '104',
#   'Boston Celtics',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201611180BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '8:00p',
#   'Portland Trail Blazers',
#   '101',
#   'New Orleans Pelicans',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201611180NOP.html',
#   '',
#   '15,552',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '8:00p',
#   'Brooklyn Nets',
#   '105',
#   'Oklahoma City Thunder',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201611180OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '8:30p',
#   'Memphis Grizzlies',
#   '80',
#   'Dallas Mavericks',
#   '64',
#   'https://www.basketball-reference.com/boxscores/201611180DAL.html',
#   '',
#   '19,715',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '9:00p',
#   'Toronto Raptors',
#   '113',
#   'Denver Nuggets',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611180DEN.html',
#   'OT',
#   '12,476',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '10:30p',
#   'San Antonio Spurs',
#   '116',
#   'Los Angeles Lakers',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611180LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Fri, Nov 18, 2016',
#   '10:30p',
#   'Los Angeles Clippers',
#   '121',
#   'Sacramento Kings',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201611180SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '5:00p',
#   'Utah Jazz',
#   '102',
#   'Houston Rockets',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611190HOU.html',
#   '',
#   '14,760',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '7:00p',
#   'Boston Celtics',
#   '94',
#   'Detroit Pistons',
#   '92',
#   'https://www.basketball-reference.com/boxscores/201611190DET.html',
#   '',
#   '16,107',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '7:00p',
#   'Charlotte Hornets',
#   '116',
#   'New Orleans Pelicans',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201611190NOP.html',
#   'OT',
#   '15,739',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '7:00p',
#   'Dallas Mavericks',
#   '87',
#   'Orlando Magic',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611190ORL.html',
#   '',
#   '18,846',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '7:00p',
#   'Miami Heat',
#   '114',
#   'Washington Wizards',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611190WAS.html',
#   '',
#   '15,848',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '7:30p',
#   'Phoenix Suns',
#   '105',
#   'Philadelphia 76ers',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201611190PHI.html',
#   '',
#   '18,125',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '8:00p',
#   'Minnesota Timberwolves',
#   '71',
#   'Memphis Grizzlies',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201611190MEM.html',
#   '',
#   '17,112',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '8:30p',
#   'Golden State Warriors',
#   '124',
#   'Milwaukee Bucks',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201611190MIL.html',
#   '',
#   '18,717',
#   ''],
#  ['Sat, Nov 19, 2016',
#   '10:30p',
#   'Chicago Bulls',
#   '95',
#   'Los Angeles Clippers',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611190LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Sun, Nov 20, 2016',
#   '12:00p',
#   'Atlanta Hawks',
#   '94',
#   'New York Knicks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611200NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Sun, Nov 20, 2016',
#   '3:30p',
#   'Portland Trail Blazers',
#   '129',
#   'Brooklyn Nets',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611200BRK.html',
#   '',
#   '16,608',
#   ''],
#  ['Sun, Nov 20, 2016',
#   '7:00p',
#   'Indiana Pacers',
#   '115',
#   'Oklahoma City Thunder',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611200OKC.html',
#   'OT',
#   '18,203',
#   ''],
#  ['Sun, Nov 20, 2016',
#   '9:00p',
#   'Utah Jazz',
#   '91',
#   'Denver Nuggets',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201611200DEN.html',
#   '',
#   '12,565',
#   ''],
#  ['Sun, Nov 20, 2016',
#   '9:00p',
#   'Toronto Raptors',
#   '99',
#   'Sacramento Kings',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611200SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Sun, Nov 20, 2016',
#   '9:30p',
#   'Chicago Bulls',
#   '118',
#   'Los Angeles Lakers',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201611200LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '7:00p',
#   'Memphis Grizzlies',
#   '105',
#   'Charlotte Hornets',
#   '90',
#   'https://www.basketball-reference.com/boxscores/201611210CHO.html',
#   '',
#   '14,181',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '7:00p',
#   'Golden State Warriors',
#   '120',
#   'Indiana Pacers',
#   '83',
#   'https://www.basketball-reference.com/boxscores/201611210IND.html',
#   '',
#   '17,923',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '7:00p',
#   'Miami Heat',
#   '94',
#   'Philadelphia 76ers',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201611210PHI.html',
#   '',
#   '16,477',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '7:00p',
#   'Phoenix Suns',
#   '101',
#   'Washington Wizards',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611210WAS.html',
#   '',
#   '12,790',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '7:30p',
#   'Houston Rockets',
#   '99',
#   'Detroit Pistons',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611210DET.html',
#   '',
#   '13,632',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '8:00p',
#   'Orlando Magic',
#   '89',
#   'Milwaukee Bucks',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201611210MIL.html',
#   '',
#   '12,306',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '8:00p',
#   'Boston Celtics',
#   '99',
#   'Minnesota Timberwolves',
#   '93',
#   'https://www.basketball-reference.com/boxscores/201611210MIN.html',
#   '',
#   '13,167',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '8:30p',
#   'Dallas Mavericks',
#   '91',
#   'San Antonio Spurs',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611210SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Mon, Nov 21, 2016',
#   '10:30p',
#   'Toronto Raptors',
#   '115',
#   'Los Angeles Clippers',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201611210LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Tue, Nov 22, 2016',
#   '7:30p',
#   'New Orleans Pelicans',
#   '112',
#   'Atlanta Hawks',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201611220ATL.html',
#   '',
#   '19,120',
#   ''],
#  ['Tue, Nov 22, 2016',
#   '7:30p',
#   'Portland Trail Blazers',
#   '103',
#   'New York Knicks',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611220NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Tue, Nov 22, 2016',
#   '9:00p',
#   'Chicago Bulls',
#   '107',
#   'Denver Nuggets',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201611220DEN.html',
#   '',
#   '14,328',
#   ''],
#  ['Tue, Nov 22, 2016',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '109',
#   'Los Angeles Lakers',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201611220LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:00p',
#   'San Antonio Spurs',
#   '119',
#   'Charlotte Hornets',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201611230CHO.html',
#   '',
#   '18,515',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:00p',
#   'Portland Trail Blazers',
#   '125',
#   'Cleveland Cavaliers',
#   '137',
#   'https://www.basketball-reference.com/boxscores/201611230CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:00p',
#   'Atlanta Hawks',
#   '96',
#   'Indiana Pacers',
#   '85',
#   'https://www.basketball-reference.com/boxscores/201611230IND.html',
#   '',
#   '16,032',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:00p',
#   'Phoenix Suns',
#   '92',
#   'Orlando Magic',
#   '87',
#   'https://www.basketball-reference.com/boxscores/201611230ORL.html',
#   '',
#   '17,069',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:00p',
#   'Memphis Grizzlies',
#   '104',
#   'Philadelphia 76ers',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611230PHI.html',
#   '2OT',
#   '15,880',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:30p',
#   'Boston Celtics',
#   '111',
#   'Brooklyn Nets',
#   '92',
#   'https://www.basketball-reference.com/boxscores/201611230BRK.html',
#   '',
#   '16,210',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '7:30p',
#   'Miami Heat',
#   '84',
#   'Detroit Pistons',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611230DET.html',
#   '',
#   '14,520',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '8:00p',
#   'Toronto Raptors',
#   '115',
#   'Houston Rockets',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201611230HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '8:30p',
#   'Los Angeles Clippers',
#   '124',
#   'Dallas Mavericks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611230DAL.html',
#   '',
#   '20,042',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '9:00p',
#   'Denver Nuggets',
#   '83',
#   'Utah Jazz',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611230UTA.html',
#   '',
#   '19,229',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '9:30p',
#   'Minnesota Timberwolves',
#   '96',
#   'New Orleans Pelicans',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201611230NOP.html',
#   '',
#   '15,555',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '10:30p',
#   'Los Angeles Lakers',
#   '106',
#   'Golden State Warriors',
#   '149',
#   'https://www.basketball-reference.com/boxscores/201611230GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Wed, Nov 23, 2016',
#   '10:30p',
#   'Oklahoma City Thunder',
#   '101',
#   'Sacramento Kings',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201611230SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '1:00p',
#   'San Antonio Spurs',
#   '109',
#   'Boston Celtics',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201611250BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '7:00p',
#   'Washington Wizards',
#   '94',
#   'Orlando Magic',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611250ORL.html',
#   '',
#   '17,103',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '7:30p',
#   'Dallas Mavericks',
#   '90',
#   'Cleveland Cavaliers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201611250CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '7:30p',
#   'Los Angeles Clippers',
#   '97',
#   'Detroit Pistons',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611250DET.html',
#   '',
#   '17,023',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '7:30p',
#   'Charlotte Hornets',
#   '111',
#   'New York Knicks',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201611250NYK.html',
#   'OT',
#   '19,812',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '7:30p',
#   'Chicago Bulls',
#   '105',
#   'Philadelphia 76ers',
#   '89',
#   'https://www.basketball-reference.com/boxscores/201611250PHI.html',
#   '',
#   '18,234',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '8:00p',
#   'Brooklyn Nets',
#   '97',
#   'Indiana Pacers',
#   '118',
#   'https://www.basketball-reference.com/boxscores/201611250IND.html',
#   '',
#   '16,083',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '8:00p',
#   'Miami Heat',
#   '90',
#   'Memphis Grizzlies',
#   '81',
#   'https://www.basketball-reference.com/boxscores/201611250MEM.html',
#   '',
#   '17,222',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '8:00p',
#   'Toronto Raptors',
#   '105',
#   'Milwaukee Bucks',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201611250MIL.html',
#   '',
#   '16,223',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '8:00p',
#   'Atlanta Hawks',
#   '68',
#   'Utah Jazz',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201611250UTA.html',
#   '',
#   '19,911',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '9:00p',
#   'Oklahoma City Thunder',
#   '132',
#   'Denver Nuggets',
#   '129',
#   'https://www.basketball-reference.com/boxscores/201611250DEN.html',
#   'OT',
#   '14,327',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '9:00p',
#   'Minnesota Timberwolves',
#   '98',
#   'Phoenix Suns',
#   '85',
#   'https://www.basketball-reference.com/boxscores/201611250PHO.html',
#   '',
#   '16,728',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '10:00p',
#   'New Orleans Pelicans',
#   '104',
#   'Portland Trail Blazers',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201611250POR.html',
#   '',
#   '19,393',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '10:30p',
#   'Golden State Warriors',
#   '109',
#   'Los Angeles Lakers',
#   '85',
#   'https://www.basketball-reference.com/boxscores/201611250LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Fri, Nov 25, 2016',
#   '10:30p',
#   'Houston Rockets',
#   '117',
#   'Sacramento Kings',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201611250SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Sat, Nov 26, 2016',
#   '7:00p',
#   'New York Knicks',
#   '102',
#   'Charlotte Hornets',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611260CHO.html',
#   '',
#   '19,195',
#   ''],
#  ['Sat, Nov 26, 2016',
#   '7:00p',
#   'San Antonio Spurs',
#   '112',
#   'Washington Wizards',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201611260WAS.html',
#   '',
#   '17,066',
#   ''],
#  ['Sat, Nov 26, 2016',
#   '8:00p',
#   'Memphis Grizzlies',
#   '110',
#   'Miami Heat',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201611260MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Nov 26, 2016',
#   '8:00p',
#   'Detroit Pistons',
#   '88',
#   'Oklahoma City Thunder',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201611260OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sat, Nov 26, 2016',
#   '10:30p',
#   'Minnesota Timberwolves',
#   '102',
#   'Golden State Warriors',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201611260GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '1:00p',
#   'Cleveland Cavaliers',
#   '112',
#   'Philadelphia 76ers',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201611270PHI.html',
#   '',
#   '19,311',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '3:30p',
#   'Denver Nuggets',
#   '120',
#   'Phoenix Suns',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201611270PHO.html',
#   '',
#   '15,365',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '6:00p',
#   'Sacramento Kings',
#   '122',
#   'Brooklyn Nets',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201611270BRK.html',
#   '',
#   '13,646',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '6:00p',
#   'Los Angeles Clippers',
#   '70',
#   'Indiana Pacers',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611270IND.html',
#   '',
#   '15,572',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '6:00p',
#   'Milwaukee Bucks',
#   '104',
#   'Orlando Magic',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201611270ORL.html',
#   '',
#   '16,521',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '7:00p',
#   'New Orleans Pelicans',
#   '81',
#   'Dallas Mavericks',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201611270DAL.html',
#   '',
#   '19,302',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '9:00p',
#   'Houston Rockets',
#   '130',
#   'Portland Trail Blazers',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201611270POR.html',
#   '',
#   '19,393',
#   ''],
#  ['Sun, Nov 27, 2016',
#   '9:30p',
#   'Atlanta Hawks',
#   '94',
#   'Los Angeles Lakers',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201611270LAL.html',
#   '',
# ...
#   '19,911',
#   ''],
#  ['Fri, Mar 3, 2017',
#   '9:30p',
#   'San Antonio Spurs',
#   '101',
#   'New Orleans Pelicans',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201703030NOP.html',
#   'OT',
#   '17,669',
#   ''],
#  ['Fri, Mar 3, 2017',
#   '10:30p',
#   'Boston Celtics',
#   '115',
#   'Los Angeles Lakers',
#   '95',
#   'https://www.basketball-reference.com/boxscores/201703030LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '6:00p',
#   'Detroit Pistons',
#   '136',
#   'Philadelphia 76ers',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201703040PHI.html',
#   '',
#   '19,523',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '8:00p',
#   'Cleveland Cavaliers',
#   '92',
#   'Miami Heat',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201703040MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '8:00p',
#   'Toronto Raptors',
#   '94',
#   'Milwaukee Bucks',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201703040MIL.html',
#   '',
#   '16,775',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '8:30p',
#   'Los Angeles Clippers',
#   '101',
#   'Chicago Bulls',
#   '91',
#   'https://www.basketball-reference.com/boxscores/201703040CHI.html',
#   '',
#   '22,807',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '9:00p',
#   'Charlotte Hornets',
#   '112',
#   'Denver Nuggets',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201703040DEN.html',
#   '',
#   '14,708',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '9:00p',
#   'Memphis Grizzlies',
#   '108',
#   'Houston Rockets',
#   '123',
#   'https://www.basketball-reference.com/boxscores/201703040HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '9:00p',
#   'Minnesota Timberwolves',
#   '90',
#   'San Antonio Spurs',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201703040SAS.html',
#   'OT',
#   '18,418',
#   ''],
#  ['Sat, Mar 4, 2017',
#   '10:00p',
#   'Brooklyn Nets',
#   '116',
#   'Portland Trail Blazers',
#   '130',
#   'https://www.basketball-reference.com/boxscores/201703040POR.html',
#   '',
#   '19,638',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '1:00p',
#   'Indiana Pacers',
#   '97',
#   'Atlanta Hawks',
#   '96',
#   'https://www.basketball-reference.com/boxscores/201703050ATL.html',
#   '',
#   '15,366',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '3:30p',
#   'Golden State Warriors',
#   '112',
#   'New York Knicks',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201703050NYK.html',
#   '',
#   '19,812',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '5:00p',
#   'Boston Celtics',
#   '106',
#   'Phoenix Suns',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201703050PHO.html',
#   '',
#   '16,790',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '5:00p',
#   'Orlando Magic',
#   '114',
#   'Washington Wizards',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201703050WAS.html',
#   '',
#   '19,195',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '6:00p',
#   'Utah Jazz',
#   '110',
#   'Sacramento Kings',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201703050SAC.html',
#   'OT',
#   '17,608',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '8:30p',
#   'Oklahoma City Thunder',
#   '89',
#   'Dallas Mavericks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201703050DAL.html',
#   '',
#   '20,232',
#   ''],
#  ['Sun, Mar 5, 2017',
#   '9:30p',
#   'New Orleans Pelicans',
#   '105',
#   'Los Angeles Lakers',
#   '97',
#   'https://www.basketball-reference.com/boxscores/201703050LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '7:00p',
#   'Miami Heat',
#   '106',
#   'Cleveland Cavaliers',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201703060CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '7:00p',
#   'New York Knicks',
#   '113',
#   'Orlando Magic',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201703060ORL.html',
#   '',
#   '16,046',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '7:00p',
#   'Milwaukee Bucks',
#   '112',
#   'Philadelphia 76ers',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201703060PHI.html',
#   '',
#   '18,351',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '7:30p',
#   'Golden State Warriors',
#   '119',
#   'Atlanta Hawks',
#   '111',
#   'https://www.basketball-reference.com/boxscores/201703060ATL.html',
#   '',
#   '18,890',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '7:30p',
#   'Chicago Bulls',
#   '95',
#   'Detroit Pistons',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201703060DET.html',
#   '',
#   '16,039',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '8:00p',
#   'Indiana Pacers',
#   '88',
#   'Charlotte Hornets',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201703060CHO.html',
#   '',
#   '16,387',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '8:00p',
#   'Brooklyn Nets',
#   '122',
#   'Memphis Grizzlies',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201703060MEM.html',
#   '',
#   '15,505',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '8:30p',
#   'Houston Rockets',
#   '110',
#   'San Antonio Spurs',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201703060SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '9:00p',
#   'Sacramento Kings',
#   '96',
#   'Denver Nuggets',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201703060DEN.html',
#   '',
#   '11,614',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '9:00p',
#   'New Orleans Pelicans',
#   '83',
#   'Utah Jazz',
#   '88',
#   'https://www.basketball-reference.com/boxscores/201703060UTA.html',
#   '',
#   '19,649',
#   ''],
#  ['Mon, Mar 6, 2017',
#   '10:30p',
#   'Boston Celtics',
#   '102',
#   'Los Angeles Clippers',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201703060LAC.html',
#   '',
#   '19,283',
#   ''],
#  ['Tue, Mar 7, 2017',
#   '8:00p',
#   'Portland Trail Blazers',
#   '126',
#   'Oklahoma City Thunder',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201703070OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Tue, Mar 7, 2017',
#   '8:30p',
#   'Los Angeles Lakers',
#   '111',
#   'Dallas Mavericks',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201703070DAL.html',
#   '',
#   '20,484',
#   ''],
#  ['Tue, Mar 7, 2017',
#   '9:00p',
#   'Washington Wizards',
#   '131',
#   'Phoenix Suns',
#   '127',
#   'https://www.basketball-reference.com/boxscores/201703070PHO.html',
#   '',
#   '16,372',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '7:00p',
#   'Chicago Bulls',
#   '91',
#   'Orlando Magic',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201703080ORL.html',
#   '',
#   '16,063',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '7:30p',
#   'Brooklyn Nets',
#   '105',
#   'Atlanta Hawks',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201703080ATL.html',
#   '',
#   '11,931',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '7:30p',
#   'Charlotte Hornets',
#   '101',
#   'Miami Heat',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201703080MIA.html',
#   '',
#   '19,600',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '8:00p',
#   'Utah Jazz',
#   '115',
#   'Houston Rockets',
#   '108',
#   'https://www.basketball-reference.com/boxscores/201703080HOU.html',
#   '',
#   '16,230',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '8:00p',
#   'Detroit Pistons',
#   '98',
#   'Indiana Pacers',
#   '115',
#   'https://www.basketball-reference.com/boxscores/201703080IND.html',
#   '',
#   '14,353',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '8:00p',
#   'New York Knicks',
#   '93',
#   'Milwaukee Bucks',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201703080MIL.html',
#   '',
#   '13,767',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '8:00p',
#   'Los Angeles Clippers',
#   '91',
#   'Minnesota Timberwolves',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201703080MIN.html',
#   '',
#   '14,933',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '8:00p',
#   'Toronto Raptors',
#   '94',
#   'New Orleans Pelicans',
#   '87',
#   'https://www.basketball-reference.com/boxscores/201703080NOP.html',
#   '',
#   '14,543',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '8:30p',
#   'Sacramento Kings',
#   '104',
#   'San Antonio Spurs',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201703080SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '9:00p',
#   'Washington Wizards',
#   '123',
#   'Denver Nuggets',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201703080DEN.html',
#   '',
#   '12,323',
#   ''],
#  ['Wed, Mar 8, 2017',
#   '10:30p',
#   'Boston Celtics',
#   '99',
#   'Golden State Warriors',
#   '86',
#   'https://www.basketball-reference.com/boxscores/201703080GSW.html',
#   '',
#   '19,596',
#   ''],
#  ['Thu, Mar 9, 2017',
#   '7:30p',
#   'Cleveland Cavaliers',
#   '101',
#   'Detroit Pistons',
#   '106',
#   'https://www.basketball-reference.com/boxscores/201703090DET.html',
#   '',
#   '19,421',
#   ''],
#  ['Thu, Mar 9, 2017',
#   '8:00p',
#   'Los Angeles Clippers',
#   '114',
#   'Memphis Grizzlies',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201703090MEM.html',
#   '',
#   '16,642',
#   ''],
#  ['Thu, Mar 9, 2017',
#   '8:00p',
#   'San Antonio Spurs',
#   '92',
#   'Oklahoma City Thunder',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201703090OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Thu, Mar 9, 2017',
#   '10:00p',
#   'Philadelphia 76ers',
#   '108',
#   'Portland Trail Blazers',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201703090POR.html',
#   'OT',
#   '19,240',
#   ''],
#  ['Thu, Mar 9, 2017',
#   '10:30p',
#   'Los Angeles Lakers',
#   '122',
#   'Phoenix Suns',
#   '110',
#   'https://www.basketball-reference.com/boxscores/201703090PHO.html',
#   '',
#   '17,552',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '7:00p',
#   'Orlando Magic',
#   '81',
#   'Charlotte Hornets',
#   '121',
#   'https://www.basketball-reference.com/boxscores/201703100CHO.html',
#   '',
#   '17,444',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '8:00p',
#   'Toronto Raptors',
#   '99',
#   'Atlanta Hawks',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201703100ATL.html',
#   '',
#   '16,078',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '8:00p',
#   'Houston Rockets',
#   '115',
#   'Chicago Bulls',
#   '94',
#   'https://www.basketball-reference.com/boxscores/201703100CHI.html',
#   '',
#   '21,995',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '8:00p',
#   'Indiana Pacers',
#   '85',
#   'Milwaukee Bucks',
#   '99',
#   'https://www.basketball-reference.com/boxscores/201703100MIL.html',
#   '',
#   '16,177',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '8:00p',
#   'Golden State Warriors',
#   '102',
#   'Minnesota Timberwolves',
#   '103',
#   'https://www.basketball-reference.com/boxscores/201703100MIN.html',
#   '',
#   '20,412',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '9:00p',
#   'Brooklyn Nets',
#   '96',
#   'Dallas Mavericks',
#   '105',
#   'https://www.basketball-reference.com/boxscores/201703100DAL.html',
#   '',
#   '20,022',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '9:00p',
#   'Boston Celtics',
#   '99',
#   'Denver Nuggets',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201703100DEN.html',
#   '',
#   '17,147',
#   ''],
#  ['Fri, Mar 10, 2017',
#   '10:30p',
#   'Washington Wizards',
#   '130',
#   'Sacramento Kings',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201703100SAC.html',
#   'OT',
#   '17,608',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '3:00p',
#   'Utah Jazz',
#   '104',
#   'Oklahoma City Thunder',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201703110OKC.html',
#   '',
#   '18,203',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '3:30p',
#   'Philadelphia 76ers',
#   '100',
#   'Los Angeles Clippers',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201703110LAC.html',
#   '',
#   '19,060',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '5:00p',
#   'New York Knicks',
#   '92',
#   'Detroit Pistons',
#   '112',
#   'https://www.basketball-reference.com/boxscores/201703110DET.html',
#   '',
#   '19,607',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '7:00p',
#   'New Orleans Pelicans',
#   '125',
#   'Charlotte Hornets',
#   '122',
#   'https://www.basketball-reference.com/boxscores/201703110CHO.html',
#   'OT',
#   '18,196',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '7:00p',
#   'Cleveland Cavaliers',
#   '116',
#   'Orlando Magic',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201703110ORL.html',
#   '',
#   '18,846',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '8:00p',
#   'Toronto Raptors',
#   '89',
#   'Miami Heat',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201703110MIA.html',
#   '',
#   '19,745',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '8:00p',
#   'Minnesota Timberwolves',
#   '95',
#   'Milwaukee Bucks',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201703110MIL.html',
#   '',
#   '18,717',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '8:30p',
#   'Golden State Warriors',
#   '85',
#   'San Antonio Spurs',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201703110SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '9:00p',
#   'Phoenix Suns',
#   '100',
#   'Dallas Mavericks',
#   '98',
#   'https://www.basketball-reference.com/boxscores/201703110DAL.html',
#   '',
#   '20,324',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '9:00p',
#   'Atlanta Hawks',
#   '107',
#   'Memphis Grizzlies',
#   '90',
#   'https://www.basketball-reference.com/boxscores/201703110MEM.html',
#   '',
#   '17,523',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '10:00p',
#   'Washington Wizards',
#   '125',
#   'Portland Trail Blazers',
#   '124',
#   'https://www.basketball-reference.com/boxscores/201703110POR.html',
#   'OT',
#   '19,482',
#   ''],
#  ['Sat, Mar 11, 2017',
#   '10:30p',
#   'Denver Nuggets',
#   '105',
#   'Sacramento Kings',
#   '92',
#   'https://www.basketball-reference.com/boxscores/201703110SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Sun, Mar 12, 2017',
#   '3:30p',
#   'Chicago Bulls',
#   '80',
#   'Boston Celtics',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201703120BOS.html',
#   '',
#   '18,624',
#   ''],
#  ['Sun, Mar 12, 2017',
#   '6:00p',
#   'New York Knicks',
#   '112',
#   'Brooklyn Nets',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201703120BRK.html',
#   '',
#   '17,732',
#   ''],
#  ['Sun, Mar 12, 2017',
#   '6:00p',
#   'Miami Heat',
#   '98',
#   'Indiana Pacers',
#   '102',
#   'https://www.basketball-reference.com/boxscores/201703120IND.html',
#   '',
#   '17,923',
#   ''],
#  ['Sun, Mar 12, 2017',
#   '9:00p',
#   'Cleveland Cavaliers',
#   '112',
#   'Houston Rockets',
#   '117',
#   'https://www.basketball-reference.com/boxscores/201703120HOU.html',
#   '',
#   '18,055',
#   ''],
#  ['Sun, Mar 12, 2017',
#   '9:00p',
#   'Portland Trail Blazers',
#   '110',
#   'Phoenix Suns',
#   '101',
#   'https://www.basketball-reference.com/boxscores/201703120PHO.html',
#   '',
#   '16,664',
#   ''],
#  ['Sun, Mar 12, 2017',
#   '9:30p',
#   'Philadelphia 76ers',
#   '118',
#   'Los Angeles Lakers',
#   '116',
#   'https://www.basketball-reference.com/boxscores/201703120LAL.html',
#   '',
#   '18,997',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '7:00p',
#   'Chicago Bulls',
#   '115',
#   'Charlotte Hornets',
#   '109',
#   'https://www.basketball-reference.com/boxscores/201703130CHO.html',
#   '',
#   '16,489',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '7:30p',
#   'Dallas Mavericks',
#   '78',
#   'Toronto Raptors',
#   '100',
#   'https://www.basketball-reference.com/boxscores/201703130TOR.html',
#   '',
#   '19,800',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '8:00p',
#   'Milwaukee Bucks',
#   '93',
#   'Memphis Grizzlies',
#   '113',
#   'https://www.basketball-reference.com/boxscores/201703130MEM.html',
#   '',
#   '16,770',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '8:00p',
#   'Washington Wizards',
#   '104',
#   'Minnesota Timberwolves',
#   '119',
#   'https://www.basketball-reference.com/boxscores/201703130MIN.html',
#   '',
#   '15,747',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '8:00p',
#   'Atlanta Hawks',
#   '99',
#   'San Antonio Spurs',
#   '107',
#   'https://www.basketball-reference.com/boxscores/201703130SAS.html',
#   '',
#   '18,418',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '9:00p',
#   'Los Angeles Clippers',
#   '108',
#   'Utah Jazz',
#   '114',
#   'https://www.basketball-reference.com/boxscores/201703130UTA.html',
#   '',
#   '19,911',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '10:30p',
#   'Los Angeles Lakers',
#   '101',
#   'Denver Nuggets',
#   '129',
#   'https://www.basketball-reference.com/boxscores/201703130DEN.html',
#   '',
#   '17,344',
#   ''],
#  ['Mon, Mar 13, 2017',
#   '10:30p',
#   'Orlando Magic',
#   '115',
#   'Sacramento Kings',
#   '120',
#   'https://www.basketball-reference.com/boxscores/201703130SAC.html',
#   '',
#   '17,608',
#   ''],
#  ['Tue, Mar 14, 2017',
#   '7:00p',
#   'Detroit Pistons',
#   '96',
#   'Cleveland Cavaliers',
#   '128',
#   'https://www.basketball-reference.com/boxscores/201703140CLE.html',
#   '',
#   '20,562',
#   ''],
#  ['Tue, Mar 14, 2017',
#   '7:30p',
#   'Oklahoma City Thunder',
#   '122',
#   'Brooklyn Nets',
#   '104',
#   'https://www.basketball-reference.com/boxscores/201703140BRK.html',
#   '',
#   '13,911',
#   ''],
#  ['Tue, Mar 14, 2017',
#   '7:30p',
#   'Indiana Pacers',
#   '81',
#   'New York Knicks',
#   '87',
#   'https://www.basketball-reference.com/boxscores/201703140NYK.html',
#   '',
#   '18,261',
#   ''],
#  ...]

# %%
#Combine Header and Data to create intiial DF

df = pd.DataFrame(cleanCellData,columns = column_headers)

# %%
def date_change(row):
    t = datetime.datetime.strptime(row['date_game'].replace(',',''), "%a %b %d %Y")
    convert_date = t.strftime('%m/%d/%Y')
    return(convert_date)

df['Date'] = pd.to_datetime(df.apply(date_change,axis = 1))

# %%
nbaDict = {
'Atlanta Hawks': 'ATL',
'Brooklyn Nets': 'BRK',
'Boston Celtics': 'BOS',
'Charlotte Hornets': 'CHO',
'Chicago Bulls': 'CHI',
'Cleveland Cavaliers': 'CLE',
'Dallas Mavericks': 'DAL',
'Denver Nuggets': 'DEN',
'Detroit Pistons': 'DET',
'Golden State Warriors': 'GSW',
'Houston Rockets': 'HOU',
'Indiana Pacers': 'IND',
'Los Angeles Clippers': 'LAC',
'Los Angeles Lakers': 'LAL',
'Memphis Grizzlies': 'MEM',
'Miami Heat': 'MIA',
'Milwaukee Bucks': 'MIL',
'Minnesota Timberwolves': 'MIN',
'New Orleans Pelicans': 'NOP',
'New York Knicks': 'NYK',
'Oklahoma City Thunder': 'OKC',
'Orlando Magic': 'ORL',
'Philadelphia 76ers': 'PHI',
'Phoenix Suns': 'PHO',
'Portland Trail Blazers': 'POR',
'Sacramento Kings': 'SAC',
'San Antonio Spurs': 'SAS',
'Toronto Raptors': 'TOR',
'Utah Jazz': 'UTA',
'Washington Wizards': 'WAS'}

# %%
statColumns = ['Team TS%','Team eFG%','Team ORtg','Opp TS%','Opp eFG%','Opp ORtg']

# %%
def statRecorder(row):
    url1 = row['box_score_text']
    response1 = requests.get(url1)
    page1 = response1.text
    soup1 = BeautifulSoup(page1, "lxml")
    team_list = [nbaDict[row['visitor_team_name']],nbaDict[row['home_team_name']]]
    print([row['visitor_team_name'],row['home_team_name']])
    statsList = []
    index = [1,2,-2]
    for team in team_list:
        boxScoreLink = "box-{}-game-advanced".format(team)
        totalStats = soup1.find('table', id =boxScoreLink).find_all('tr')[-1].find_all('td')
        for i in index:
            statsList.append(totalStats[i].contents[0])
    return(statsList)

# %%
#Create new stats list incrementally and then concatenate after
stats_list = []

# %%
firstBatch = df[0:1200].apply(statRecorder,axis = 1)
for i in firstBatch:
    stats_list.append(i)
# Out:
# ['New York Knicks', 'Cleveland Cavaliers']
# ['Utah Jazz', 'Portland Trail Blazers']
# ['San Antonio Spurs', 'Golden State Warriors']
# ['Dallas Mavericks', 'Indiana Pacers']
# ['Miami Heat', 'Orlando Magic']
# ['Brooklyn Nets', 'Boston Celtics']
# ['Detroit Pistons', 'Toronto Raptors']
# ['Denver Nuggets', 'New Orleans Pelicans']
# ['Charlotte Hornets', 'Milwaukee Bucks']
# ['Minnesota Timberwolves', 'Memphis Grizzlies']
# ['Oklahoma City Thunder', 'Philadelphia 76ers']
# ['Sacramento Kings', 'Phoenix Suns']
# ['Houston Rockets', 'Los Angeles Lakers']
# ['Washington Wizards', 'Atlanta Hawks']
# ['Boston Celtics', 'Chicago Bulls']
# ['Los Angeles Clippers', 'Portland Trail Blazers']
# ['San Antonio Spurs', 'Sacramento Kings']
# ['Cleveland Cavaliers', 'Toronto Raptors']
# ['Indiana Pacers', 'Brooklyn Nets']
# ['Orlando Magic', 'Detroit Pistons']
# ['Phoenix Suns', 'Oklahoma City Thunder']
# ['Charlotte Hornets', 'Miami Heat']
# ['Houston Rockets', 'Dallas Mavericks']
# ['Los Angeles Lakers', 'Utah Jazz']
# ['Golden State Warriors', 'New Orleans Pelicans']
# ['Atlanta Hawks', 'Philadelphia 76ers']
# ['Boston Celtics', 'Charlotte Hornets']
# ['Orlando Magic', 'Cleveland Cavaliers']
# ['Memphis Grizzlies', 'New York Knicks']
# ['New Orleans Pelicans', 'San Antonio Spurs']
# ['Brooklyn Nets', 'Milwaukee Bucks']
# ['Indiana Pacers', 'Chicago Bulls']
# ['Portland Trail Blazers', 'Denver Nuggets']
# ['Minnesota Timberwolves', 'Sacramento Kings']
# ['Utah Jazz', 'Los Angeles Clippers']
# ['Milwaukee Bucks', 'Detroit Pistons']
# ['Golden State Warriors', 'Phoenix Suns']
# ['San Antonio Spurs', 'Miami Heat']
# ['Los Angeles Lakers', 'Oklahoma City Thunder']
# ['Washington Wizards', 'Memphis Grizzlies']
# ['Dallas Mavericks', 'Houston Rockets']
# ['Sacramento Kings', 'Atlanta Hawks']
# ['Chicago Bulls', 'Brooklyn Nets']
# ['Denver Nuggets', 'Toronto Raptors']
# ['Phoenix Suns', 'Los Angeles Clippers']
# ['Houston Rockets', 'Cleveland Cavaliers']
# ['Los Angeles Lakers', 'Indiana Pacers']
# ['Orlando Magic', 'Philadelphia 76ers']
# ['New York Knicks', 'Detroit Pistons']
# ['Sacramento Kings', 'Miami Heat']
# ['Memphis Grizzlies', 'Minnesota Timberwolves']
# ['Milwaukee Bucks', 'New Orleans Pelicans']
# ['Utah Jazz', 'San Antonio Spurs']
# ['Golden State Warriors', 'Portland Trail Blazers']
# ['Philadelphia 76ers', 'Charlotte Hornets']
# ['Toronto Raptors', 'Washington Wizards']
# ['Los Angeles Lakers', 'Atlanta Hawks']
# ['Detroit Pistons', 'Brooklyn Nets']
# ['Houston Rockets', 'New York Knicks']
# ['Chicago Bulls', 'Boston Celtics']
# ['New Orleans Pelicans', 'Memphis Grizzlies']
# ['Dallas Mavericks', 'Utah Jazz']
# ['Portland Trail Blazers', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Los Angeles Clippers']
# ['Sacramento Kings', 'Orlando Magic']
# ['Boston Celtics', 'Cleveland Cavaliers']
# ['Indiana Pacers', 'Milwaukee Bucks']
# ['Denver Nuggets', 'Minnesota Timberwolves']
# ['Oklahoma City Thunder', 'Golden State Warriors']
# ['Atlanta Hawks', 'Washington Wizards']
# ['Charlotte Hornets', 'Brooklyn Nets']
# ['Miami Heat', 'Toronto Raptors']
# ['New York Knicks', 'Chicago Bulls']
# ['Los Angeles Clippers', 'Memphis Grizzlies']
# ['Phoenix Suns', 'New Orleans Pelicans']
# ['Portland Trail Blazers', 'Dallas Mavericks']
# ['San Antonio Spurs', 'Utah Jazz']
# ['Golden State Warriors', 'Los Angeles Lakers']
# ['Minnesota Timberwolves', 'Oklahoma City Thunder']
# ['Denver Nuggets', 'Detroit Pistons']
# ['Chicago Bulls', 'Indiana Pacers']
# ['Washington Wizards', 'Orlando Magic']
# ['Cleveland Cavaliers', 'Philadelphia 76ers']
# ['Houston Rockets', 'Atlanta Hawks']
# ['Sacramento Kings', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'San Antonio Spurs']
# ['Utah Jazz', 'New York Knicks']
# ['Portland Trail Blazers', 'Memphis Grizzlies']
# ['Sacramento Kings', 'Toronto Raptors']
# ['Milwaukee Bucks', 'Dallas Mavericks']
# ['Denver Nuggets', 'Boston Celtics']
# ['Phoenix Suns', 'Los Angeles Lakers']
# ['Indiana Pacers', 'Charlotte Hornets']
# ['Utah Jazz', 'Philadelphia 76ers']
# ['Houston Rockets', 'Washington Wizards']
# ['Orlando Magic', 'Chicago Bulls']
# ['Miami Heat', 'Oklahoma City Thunder']
# ['New Orleans Pelicans', 'Golden State Warriors']
# ['Detroit Pistons', 'Los Angeles Clippers']
# ['Atlanta Hawks', 'Cleveland Cavaliers']
# ['Minnesota Timberwolves', 'Brooklyn Nets']
# ['Denver Nuggets', 'Memphis Grizzlies']
# ['Phoenix Suns', 'Portland Trail Blazers']
# ['Dallas Mavericks', 'Los Angeles Lakers']
# ['New Orleans Pelicans', 'Sacramento Kings']
# ['Utah Jazz', 'Charlotte Hornets']
# ['Philadelphia 76ers', 'Indiana Pacers']
# ['Brooklyn Nets', 'New York Knicks']
# ['Minnesota Timberwolves', 'Orlando Magic']
# ['Boston Celtics', 'Washington Wizards']
# ['Chicago Bulls', 'Atlanta Hawks']
# ['Toronto Raptors', 'Oklahoma City Thunder']
# ['Detroit Pistons', 'Phoenix Suns']
# ['Houston Rockets', 'San Antonio Spurs']
# ['Dallas Mavericks', 'Golden State Warriors']
# ['Portland Trail Blazers', 'Los Angeles Clippers']
# ['Chicago Bulls', 'Miami Heat']
# ['New Orleans Pelicans', 'Milwaukee Bucks']
# ['Golden State Warriors', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Sacramento Kings']
# ['Toronto Raptors', 'Charlotte Hornets']
# ['Utah Jazz', 'Orlando Magic']
# ['Indiana Pacers', 'Philadelphia 76ers']
# ['Cleveland Cavaliers', 'Washington Wizards']
# ['New York Knicks', 'Boston Celtics']
# ['Los Angeles Clippers', 'Oklahoma City Thunder']
# ['Detroit Pistons', 'San Antonio Spurs']
# ['Sacramento Kings', 'Portland Trail Blazers']
# ['Boston Celtics', 'Indiana Pacers']
# ['Los Angeles Lakers', 'New Orleans Pelicans']
# ['Philadelphia 76ers', 'Atlanta Hawks']
# ['New York Knicks', 'Toronto Raptors']
# ['Washington Wizards', 'Chicago Bulls']
# ['San Antonio Spurs', 'Houston Rockets']
# ['Utah Jazz', 'Miami Heat']
# ['Los Angeles Clippers', 'Minnesota Timberwolves']
# ['Memphis Grizzlies', 'Milwaukee Bucks']
# ['Detroit Pistons', 'Denver Nuggets']
# ['Brooklyn Nets', 'Phoenix Suns']
# ['Charlotte Hornets', 'Cleveland Cavaliers']
# ['Los Angeles Lakers', 'Minnesota Timberwolves']
# ['Orlando Magic', 'Oklahoma City Thunder']
# ['Phoenix Suns', 'Golden State Warriors']
# ['Denver Nuggets', 'Portland Trail Blazers']
# ['Orlando Magic', 'Indiana Pacers']
# ['Oklahoma City Thunder', 'Detroit Pistons']
# ['Dallas Mavericks', 'New York Knicks']
# ['Philadelphia 76ers', 'Houston Rockets']
# ['Boston Celtics', 'New Orleans Pelicans']
# ['Miami Heat', 'San Antonio Spurs']
# ['Memphis Grizzlies', 'Utah Jazz']
# ['Brooklyn Nets', 'Los Angeles Clippers']
# ['Toronto Raptors', 'Cleveland Cavaliers']
# ['Atlanta Hawks', 'Miami Heat']
# ['Charlotte Hornets', 'Minnesota Timberwolves']
# ['Chicago Bulls', 'Portland Trail Blazers']
# ['Brooklyn Nets', 'Los Angeles Lakers']
# ['Cleveland Cavaliers', 'Indiana Pacers']
# ['New Orleans Pelicans', 'Orlando Magic']
# ['Washington Wizards', 'Philadelphia 76ers']
# ['Milwaukee Bucks', 'Atlanta Hawks']
# ['Dallas Mavericks', 'Boston Celtics']
# ['Detroit Pistons', 'New York Knicks']
# ['Houston Rockets', 'Oklahoma City Thunder']
# ['Golden State Warriors', 'Toronto Raptors']
# ['Phoenix Suns', 'Denver Nuggets']
# ['Memphis Grizzlies', 'Los Angeles Clippers']
# ['San Antonio Spurs', 'Sacramento Kings']
# ['New York Knicks', 'Washington Wizards']
# ['Milwaukee Bucks', 'Miami Heat']
# ['Portland Trail Blazers', 'Houston Rockets']
# ['Philadelphia 76ers', 'Minnesota Timberwolves']
# ['Chicago Bulls', 'Utah Jazz']
# ['Atlanta Hawks', 'Charlotte Hornets']
# ['Phoenix Suns', 'Indiana Pacers']
# ['Detroit Pistons', 'Cleveland Cavaliers']
# ['Golden State Warriors', 'Boston Celtics']
# ['Portland Trail Blazers', 'New Orleans Pelicans']
# ['Brooklyn Nets', 'Oklahoma City Thunder']
# ['Memphis Grizzlies', 'Dallas Mavericks']
# ['Toronto Raptors', 'Denver Nuggets']
# ['San Antonio Spurs', 'Los Angeles Lakers']
# ['Los Angeles Clippers', 'Sacramento Kings']
# ['Utah Jazz', 'Houston Rockets']
# ['Boston Celtics', 'Detroit Pistons']
# ['Charlotte Hornets', 'New Orleans Pelicans']
# ['Dallas Mavericks', 'Orlando Magic']
# ['Miami Heat', 'Washington Wizards']
# ['Phoenix Suns', 'Philadelphia 76ers']
# ['Minnesota Timberwolves', 'Memphis Grizzlies']
# ['Golden State Warriors', 'Milwaukee Bucks']
# ['Chicago Bulls', 'Los Angeles Clippers']
# ['Atlanta Hawks', 'New York Knicks']
# ['Portland Trail Blazers', 'Brooklyn Nets']
# ['Indiana Pacers', 'Oklahoma City Thunder']
# ['Utah Jazz', 'Denver Nuggets']
# ['Toronto Raptors', 'Sacramento Kings']
# ['Chicago Bulls', 'Los Angeles Lakers']
# ['Memphis Grizzlies', 'Charlotte Hornets']
# ['Golden State Warriors', 'Indiana Pacers']
# ['Miami Heat', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Washington Wizards']
# ['Houston Rockets', 'Detroit Pistons']
# ['Orlando Magic', 'Milwaukee Bucks']
# ['Boston Celtics', 'Minnesota Timberwolves']
# ['Dallas Mavericks', 'San Antonio Spurs']
# ['Toronto Raptors', 'Los Angeles Clippers']
# ['New Orleans Pelicans', 'Atlanta Hawks']
# ['Portland Trail Blazers', 'New York Knicks']
# ['Chicago Bulls', 'Denver Nuggets']
# ['Oklahoma City Thunder', 'Los Angeles Lakers']
# ['San Antonio Spurs', 'Charlotte Hornets']
# ['Portland Trail Blazers', 'Cleveland Cavaliers']
# ['Atlanta Hawks', 'Indiana Pacers']
# ['Phoenix Suns', 'Orlando Magic']
# ['Memphis Grizzlies', 'Philadelphia 76ers']
# ['Boston Celtics', 'Brooklyn Nets']
# ['Miami Heat', 'Detroit Pistons']
# ['Toronto Raptors', 'Houston Rockets']
# ['Los Angeles Clippers', 'Dallas Mavericks']
# ['Denver Nuggets', 'Utah Jazz']
# ['Minnesota Timberwolves', 'New Orleans Pelicans']
# ['Los Angeles Lakers', 'Golden State Warriors']
# ['Oklahoma City Thunder', 'Sacramento Kings']
# ['San Antonio Spurs', 'Boston Celtics']
# ['Washington Wizards', 'Orlando Magic']
# ['Dallas Mavericks', 'Cleveland Cavaliers']
# ['Los Angeles Clippers', 'Detroit Pistons']
# ['Charlotte Hornets', 'New York Knicks']
# ['Chicago Bulls', 'Philadelphia 76ers']
# ['Brooklyn Nets', 'Indiana Pacers']
# ['Miami Heat', 'Memphis Grizzlies']
# ['Toronto Raptors', 'Milwaukee Bucks']
# ['Atlanta Hawks', 'Utah Jazz']
# ['Oklahoma City Thunder', 'Denver Nuggets']
# ['Minnesota Timberwolves', 'Phoenix Suns']
# ['New Orleans Pelicans', 'Portland Trail Blazers']
# ['Golden State Warriors', 'Los Angeles Lakers']
# ['Houston Rockets', 'Sacramento Kings']
# ['New York Knicks', 'Charlotte Hornets']
# ['San Antonio Spurs', 'Washington Wizards']
# ['Memphis Grizzlies', 'Miami Heat']
# ['Detroit Pistons', 'Oklahoma City Thunder']
# ['Minnesota Timberwolves', 'Golden State Warriors']
# ['Cleveland Cavaliers', 'Philadelphia 76ers']
# ['Denver Nuggets', 'Phoenix Suns']
# ['Sacramento Kings', 'Brooklyn Nets']
# ['Los Angeles Clippers', 'Indiana Pacers']
# ['Milwaukee Bucks', 'Orlando Magic']
# ['New Orleans Pelicans', 'Dallas Mavericks']
# ['Houston Rockets', 'Portland Trail Blazers']
# ['Atlanta Hawks', 'Los Angeles Lakers']
# ['Sacramento Kings', 'Washington Wizards']
# ['Boston Celtics', 'Miami Heat']
# ['Oklahoma City Thunder', 'New York Knicks']
# ['Philadelphia 76ers', 'Toronto Raptors']
# ['Charlotte Hornets', 'Memphis Grizzlies']
# ['Utah Jazz', 'Minnesota Timberwolves']
# ['Atlanta Hawks', 'Golden State Warriors']
# ['Detroit Pistons', 'Charlotte Hornets']
# ['Los Angeles Clippers', 'Brooklyn Nets']
# ['Cleveland Cavaliers', 'Milwaukee Bucks']
# ['Los Angeles Lakers', 'New Orleans Pelicans']
# ['Orlando Magic', 'San Antonio Spurs']
# ['Houston Rockets', 'Utah Jazz']
# ['Detroit Pistons', 'Boston Celtics']
# ['Memphis Grizzlies', 'Toronto Raptors']
# ['Los Angeles Lakers', 'Chicago Bulls']
# ['New York Knicks', 'Minnesota Timberwolves']
# ['Washington Wizards', 'Oklahoma City Thunder']
# ['San Antonio Spurs', 'Dallas Mavericks']
# ['Miami Heat', 'Denver Nuggets']
# ['Atlanta Hawks', 'Phoenix Suns']
# ['Indiana Pacers', 'Portland Trail Blazers']
# ['Dallas Mavericks', 'Charlotte Hornets']
# ['Milwaukee Bucks', 'Brooklyn Nets']
# ['Los Angeles Clippers', 'Cleveland Cavaliers']
# ['Orlando Magic', 'Memphis Grizzlies']
# ['Miami Heat', 'Utah Jazz']
# ['Houston Rockets', 'Golden State Warriors']
# ['Orlando Magic', 'Philadelphia 76ers']
# ['Sacramento Kings', 'Boston Celtics']
# ['Minnesota Timberwolves', 'New York Knicks']
# ['Los Angeles Lakers', 'Toronto Raptors']
# ['Detroit Pistons', 'Atlanta Hawks']
# ['Cleveland Cavaliers', 'Chicago Bulls']
# ['Los Angeles Clippers', 'New Orleans Pelicans']
# ['Washington Wizards', 'San Antonio Spurs']
# ['Houston Rockets', 'Denver Nuggets']
# ['Brooklyn Nets', 'Milwaukee Bucks']
# ['Minnesota Timberwolves', 'Charlotte Hornets']
# ['Boston Celtics', 'Philadelphia 76ers']
# ['Atlanta Hawks', 'Toronto Raptors']
# ['Los Angeles Lakers', 'Memphis Grizzlies']
# ['Chicago Bulls', 'Dallas Mavericks']
# ['Denver Nuggets', 'Utah Jazz']
# ['Miami Heat', 'Portland Trail Blazers']
# ['Phoenix Suns', 'Golden State Warriors']
# ['Orlando Magic', 'Detroit Pistons']
# ['New Orleans Pelicans', 'Oklahoma City Thunder']
# ['Sacramento Kings', 'New York Knicks']
# ['Indiana Pacers', 'Los Angeles Clippers']
# ['Denver Nuggets', 'Philadelphia 76ers']
# ['Oklahoma City Thunder', 'Atlanta Hawks']
# ['Washington Wizards', 'Brooklyn Nets']
# ['Cleveland Cavaliers', 'Toronto Raptors']
# ['Portland Trail Blazers', 'Chicago Bulls']
# ['Boston Celtics', 'Houston Rockets']
# ['San Antonio Spurs', 'Milwaukee Bucks']
# ['Memphis Grizzlies', 'New Orleans Pelicans']
# ['Charlotte Hornets', 'Dallas Mavericks']
# ['Indiana Pacers', 'Golden State Warriors']
# ['Utah Jazz', 'Los Angeles Lakers']
# ['Orlando Magic', 'Washington Wizards']
# ['Chicago Bulls', 'Detroit Pistons']
# ['New York Knicks', 'Miami Heat']
# ['Philadelphia 76ers', 'Memphis Grizzlies']
# ['San Antonio Spurs', 'Minnesota Timberwolves']
# ['Phoenix Suns', 'Utah Jazz']
# ['Detroit Pistons', 'Charlotte Hornets']
# ['Boston Celtics', 'Orlando Magic']
# ['Miami Heat', 'Atlanta Hawks']
# ['Denver Nuggets', 'Brooklyn Nets']
# ['Los Angeles Lakers', 'Houston Rockets']
# ['Portland Trail Blazers', 'Milwaukee Bucks']
# ['Cleveland Cavaliers', 'New York Knicks']
# ['Sacramento Kings', 'Dallas Mavericks']
# ['Indiana Pacers', 'Phoenix Suns']
# ['Golden State Warriors', 'Los Angeles Clippers']
# ['Minnesota Timberwolves', 'Toronto Raptors']
# ['Denver Nuggets', 'Washington Wizards']
# ['Portland Trail Blazers', 'Memphis Grizzlies']
# ['Philadelphia 76ers', 'New Orleans Pelicans']
# ['Golden State Warriors', 'Utah Jazz']
# ['San Antonio Spurs', 'Chicago Bulls']
# ['Orlando Magic', 'Charlotte Hornets']
# ['Toronto Raptors', 'Boston Celtics']
# ['Miami Heat', 'Cleveland Cavaliers']
# ['Atlanta Hawks', 'Milwaukee Bucks']
# ['Detroit Pistons', 'Minnesota Timberwolves']
# ['Houston Rockets', 'Oklahoma City Thunder']
# ['Indiana Pacers', 'Dallas Mavericks']
# ['Phoenix Suns', 'Los Angeles Lakers']
# ['New York Knicks', 'Sacramento Kings']
# ['Portland Trail Blazers', 'Indiana Pacers']
# ['Denver Nuggets', 'Orlando Magic']
# ['Milwaukee Bucks', 'Washington Wizards']
# ['Charlotte Hornets', 'Cleveland Cavaliers']
# ['Miami Heat', 'Chicago Bulls']
# ['Dallas Mavericks', 'Houston Rockets']
# ['Golden State Warriors', 'Memphis Grizzlies']
# ['Brooklyn Nets', 'San Antonio Spurs']
# ['Sacramento Kings', 'Utah Jazz']
# ['New Orleans Pelicans', 'Los Angeles Clippers']
# ['Philadelphia 76ers', 'Detroit Pistons']
# ['Golden State Warriors', 'Minnesota Timberwolves']
# ['Boston Celtics', 'Oklahoma City Thunder']
# ['New Orleans Pelicans', 'Phoenix Suns']
# ['New York Knicks', 'Los Angeles Lakers']
# ['Charlotte Hornets', 'Indiana Pacers']
# ['Washington Wizards', 'Miami Heat']
# ['Milwaukee Bucks', 'Toronto Raptors']
# ['Brooklyn Nets', 'Houston Rockets']
# ['Denver Nuggets', 'Dallas Mavericks']
# ['Portland Trail Blazers', 'Los Angeles Clippers']
# ['Los Angeles Lakers', 'Sacramento Kings']
# ['Memphis Grizzlies', 'Cleveland Cavaliers']
# ['Orlando Magic', 'Atlanta Hawks']
# ['Minnesota Timberwolves', 'Chicago Bulls']
# ['Golden State Warriors', 'New Orleans Pelicans']
# ['New York Knicks', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Portland Trail Blazers']
# ['Indiana Pacers', 'Miami Heat']
# ['Los Angeles Clippers', 'Orlando Magic']
# ['Toronto Raptors', 'Philadelphia 76ers']
# ['Charlotte Hornets', 'Washington Wizards']
# ['Los Angeles Lakers', 'Brooklyn Nets']
# ['Sacramento Kings', 'Houston Rockets']
# ['Cleveland Cavaliers', 'Memphis Grizzlies']
# ['Detroit Pistons', 'Dallas Mavericks']
# ['Oklahoma City Thunder', 'Utah Jazz']
# ['Boston Celtics', 'San Antonio Spurs']
# ['Chicago Bulls', 'Milwaukee Bucks']
# ['Indiana Pacers', 'New Orleans Pelicans']
# ['Portland Trail Blazers', 'Denver Nuggets']
# ['San Antonio Spurs', 'Phoenix Suns']
# ['New York Knicks', 'Golden State Warriors']
# ['Brooklyn Nets', 'Orlando Magic']
# ['Detroit Pistons', 'Washington Wizards']
# ['Charlotte Hornets', 'Boston Celtics']
# ['Atlanta Hawks', 'Toronto Raptors']
# ['Milwaukee Bucks', 'Chicago Bulls']
# ['New Orleans Pelicans', 'Houston Rockets']
# ['Sacramento Kings', 'Memphis Grizzlies']
# ['Los Angeles Clippers', 'Miami Heat']
# ['Los Angeles Lakers', 'Philadelphia 76ers']
# ['Dallas Mavericks', 'Utah Jazz']
# ['Phoenix Suns', 'Oklahoma City Thunder']
# ['Indiana Pacers', 'Detroit Pistons']
# ['Charlotte Hornets', 'Atlanta Hawks']
# ['Los Angeles Lakers', 'Cleveland Cavaliers']
# ['Houston Rockets', 'Minnesota Timberwolves']
# ['New York Knicks', 'Denver Nuggets']
# ['Portland Trail Blazers', 'Golden State Warriors']
# ['Los Angeles Clippers', 'Washington Wizards']
# ['Sacramento Kings', 'Dallas Mavericks']
# ['Utah Jazz', 'Memphis Grizzlies']
# ['Boston Celtics', 'Miami Heat']
# ['Toronto Raptors', 'Orlando Magic']
# ['Brooklyn Nets', 'Philadelphia 76ers']
# ['New Orleans Pelicans', 'San Antonio Spurs']
# ['Washington Wizards', 'Indiana Pacers']
# ['Detroit Pistons', 'Chicago Bulls']
# ['Phoenix Suns', 'Minnesota Timberwolves']
# ['Atlanta Hawks', 'Oklahoma City Thunder']
# ['Dallas Mavericks', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Charlotte Hornets']
# ['New Orleans Pelicans', 'Philadelphia 76ers']
# ['Orlando Magic', 'Miami Heat']
# ['Indiana Pacers', 'New York Knicks']
# ['Brooklyn Nets', 'Toronto Raptors']
# ['San Antonio Spurs', 'Houston Rockets']
# ['Boston Celtics', 'Memphis Grizzlies']
# ['Cleveland Cavaliers', 'Milwaukee Bucks']
# ['Utah Jazz', 'Golden State Warriors']
# ['Denver Nuggets', 'Los Angeles Clippers']
# ['Portland Trail Blazers', 'Sacramento Kings']
# ['Milwaukee Bucks', 'Cleveland Cavaliers']
# ['Minnesota Timberwolves', 'Atlanta Hawks']
# ['Memphis Grizzlies', 'Detroit Pistons']
# ['Washington Wizards', 'Chicago Bulls']
# ['Oklahoma City Thunder', 'New Orleans Pelicans']
# ['Houston Rockets', 'Phoenix Suns']
# ['Sacramento Kings', 'Utah Jazz']
# ['Dallas Mavericks', 'Portland Trail Blazers']
# ['Boston Celtics', 'Indiana Pacers']
# ['Golden State Warriors', 'Brooklyn Nets']
# ['Orlando Magic', 'New York Knicks']
# ['Los Angeles Lakers', 'Miami Heat']
# ['San Antonio Spurs', 'Los Angeles Clippers']
# ['Chicago Bulls', 'Charlotte Hornets']
# ['Los Angeles Lakers', 'Orlando Magic']
# ['Oklahoma City Thunder', 'Boston Celtics']
# ['Brooklyn Nets', 'Cleveland Cavaliers']
# ['Golden State Warriors', 'Detroit Pistons']
# ['Houston Rockets', 'Memphis Grizzlies']
# ['Washington Wizards', 'Milwaukee Bucks']
# ['Sacramento Kings', 'Minnesota Timberwolves']
# ['Miami Heat', 'New Orleans Pelicans']
# ['Atlanta Hawks', 'Denver Nuggets']
# ['Philadelphia 76ers', 'Phoenix Suns']
# ['Toronto Raptors', 'Utah Jazz']
# ['San Antonio Spurs', 'Portland Trail Blazers']
# ['Dallas Mavericks', 'Los Angeles Clippers']
# ['Boston Celtics', 'New York Knicks']
# ['Golden State Warriors', 'Cleveland Cavaliers']
# ['Chicago Bulls', 'San Antonio Spurs']
# ['Minnesota Timberwolves', 'Oklahoma City Thunder']
# ['Los Angeles Clippers', 'Los Angeles Lakers']
# ['Memphis Grizzlies', 'Orlando Magic']
# ['Milwaukee Bucks', 'Washington Wizards']
# ['Charlotte Hornets', 'Brooklyn Nets']
# ['Cleveland Cavaliers', 'Detroit Pistons']
# ['Indiana Pacers', 'Chicago Bulls']
# ['Phoenix Suns', 'Houston Rockets']
# ['Atlanta Hawks', 'Minnesota Timberwolves']
# ['Dallas Mavericks', 'New Orleans Pelicans']
# ['Toronto Raptors', 'Portland Trail Blazers']
# ['Denver Nuggets', 'Los Angeles Clippers']
# ['Philadelphia 76ers', 'Sacramento Kings']
# ['Memphis Grizzlies', 'Boston Celtics']
# ['Oklahoma City Thunder', 'Miami Heat']
# ['Houston Rockets', 'Dallas Mavericks']
# ['Utah Jazz', 'Los Angeles Lakers']
# ['Charlotte Hornets', 'Orlando Magic']
# ['Indiana Pacers', 'Washington Wizards']
# ['New York Knicks', 'Atlanta Hawks']
# ['Milwaukee Bucks', 'Detroit Pistons']
# ['Brooklyn Nets', 'Chicago Bulls']
# ['Los Angeles Clippers', 'New Orleans Pelicans']
# ['Phoenix Suns', 'San Antonio Spurs']
# ['Minnesota Timberwolves', 'Denver Nuggets']
# ['Sacramento Kings', 'Portland Trail Blazers']
# ['Toronto Raptors', 'Golden State Warriors']
# ['Miami Heat', 'Charlotte Hornets']
# ['Boston Celtics', 'Cleveland Cavaliers']
# ['Oklahoma City Thunder', 'Memphis Grizzlies']
# ['Toronto Raptors', 'Phoenix Suns']
# ['Philadelphia 76ers', 'Utah Jazz']
# ['Dallas Mavericks', 'Los Angeles Lakers']
# ['Chicago Bulls', 'Indiana Pacers']
# ['Brooklyn Nets', 'Washington Wizards']
# ['Miami Heat', 'Boston Celtics']
# ['Detroit Pistons', 'Atlanta Hawks']
# ['Los Angeles Clippers', 'Houston Rockets']
# ['Milwaukee Bucks', 'Minnesota Timberwolves']
# ['New York Knicks', 'New Orleans Pelicans']
# ['Portland Trail Blazers', 'San Antonio Spurs']
# ['Philadelphia 76ers', 'Denver Nuggets']
# ['Dallas Mavericks', 'Golden State Warriors']
# ['Memphis Grizzlies', 'Sacramento Kings']
# ['Milwaukee Bucks', 'Chicago Bulls']
# ['Cleveland Cavaliers', 'Charlotte Hornets']
# ['New York Knicks', 'Houston Rockets']
# ['Los Angeles Clippers', 'Oklahoma City Thunder']
# ['Phoenix Suns', 'Utah Jazz']
# ['San Antonio Spurs', 'Atlanta Hawks']
# ['Orlando Magic', 'Indiana Pacers']
# ['Detroit Pistons', 'Miami Heat']
# ['Portland Trail Blazers', 'Minnesota Timberwolves']
# ['Toronto Raptors', 'Los Angeles Lakers']
# ['New Orleans Pelicans', 'Cleveland Cavaliers']
# ['Oklahoma City Thunder', 'Milwaukee Bucks']
# ['Utah Jazz', 'Brooklyn Nets']
# ['Orlando Magic', 'New York Knicks']
# ['Charlotte Hornets', 'Chicago Bulls']
# ['Washington Wizards', 'Houston Rockets']
# ['Denver Nuggets', 'Golden State Warriors']
# ['Phoenix Suns', 'Los Angeles Clippers']
# ['Minnesota Timberwolves', 'Philadelphia 76ers']
# ['Utah Jazz', 'Boston Celtics']
# ['Indiana Pacers', 'Detroit Pistons']
# ['Washington Wizards', 'Dallas Mavericks']
# ['Toronto Raptors', 'San Antonio Spurs']
# ['Sacramento Kings', 'Denver Nuggets']
# ['Miami Heat', 'Phoenix Suns']
# ['Memphis Grizzlies', 'Los Angeles Lakers']
# ['Oklahoma City Thunder', 'Charlotte Hornets']
# ['Atlanta Hawks', 'Orlando Magic']
# ['Milwaukee Bucks', 'New York Knicks']
# ['Chicago Bulls', 'Cleveland Cavaliers']
# ['Portland Trail Blazers', 'Golden State Warriors']
# ['Memphis Grizzlies', 'Los Angeles Clippers']
# ['Miami Heat', 'Sacramento Kings']
# ['Brooklyn Nets', 'Indiana Pacers']
# ['Charlotte Hornets', 'Detroit Pistons']
# ['Utah Jazz', 'Toronto Raptors']
# ['Oklahoma City Thunder', 'Houston Rockets']
# ['Atlanta Hawks', 'New Orleans Pelicans']
# ['Phoenix Suns', 'Dallas Mavericks']
# ['San Antonio Spurs', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Portland Trail Blazers']
# ['Houston Rockets', 'Orlando Magic']
# ['Minnesota Timberwolves', 'Washington Wizards']
# ['Philadelphia 76ers', 'Boston Celtics']
# ['Cleveland Cavaliers', 'Brooklyn Nets']
# ['New York Knicks', 'Milwaukee Bucks']
# ['Memphis Grizzlies', 'Golden State Warriors']
# ['Miami Heat', 'Los Angeles Lakers']
# ['Los Angeles Clippers', 'Sacramento Kings']
# ['New York Knicks', 'Indiana Pacers']
# ['New Orleans Pelicans', 'Boston Celtics']
# ['Toronto Raptors', 'Chicago Bulls']
# ['Utah Jazz', 'Minnesota Timberwolves']
# ['Denver Nuggets', 'Oklahoma City Thunder']
# ['Atlanta Hawks', 'Dallas Mavericks']
# ['Charlotte Hornets', 'San Antonio Spurs']
# ['Philadelphia 76ers', 'Brooklyn Nets']
# ['Washington Wizards', 'Milwaukee Bucks']
# ['Miami Heat', 'Los Angeles Clippers']
# ['Houston Rockets', 'Toronto Raptors']
# ['Utah Jazz', 'Memphis Grizzlies']
# ['Cleveland Cavaliers', 'Phoenix Suns']
# ['Detroit Pistons', 'Portland Trail Blazers']
# ['Golden State Warriors', 'Sacramento Kings']
# ['Orlando Magic', 'Los Angeles Lakers']
# ['New Orleans Pelicans', 'New York Knicks']
# ['Oklahoma City Thunder', 'Chicago Bulls']
# ['Dallas Mavericks', 'Minnesota Timberwolves']
# ['Chicago Bulls', 'Washington Wizards']
# ['Atlanta Hawks', 'Brooklyn Nets']
# ['Boston Celtics', 'Toronto Raptors']
# ['Charlotte Hornets', 'Houston Rockets']
# ['Milwaukee Bucks', 'San Antonio Spurs']
# ['Cleveland Cavaliers', 'Utah Jazz']
# ['Miami Heat', 'Golden State Warriors']
# ['Portland Trail Blazers', 'Los Angeles Lakers']
# ['Detroit Pistons', 'Sacramento Kings']
# ['New York Knicks', 'Philadelphia 76ers']
# ['Washington Wizards', 'Boston Celtics']
# ['Houston Rockets', 'Minnesota Timberwolves']
# ['Memphis Grizzlies', 'Oklahoma City Thunder']
# ['Orlando Magic', 'Los Angeles Clippers']
# ['Cleveland Cavaliers', 'Portland Trail Blazers']
# ['Indiana Pacers', 'Denver Nuggets']
# ['New Orleans Pelicans', 'Brooklyn Nets']
# ['Chicago Bulls', 'New York Knicks']
# ['Los Angeles Lakers', 'San Antonio Spurs']
# ['Dallas Mavericks', 'Phoenix Suns']
# ['Detroit Pistons', 'Golden State Warriors']
# ['Charlotte Hornets', 'Philadelphia 76ers']
# ['Brooklyn Nets', 'Toronto Raptors']
# ['Boston Celtics', 'Atlanta Hawks']
# ['Memphis Grizzlies', 'Houston Rockets']
# ['Miami Heat', 'Milwaukee Bucks']
# ['Oklahoma City Thunder', 'Minnesota Timberwolves']
# ['Orlando Magic', 'Portland Trail Blazers']
# ['Cleveland Cavaliers', 'Sacramento Kings']
# ['Detroit Pistons', 'Utah Jazz']
# ['Los Angeles Lakers', 'Los Angeles Clippers']
# ['New Orleans Pelicans', 'Chicago Bulls']
# ['San Antonio Spurs', 'Phoenix Suns']
# ['Philadelphia 76ers', 'Washington Wizards']
# ['Orlando Magic', 'Utah Jazz']
# ['Minnesota Timberwolves', 'Dallas Mavericks']
# ['Milwaukee Bucks', 'Atlanta Hawks']
# ['New York Knicks', 'Toronto Raptors']
# ['Houston Rockets', 'Brooklyn Nets']
# ['Chicago Bulls', 'Memphis Grizzlies']
# ['Oklahoma City Thunder', 'Sacramento Kings']
# ['Detroit Pistons', 'Los Angeles Lakers']
# ['Atlanta Hawks', 'New York Knicks']
# ['Portland Trail Blazers', 'Washington Wizards']
# ['Philadelphia 76ers', 'Milwaukee Bucks']
# ['New Orleans Pelicans', 'Indiana Pacers']
# ['Orlando Magic', 'Denver Nuggets']
# ['Charlotte Hornets', 'Boston Celtics']
# ['Cleveland Cavaliers', 'Golden State Warriors']
# ['Utah Jazz', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Los Angeles Clippers']
# ['Toronto Raptors', 'Brooklyn Nets']
# ['Houston Rockets', 'Miami Heat']
# ['Dallas Mavericks', 'Chicago Bulls']
# ['Minnesota Timberwolves', 'San Antonio Spurs']
# ['Denver Nuggets', 'Los Angeles Lakers']
# ['Portland Trail Blazers', 'Charlotte Hornets']
# ['Toronto Raptors', 'Philadelphia 76ers']
# ['Memphis Grizzlies', 'Washington Wizards']
# ['New York Knicks', 'Boston Celtics']
# ['Atlanta Hawks', 'Detroit Pistons']
# ['Milwaukee Bucks', 'Houston Rockets']
# ['Orlando Magic', 'New Orleans Pelicans']
# ['Oklahoma City Thunder', 'Golden State Warriors']
# ['Indiana Pacers', 'Sacramento Kings']
# ['Phoenix Suns', 'Cleveland Cavaliers']
# ['Dallas Mavericks', 'Miami Heat']
# ['Washington Wizards', 'New York Knicks']
# ['Denver Nuggets', 'San Antonio Spurs']
# ['Minnesota Timberwolves', 'Los Angeles Clippers']
# ['Toronto Raptors', 'Charlotte Hornets']
# ['Milwaukee Bucks', 'Orlando Magic']
# ['Portland Trail Blazers', 'Philadelphia 76ers']
# ['Chicago Bulls', 'Atlanta Hawks']
# ['Golden State Warriors', 'Houston Rockets']
# ['Sacramento Kings', 'Memphis Grizzlies']
# ['Brooklyn Nets', 'New Orleans Pelicans']
# ['Utah Jazz', 'Dallas Mavericks']
# ['Indiana Pacers', 'Los Angeles Lakers']
# ['Portland Trail Blazers', 'Boston Celtics']
# ['Washington Wizards', 'Detroit Pistons']
# ['Philadelphia 76ers', 'Atlanta Hawks']
# ['Brooklyn Nets', 'Charlotte Hornets']
# ['Milwaukee Bucks', 'Miami Heat']
# ['Phoenix Suns', 'New York Knicks']
# ['Houston Rockets', 'Memphis Grizzlies']
# ['San Antonio Spurs', 'Cleveland Cavaliers']
# ['Sacramento Kings', 'Chicago Bulls']
# ['Los Angeles Clippers', 'Denver Nuggets']
# ['Indiana Pacers', 'Utah Jazz']
# ['Golden State Warriors', 'Orlando Magic']
# ['Los Angeles Lakers', 'Dallas Mavericks']
# ['Phoenix Suns', 'Toronto Raptors']
# ['Denver Nuggets', 'Minnesota Timberwolves']
# ['Washington Wizards', 'Charlotte Hornets']
# ['Los Angeles Clippers', 'Atlanta Hawks']
# ['San Antonio Spurs', 'Brooklyn Nets']
# ['Sacramento Kings', 'Detroit Pistons']
# ['Golden State Warriors', 'Miami Heat']
# ['New York Knicks', 'Indiana Pacers']
# ['Houston Rockets', 'Milwaukee Bucks']
# ['Cleveland Cavaliers', 'New Orleans Pelicans']
# ['Oklahoma City Thunder', 'Utah Jazz']
# ['Chicago Bulls', 'Orlando Magic']
# ['Los Angeles Clippers', 'Philadelphia 76ers']
# ['San Antonio Spurs', 'Toronto Raptors']
# ['Boston Celtics', 'Washington Wizards']
# ['Utah Jazz', 'Denver Nuggets']
# ['Minnesota Timberwolves', 'Phoenix Suns']
# ['Sacramento Kings', 'Cleveland Cavaliers']
# ['Houston Rockets', 'Boston Celtics']
# ['Miami Heat', 'Brooklyn Nets']
# ['Atlanta Hawks', 'Chicago Bulls']
# ['Golden State Warriors', 'Charlotte Hornets']
# ['Toronto Raptors', 'Memphis Grizzlies']
# ['Philadelphia 76ers', 'Milwaukee Bucks']
# ['Oklahoma City Thunder', 'New Orleans Pelicans']
# ['New York Knicks', 'Dallas Mavericks']
# ['Los Angeles Lakers', 'Portland Trail Blazers']
# ['Indiana Pacers', 'Minnesota Timberwolves']
# ['Dallas Mavericks', 'Oklahoma City Thunder']
# ['Phoenix Suns', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Utah Jazz']
# ['Sacramento Kings', 'Indiana Pacers']
# ['Orlando Magic', 'Boston Celtics']
# ['Brooklyn Nets', 'Cleveland Cavaliers']
# ['Charlotte Hornets', 'New York Knicks']
# ['Milwaukee Bucks', 'Toronto Raptors']
# ['Washington Wizards', 'Atlanta Hawks']
# ['Miami Heat', 'Chicago Bulls']
# ['San Antonio Spurs', 'New Orleans Pelicans']
# ['Houston Rockets', 'Philadelphia 76ers']
# ['Memphis Grizzlies', 'Portland Trail Blazers']
# ['Sacramento Kings', 'Charlotte Hornets']
# ['Detroit Pistons', 'Miami Heat']
# ['Boston Celtics', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'Golden State Warriors']
# ['Brooklyn Nets', 'Minnesota Timberwolves']
# ['Denver Nuggets', 'Phoenix Suns']
# ['Memphis Grizzlies', 'Utah Jazz']
# ['New York Knicks', 'Atlanta Hawks']
# ['Oklahoma City Thunder', 'Cleveland Cavaliers']
# ['Houston Rockets', 'Indiana Pacers']
# ['Washington Wizards', 'New Orleans Pelicans']
# ['Orlando Magic', 'Toronto Raptors']
# ['Philadelphia 76ers', 'Chicago Bulls']
# ['Dallas Mavericks', 'San Antonio Spurs']
# ['Golden State Warriors', 'Portland Trail Blazers']
# ['Sacramento Kings', 'Philadelphia 76ers']
# ['Brooklyn Nets', 'Miami Heat']
# ['Detroit Pistons', 'Boston Celtics']
# ['Orlando Magic', 'Minnesota Timberwolves']
# ['Cleveland Cavaliers', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'Phoenix Suns']
# ['New Orleans Pelicans', 'Toronto Raptors']
# ['New York Knicks', 'Washington Wizards']
# ['Sacramento Kings', 'Houston Rockets']
# ['Oklahoma City Thunder', 'San Antonio Spurs']
# ['Charlotte Hornets', 'Portland Trail Blazers']
# ['Denver Nuggets', 'Los Angeles Lakers']
# ['Minnesota Timberwolves', 'Cleveland Cavaliers']
# ['Indiana Pacers', 'Orlando Magic']
# ['Toronto Raptors', 'Boston Celtics']
# ['New York Knicks', 'Brooklyn Nets']
# ['New Orleans Pelicans', 'Detroit Pistons']
# ['Atlanta Hawks', 'Miami Heat']
# ['Philadelphia 76ers', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'Denver Nuggets']
# ['Los Angeles Clippers', 'Phoenix Suns']
# ['Milwaukee Bucks', 'Utah Jazz']
# ['Chicago Bulls', 'Oklahoma City Thunder']
# ['Charlotte Hornets', 'Golden State Warriors']
# ['Los Angeles Lakers', 'Washington Wizards']
# ['Atlanta Hawks', 'Houston Rockets']
# ['Philadelphia 76ers', 'San Antonio Spurs']
# ['Golden State Warriors', 'Los Angeles Clippers']
# ['Toronto Raptors', 'Orlando Magic']
# ['Indiana Pacers', 'Brooklyn Nets']
# ['Minnesota Timberwolves', 'Detroit Pistons']
# ['Los Angeles Lakers', 'Boston Celtics']
# ['Chicago Bulls', 'Houston Rockets']
# ['Memphis Grizzlies', 'Oklahoma City Thunder']
# ['Milwaukee Bucks', 'Denver Nuggets']
# ['Dallas Mavericks', 'Portland Trail Blazers']
# ['Phoenix Suns', 'Sacramento Kings']
# ['Orlando Magic', 'Atlanta Hawks']
# ['Detroit Pistons', 'Indiana Pacers']
# ['New Orleans Pelicans', 'Washington Wizards']
# ['Philadelphia 76ers', 'Miami Heat']
# ['Cleveland Cavaliers', 'New York Knicks']
# ['Memphis Grizzlies', 'Minnesota Timberwolves']
# ['Milwaukee Bucks', 'Phoenix Suns']
# ['Denver Nuggets', 'San Antonio Spurs']
# ['Charlotte Hornets', 'Utah Jazz']
# ['Golden State Warriors', 'Sacramento Kings']
# ['Toronto Raptors', 'Brooklyn Nets']
# ['Los Angeles Clippers', 'Boston Celtics']
# ['Portland Trail Blazers', 'Oklahoma City Thunder']
# ['Oklahoma City Thunder', 'Indiana Pacers']
# ['Los Angeles Lakers', 'New York Knicks']
# ['Cleveland Cavaliers', 'Washington Wizards']
# ['Utah Jazz', 'Atlanta Hawks']
# ['Philadelphia 76ers', 'Detroit Pistons']
# ['Los Angeles Clippers', 'Toronto Raptors']
# ['Miami Heat', 'Minnesota Timberwolves']
# ['Phoenix Suns', 'New Orleans Pelicans']
# ['Dallas Mavericks', 'Denver Nuggets']
# ['San Antonio Spurs', 'Memphis Grizzlies']
# ['Chicago Bulls', 'Sacramento Kings']
# ['Brooklyn Nets', 'Charlotte Hornets']
# ['Orlando Magic', 'Houston Rockets']
# ['Portland Trail Blazers', 'Dallas Mavericks']
# ['Cleveland Cavaliers', 'Indiana Pacers']
# ['San Antonio Spurs', 'Philadelphia 76ers']
# ['Denver Nuggets', 'Atlanta Hawks']
# ['Washington Wizards', 'Brooklyn Nets']
# ['Los Angeles Lakers', 'Detroit Pistons']
# ['Phoenix Suns', 'Memphis Grizzlies']
# ['Miami Heat', 'Milwaukee Bucks']
# ['Toronto Raptors', 'Minnesota Timberwolves']
# ['Utah Jazz', 'New Orleans Pelicans']
# ['Los Angeles Clippers', 'New York Knicks']
# ['Chicago Bulls', 'Golden State Warriors']
# ['Boston Celtics', 'Sacramento Kings']
# ['Houston Rockets', 'Charlotte Hornets']
# ['Philadelphia 76ers', 'Orlando Magic']
# ['Cleveland Cavaliers', 'Oklahoma City Thunder']
# ['Utah Jazz', 'Dallas Mavericks']
# ['Boston Celtics', 'Portland Trail Blazers']
# ['Miami Heat', 'Brooklyn Nets']
# ['San Antonio Spurs', 'Detroit Pistons']
# ['Denver Nuggets', 'New York Knicks']
# ['Golden State Warriors', 'Memphis Grizzlies']
# ['Los Angeles Lakers', 'Milwaukee Bucks']
# ['New Orleans Pelicans', 'Minnesota Timberwolves']
# ['Indiana Pacers', 'Washington Wizards']
# ['Chicago Bulls', 'Phoenix Suns']
# ['Atlanta Hawks', 'Sacramento Kings']
# ['Los Angeles Clippers', 'Charlotte Hornets']
# ['Milwaukee Bucks', 'Indiana Pacers']
# ['Denver Nuggets', 'Cleveland Cavaliers']
# ['Miami Heat', 'Philadelphia 76ers']
# ['Golden State Warriors', 'Oklahoma City Thunder']
# ['Orlando Magic', 'Dallas Mavericks']
# ['Phoenix Suns', 'Houston Rockets']
# ['Boston Celtics', 'Utah Jazz']
# ['Chicago Bulls', 'Minnesota Timberwolves']
# ['San Antonio Spurs', 'New York Knicks']
# ['Detroit Pistons', 'Toronto Raptors']
# ['New Orleans Pelicans', 'Sacramento Kings']
# ['Philadelphia 76ers', 'Charlotte Hornets']
# ['San Antonio Spurs', 'Indiana Pacers']
# ['Memphis Grizzlies', 'Brooklyn Nets']
# ['Orlando Magic', 'Miami Heat']
# ['Detroit Pistons', 'Milwaukee Bucks']
# ['Oklahoma City Thunder', 'Washington Wizards']
# ['Boston Celtics', 'Dallas Mavericks']
# ['Golden State Warriors', 'Denver Nuggets']
# ['New Orleans Pelicans', 'Phoenix Suns']
# ['Los Angeles Clippers', 'Utah Jazz']
# ['Atlanta Hawks', 'Portland Trail Blazers']
# ['Toronto Raptors', 'Chicago Bulls']
# ['Cleveland Cavaliers', 'Minnesota Timberwolves']
# ['Sacramento Kings', 'Los Angeles Lakers']
# ['Indiana Pacers', 'Cleveland Cavaliers']
# ['San Antonio Spurs', 'Orlando Magic']
# ['Philadelphia 76ers', 'Boston Celtics']
# ['Milwaukee Bucks', 'Brooklyn Nets']
# ['Dallas Mavericks', 'Detroit Pistons']
# ['Charlotte Hornets', 'Toronto Raptors']
# ['Miami Heat', 'Houston Rockets']
# ['New Orleans Pelicans', 'Memphis Grizzlies']
# ['Minnesota Timberwolves', 'Denver Nuggets']
# ['Los Angeles Lakers', 'Phoenix Suns']
# ['Portland Trail Blazers', 'Utah Jazz']
# ['New York Knicks', 'Oklahoma City Thunder']
# ['Sacramento Kings', 'Golden State Warriors']
# ['Atlanta Hawks', 'Los Angeles Clippers']
# ['Washington Wizards', 'Indiana Pacers']
# ['Boston Celtics', 'Chicago Bulls']
# ['Portland Trail Blazers', 'Orlando Magic']
# ['Charlotte Hornets', 'Detroit Pistons']
# ['New York Knicks', 'Cleveland Cavaliers']
# ['Houston Rockets', 'New Orleans Pelicans']
# ['Los Angeles Clippers', 'Golden State Warriors']
# ['Denver Nuggets', 'Sacramento Kings']
# ['Memphis Grizzlies', 'Indiana Pacers']
# ['Washington Wizards', 'Philadelphia 76ers']
# ['Miami Heat', 'Atlanta Hawks']
# ['Phoenix Suns', 'Chicago Bulls']
# ['Utah Jazz', 'Milwaukee Bucks']
# ['Dallas Mavericks', 'Minnesota Timberwolves']
# ['Los Angeles Lakers', 'Oklahoma City Thunder']
# ['Boston Celtics', 'Toronto Raptors']
# ['Brooklyn Nets', 'Denver Nuggets']
# ['San Antonio Spurs', 'Los Angeles Clippers']
# ['Charlotte Hornets', 'Sacramento Kings']
# ['Atlanta Hawks', 'Orlando Magic']
# ['Philadelphia 76ers', 'New York Knicks']
# ['Indiana Pacers', 'Miami Heat']
# ['Chicago Bulls', 'Cleveland Cavaliers']
# ['New Orleans Pelicans', 'Dallas Mavericks']
# ['Minnesota Timberwolves', 'Houston Rockets']
# ['Brooklyn Nets', 'Golden State Warriors']
# ['San Antonio Spurs', 'Los Angeles Lakers']
# ['Phoenix Suns', 'Milwaukee Bucks']
# ['Memphis Grizzlies', 'Denver Nuggets']
# ['Utah Jazz', 'Washington Wizards']
# ['Boston Celtics', 'Detroit Pistons']
# ['Portland Trail Blazers', 'Toronto Raptors']
# ['New Orleans Pelicans', 'Oklahoma City Thunder']
# ['Charlotte Hornets', 'Los Angeles Clippers']
# ['Milwaukee Bucks', 'Cleveland Cavaliers']
# ['Toronto Raptors', 'New York Knicks']
# ['Golden State Warriors', 'Philadelphia 76ers']
# ['Atlanta Hawks', 'Boston Celtics']
# ['Miami Heat', 'Dallas Mavericks']
# ['Indiana Pacers', 'Houston Rockets']
# ['Minnesota Timberwolves', 'Sacramento Kings']
# ['Golden State Warriors', 'Washington Wizards']
# ['Portland Trail Blazers', 'Detroit Pistons']
# ['Denver Nuggets', 'Chicago Bulls']
# ['Phoenix Suns', 'Memphis Grizzlies']
# ['Utah Jazz', 'Oklahoma City Thunder']
# ['Charlotte Hornets', 'Los Angeles Lakers']
# ['New York Knicks', 'Orlando Magic']
# ['Dallas Mavericks', 'Atlanta Hawks']
# ['Philadelphia 76ers', 'Miami Heat']
# ['Washington Wizards', 'Toronto Raptors']
# ['Cleveland Cavaliers', 'Boston Celtics']
# ['Denver Nuggets', 'Milwaukee Bucks']
# ['Detroit Pistons', 'New Orleans Pelicans']
# ['Indiana Pacers', 'San Antonio Spurs']
# ['Minnesota Timberwolves', 'Utah Jazz']
# ['Houston Rockets', 'Los Angeles Clippers']
# ['Brooklyn Nets', 'Sacramento Kings']
# ['Golden State Warriors', 'Chicago Bulls']
# ['Charlotte Hornets', 'Phoenix Suns']
# ['Oklahoma City Thunder', 'Portland Trail Blazers']
# ['Cleveland Cavaliers', 'Atlanta Hawks']
# ['Miami Heat', 'Orlando Magic']
# ['New York Knicks', 'Philadelphia 76ers']
# ['Toronto Raptors', 'Washington Wizards']
# ['Los Angeles Clippers', 'Milwaukee Bucks']
# ['Memphis Grizzlies', 'Dallas Mavericks']
# ['Oklahoma City Thunder', 'Phoenix Suns']
# ['Brooklyn Nets', 'Utah Jazz']
# ['San Antonio Spurs', 'New Orleans Pelicans']
# ['Boston Celtics', 'Los Angeles Lakers']
# ['Detroit Pistons', 'Philadelphia 76ers']
# ['Cleveland Cavaliers', 'Miami Heat']
# ['Toronto Raptors', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'Chicago Bulls']
# ['Charlotte Hornets', 'Denver Nuggets']
# ['Memphis Grizzlies', 'Houston Rockets']
# ['Minnesota Timberwolves', 'San Antonio Spurs']
# ['Brooklyn Nets', 'Portland Trail Blazers']
# ['Indiana Pacers', 'Atlanta Hawks']
# ['Golden State Warriors', 'New York Knicks']
# ['Boston Celtics', 'Phoenix Suns']
# ['Orlando Magic', 'Washington Wizards']
# ['Utah Jazz', 'Sacramento Kings']
# ['Oklahoma City Thunder', 'Dallas Mavericks']
# ['New Orleans Pelicans', 'Los Angeles Lakers']
# ['Miami Heat', 'Cleveland Cavaliers']
# ['New York Knicks', 'Orlando Magic']
# ['Milwaukee Bucks', 'Philadelphia 76ers']
# ['Golden State Warriors', 'Atlanta Hawks']
# ['Chicago Bulls', 'Detroit Pistons']
# ['Indiana Pacers', 'Charlotte Hornets']
# ['Brooklyn Nets', 'Memphis Grizzlies']
# ['Houston Rockets', 'San Antonio Spurs']
# ['Sacramento Kings', 'Denver Nuggets']
# ['New Orleans Pelicans', 'Utah Jazz']
# ['Boston Celtics', 'Los Angeles Clippers']
# ['Portland Trail Blazers', 'Oklahoma City Thunder']
# ['Los Angeles Lakers', 'Dallas Mavericks']
# ['Washington Wizards', 'Phoenix Suns']
# ['Chicago Bulls', 'Orlando Magic']
# ['Brooklyn Nets', 'Atlanta Hawks']
# ['Charlotte Hornets', 'Miami Heat']
# ['Utah Jazz', 'Houston Rockets']
# ['Detroit Pistons', 'Indiana Pacers']
# ['New York Knicks', 'Milwaukee Bucks']
# ['Los Angeles Clippers', 'Minnesota Timberwolves']
# ['Toronto Raptors', 'New Orleans Pelicans']
# ['Sacramento Kings', 'San Antonio Spurs']
# ['Washington Wizards', 'Denver Nuggets']
# ['Boston Celtics', 'Golden State Warriors']
# ['Cleveland Cavaliers', 'Detroit Pistons']
# ['Los Angeles Clippers', 'Memphis Grizzlies']
# ['San Antonio Spurs', 'Oklahoma City Thunder']
# ['Philadelphia 76ers', 'Portland Trail Blazers']
# ['Los Angeles Lakers', 'Phoenix Suns']
# ['Orlando Magic', 'Charlotte Hornets']
# ['Toronto Raptors', 'Atlanta Hawks']
# ['Houston Rockets', 'Chicago Bulls']
# ['Indiana Pacers', 'Milwaukee Bucks']
# ['Golden State Warriors', 'Minnesota Timberwolves']
# ['Brooklyn Nets', 'Dallas Mavericks']
# ['Boston Celtics', 'Denver Nuggets']
# ['Washington Wizards', 'Sacramento Kings']
# ['Utah Jazz', 'Oklahoma City Thunder']
# ['Philadelphia 76ers', 'Los Angeles Clippers']
# ['New York Knicks', 'Detroit Pistons']
# ['New Orleans Pelicans', 'Charlotte Hornets']
# ['Cleveland Cavaliers', 'Orlando Magic']
# ['Toronto Raptors', 'Miami Heat']
# ['Minnesota Timberwolves', 'Milwaukee Bucks']
# ['Golden State Warriors', 'San Antonio Spurs']
# ['Phoenix Suns', 'Dallas Mavericks']
# ['Atlanta Hawks', 'Memphis Grizzlies']
# ['Washington Wizards', 'Portland Trail Blazers']
# ['Denver Nuggets', 'Sacramento Kings']
# ['Chicago Bulls', 'Boston Celtics']
# ['New York Knicks', 'Brooklyn Nets']
# ['Miami Heat', 'Indiana Pacers']
# ['Cleveland Cavaliers', 'Houston Rockets']
# ['Portland Trail Blazers', 'Phoenix Suns']
# ['Philadelphia 76ers', 'Los Angeles Lakers']
# ['Chicago Bulls', 'Charlotte Hornets']
# ['Dallas Mavericks', 'Toronto Raptors']
# ['Milwaukee Bucks', 'Memphis Grizzlies']
# ['Washington Wizards', 'Minnesota Timberwolves']
# ['Atlanta Hawks', 'San Antonio Spurs']
# ['Los Angeles Clippers', 'Utah Jazz']
# ['Los Angeles Lakers', 'Denver Nuggets']
# ['Orlando Magic', 'Sacramento Kings']
# ['Detroit Pistons', 'Cleveland Cavaliers']
# ['Oklahoma City Thunder', 'Brooklyn Nets']
# ['Indiana Pacers', 'New York Knicks']
# ['Portland Trail Blazers', 'New Orleans Pelicans']
# ['Philadelphia 76ers', 'Golden State Warriors']
# ['Charlotte Hornets', 'Indiana Pacers']
# ['Dallas Mavericks', 'Washington Wizards']
# ['Minnesota Timberwolves', 'Boston Celtics']
# ['Utah Jazz', 'Detroit Pistons']
# ['New Orleans Pelicans', 'Miami Heat']
# ['Memphis Grizzlies', 'Chicago Bulls']
# ['Los Angeles Lakers', 'Houston Rockets']
# ['Portland Trail Blazers', 'San Antonio Spurs']
# ['Sacramento Kings', 'Phoenix Suns']
# ['Milwaukee Bucks', 'Los Angeles Clippers']
# ['Utah Jazz', 'Cleveland Cavaliers']
# ['Oklahoma City Thunder', 'Toronto Raptors']
# ['Memphis Grizzlies', 'Atlanta Hawks']
# ['Brooklyn Nets', 'New York Knicks']
# ['Los Angeles Clippers', 'Denver Nuggets']
# ['Orlando Magic', 'Golden State Warriors']
# ['Dallas Mavericks', 'Philadelphia 76ers']
# ['Chicago Bulls', 'Washington Wizards']
# ['Boston Celtics', 'Brooklyn Nets']
# ['Toronto Raptors', 'Detroit Pistons']
# ['Minnesota Timberwolves', 'Miami Heat']
# ['Houston Rockets', 'New Orleans Pelicans']
# ['Orlando Magic', 'Phoenix Suns']
# ['Milwaukee Bucks', 'Los Angeles Lakers']
# ['Sacramento Kings', 'Oklahoma City Thunder']
# ['Portland Trail Blazers', 'Atlanta Hawks']
# ['Washington Wizards', 'Charlotte Hornets']
# ['Cleveland Cavaliers', 'Los Angeles Clippers']
# ['Utah Jazz', 'Chicago Bulls']
# ['San Antonio Spurs', 'Memphis Grizzlies']
# ['Houston Rockets', 'Denver Nuggets']
# ['Milwaukee Bucks', 'Golden State Warriors']
# ['Dallas Mavericks', 'Brooklyn Nets']
# ['Boston Celtics', 'Philadelphia 76ers']
# ['Phoenix Suns', 'Detroit Pistons']
# ['Portland Trail Blazers', 'Miami Heat']
# ['Minnesota Timberwolves', 'New Orleans Pelicans']
# ['Indiana Pacers', 'Toronto Raptors']
# ['Sacramento Kings', 'San Antonio Spurs']
# ['Cleveland Cavaliers', 'Los Angeles Lakers']
# ['Atlanta Hawks', 'Charlotte Hornets']
# ['Utah Jazz', 'Indiana Pacers']
# ['Philadelphia 76ers', 'Orlando Magic']
# ['Washington Wizards', 'Boston Celtics']
# ['Denver Nuggets', 'Houston Rockets']
# ['Golden State Warriors', 'Oklahoma City Thunder']
# ['New York Knicks', 'Los Angeles Clippers']
# ['Chicago Bulls', 'Toronto Raptors']
# ['Detroit Pistons', 'Brooklyn Nets']
# ['Phoenix Suns', 'Miami Heat']
# ['Memphis Grizzlies', 'New Orleans Pelicans']
# ['Golden State Warriors', 'Dallas Mavericks']
# ['San Antonio Spurs', 'Minnesota Timberwolves']
# ['Milwaukee Bucks', 'Portland Trail Blazers']
# ['Los Angeles Clippers', 'Los Angeles Lakers']
# ['Charlotte Hornets', 'Orlando Magic']
# ['Indiana Pacers', 'Boston Celtics']
# ['Detroit Pistons', 'Chicago Bulls']
# ['Philadelphia 76ers', 'Oklahoma City Thunder']
# ['Atlanta Hawks', 'Washington Wizards']
# ['Cleveland Cavaliers', 'Denver Nuggets']
# ['Milwaukee Bucks', 'Sacramento Kings']
# ['New York Knicks', 'Utah Jazz']
# ['Phoenix Suns', 'Brooklyn Nets']
# ['Toronto Raptors', 'Miami Heat']
# ['Los Angeles Clippers', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'San Antonio Spurs']
# ['New York Knicks', 'Portland Trail Blazers']
# ['Cleveland Cavaliers', 'Charlotte Hornets']
# ['Denver Nuggets', 'Indiana Pacers']
# ['Detroit Pistons', 'Orlando Magic']
# ['Brooklyn Nets', 'Washington Wizards']
# ['Phoenix Suns', 'Boston Celtics']
# ['Philadelphia 76ers', 'Chicago Bulls']
# ['New Orleans Pelicans', 'Houston Rockets']
# ['Atlanta Hawks', 'Milwaukee Bucks']
# ['Sacramento Kings', 'Golden State Warriors']
# ['Minnesota Timberwolves', 'Los Angeles Lakers']
# ['Utah Jazz', 'Los Angeles Clippers']
# ['Washington Wizards', 'Cleveland Cavaliers']
# ['Toronto Raptors', 'Dallas Mavericks']
# ['New York Knicks', 'San Antonio Spurs']
# ['Minnesota Timberwolves', 'Portland Trail Blazers']
# ['Brooklyn Nets', 'Atlanta Hawks']
# ['Phoenix Suns', 'Charlotte Hornets']
# ['Oklahoma City Thunder', 'Houston Rockets']
# ['Sacramento Kings', 'Los Angeles Clippers']
# ['Chicago Bulls', 'Milwaukee Bucks']
# ['Miami Heat', 'Boston Celtics']
# ['Philadelphia 76ers', 'Indiana Pacers']
# ['New Orleans Pelicans', 'Denver Nuggets']
# ['Memphis Grizzlies', 'Golden State Warriors']
# ['Portland Trail Blazers', 'Los Angeles Lakers']
# ['Detroit Pistons', 'New York Knicks']
# ['Orlando Magic', 'Toronto Raptors']
# ['Cleveland Cavaliers', 'San Antonio Spurs']
# ['Oklahoma City Thunder', 'Dallas Mavericks']
# ['Memphis Grizzlies', 'Sacramento Kings']
# ['New Orleans Pelicans', 'Utah Jazz']
# ['Milwaukee Bucks', 'Charlotte Hornets']
# ['Minnesota Timberwolves', 'Indiana Pacers']
# ['Phoenix Suns', 'Atlanta Hawks']
# ['Philadelphia 76ers', 'Brooklyn Nets']
# ['Miami Heat', 'Detroit Pistons']
# ['Golden State Warriors', 'Houston Rockets']
# ['Denver Nuggets', 'Portland Trail Blazers']
# ['Washington Wizards', 'Los Angeles Lakers']
# ['Oklahoma City Thunder', 'Orlando Magic']
# ['Atlanta Hawks', 'Philadelphia 76ers']
# ['Milwaukee Bucks', 'Boston Celtics']
# ['Miami Heat', 'New York Knicks']
# ['Charlotte Hornets', 'Toronto Raptors']
# ['Indiana Pacers', 'Memphis Grizzlies']
# ['Dallas Mavericks', 'New Orleans Pelicans']
# ['Golden State Warriors', 'San Antonio Spurs']
# ['Washington Wizards', 'Los Angeles Clippers']
# ['Utah Jazz', 'Sacramento Kings']
# ['Brooklyn Nets', 'Detroit Pistons']
# ['Cleveland Cavaliers', 'Chicago Bulls']
# ['Los Angeles Lakers', 'Minnesota Timberwolves']
# ['Los Angeles Clippers', 'Phoenix Suns']
# ['Houston Rockets', 'Portland Trail Blazers']
# ['Denver Nuggets', 'Charlotte Hornets']
# ['Indiana Pacers', 'Toronto Raptors']
# ['Orlando Magic', 'Boston Celtics']
# ['Philadelphia 76ers', 'Cleveland Cavaliers']
# ['Dallas Mavericks', 'Memphis Grizzlies']
# ['New York Knicks', 'Miami Heat']
# ['Detroit Pistons', 'Milwaukee Bucks']
# ['Sacramento Kings', 'New Orleans Pelicans']
# ['San Antonio Spurs', 'Oklahoma City Thunder']
# ['Washington Wizards', 'Utah Jazz']
# ['Houston Rockets', 'Golden State Warriors']

# %%
statsdf = pd.DataFrame(stats_list,columns = statColumns)

# %%
resultdf = pd.concat([df, statsdf], axis=1)
resultdf.head()
# Out:
#            date_game game_start_time  visitor_team_name visitor_pts  \
# 0  Tue, Oct 25, 2016           7:30p    New York Knicks          88
# 1  Tue, Oct 25, 2016          10:00p          Utah Jazz         104
# 2  Tue, Oct 25, 2016          10:30p  San Antonio Spurs         129
# 3  Wed, Oct 26, 2016           7:00p   Dallas Mavericks         121
# 4  Wed, Oct 26, 2016           7:00p         Miami Heat         108
#
#            home_team_name home_pts  \
# 0     Cleveland Cavaliers      117
# 1  Portland Trail Blazers      113
# 2   Golden State Warriors      100
# 3          Indiana Pacers      130
# 4           Orlando Magic       96
#
#                                       box_score_text overtimes attendance  \
# 0  https://www.basketball-reference.com/boxscores...               20,562
# 1  https://www.basketball-reference.com/boxscores...               19,446
# 2  https://www.basketball-reference.com/boxscores...               19,596
# 3  https://www.basketball-reference.com/boxscores...        OT     17,923
# 4  https://www.basketball-reference.com/boxscores...               19,298
#
#   game_remarks       Date Team TS% Team eFG% Team ORtg Opp TS% Opp eFG%  \
# 0              2016-10-25     .459      .420      88.1    .572     .548
# 1              2016-10-25     .584      .537     114.9    .667     .607
# 2              2016-10-25     .589      .541     131.3    .538     .512
# 3              2016-10-26     .541      .519     105.8    .602     .559
# 4              2016-10-26     .519      .505     114.5    .474     .416
#
#   Opp ORtg
# 0    117.1
# 1    124.8
# 2    101.8
# 3    113.7
# 4    101.8

# %%
#visitor stats
visitor_df = resultdf.iloc[:,np.r_[0:7,11:14]]
visitor_df.head()

#home stats
home_df = resultdf.iloc[:,np.r_[0:2,4:6,2:4,6,14:17]]
home_df.head()

visitor_df.head()
# Out:
#            date_game game_start_time  visitor_team_name visitor_pts  \
# 0  Tue, Oct 25, 2016           7:30p    New York Knicks          88
# 1  Tue, Oct 25, 2016          10:00p          Utah Jazz         104
# 2  Tue, Oct 25, 2016          10:30p  San Antonio Spurs         129
# 3  Wed, Oct 26, 2016           7:00p   Dallas Mavericks         121
# 4  Wed, Oct 26, 2016           7:00p         Miami Heat         108
#
#            home_team_name home_pts  \
# 0     Cleveland Cavaliers      117
# 1  Portland Trail Blazers      113
# 2   Golden State Warriors      100
# 3          Indiana Pacers      130
# 4           Orlando Magic       96
#
#                                       box_score_text Team TS% Team eFG%  \
# 0  https://www.basketball-reference.com/boxscores...     .459      .420
# 1  https://www.basketball-reference.com/boxscores...     .584      .537
# 2  https://www.basketball-reference.com/boxscores...     .589      .541
# 3  https://www.basketball-reference.com/boxscores...     .541      .519
# 4  https://www.basketball-reference.com/boxscores...     .519      .505
#
#   Team ORtg
# 0      88.1
# 1     114.9
# 2     131.3
# 3     105.8
# 4     114.5

# %%
home_df.columns = ['date_game','game_start_time','team_name','team_pts','opposing_team','opposing_pts','box_score','TS%','eFG%','ORtg']

visitor_df.columns = ['date_game','game_start_time','team_name','team_pts','opposing_team','opposing_pts','box_score','TS%','eFG%','ORtg']

# %%
frames = [visitor_df, home_df]
agg_data = pd.concat(frames,ignore_index=True)

# %%
def date_change(row):
    t = datetime.datetime.strptime(row['date_game'].replace(',',''), "%a %b %d %Y")
    convert_date = t.strftime('%m/%d/%Y')
    return(convert_date)

agg_data['Date'] = pd.to_datetime(agg_data.apply(date_change,axis = 1))

# %%
agg_data['date_game'] = agg_data['Date']
del agg_data['Date']

# %%
ordered_agg_data = agg_data.sort_values(by = ['team_name','date_game']).reset_index()

# %%
rolling_stat_data = agg_data.sort_values(by = ['team_name','date_game'])

testdata_grouped_rolling = rolling_stat_data.groupby('team_name')[['TS%','eFG%','ORtg']].rolling(window=30, min_periods=1).mean().reset_index()

# %%
del testdata_grouped_rolling['level_1']
del testdata_grouped_rolling['team_name']

# %%
testdata_grouped_rolling.columns = ['TS1%','eFG1%','ORtg1']

# %%
full_stats_data = pd.concat([ordered_agg_data ,testdata_grouped_rolling], axis=1)

# %%
#Shift average stats so each row has the average of the games previously
full_stats_data[['TS%','eFG%','ORtg']] = full_stats_data.groupby('team_name')['TS1%','eFG1%','ORtg1'].apply(lambda grp: grp.shift(1))

# %%
#Deleted non-shifted columns

full_stats_data = full_stats_data.drop(['TS1%','eFG1%','ORtg1'],axis =1)

# %%
full_stats_data_2 = full_stats_data

# %%
newDf = pd.merge(full_stats_data_2,full_stats_data,left_on = ['date_game','team_name'],right_on = ['date_game','opposing_team'])

# %%
dedupe_new_df = newDf.drop_duplicates(subset = 'box_score_x',keep ='first')

# %%
dedupe_new_df.head()
# Out:
#    index_x  date_game game_start_time_x    team_name_x team_pts_x  \
# 0     1148 2016-10-27             7:30p  Atlanta Hawks        114
# 1       25 2016-10-29            12:30p  Atlanta Hawks        104
# 2     1176 2016-10-31             7:30p  Atlanta Hawks        106
# 3     1191 2016-11-02             7:30p  Atlanta Hawks        116
# 4       69 2016-11-04             7:00p  Atlanta Hawks         92
#
#       opposing_team_x opposing_pts_x  \
# 0  Washington Wizards             99
# 1  Philadelphia 76ers             72
# 2    Sacramento Kings             95
# 3  Los Angeles Lakers            123
# 4  Washington Wizards             95
#
#                                          box_score_x     TS%_x    eFG%_x  ...  \
# 0  https://www.basketball-reference.com/boxscores...       NaN       NaN  ...
# 1  https://www.basketball-reference.com/boxscores...  0.594000  0.568000  ...
# 2  https://www.basketball-reference.com/boxscores...  0.570500  0.546000  ...
# 3  https://www.basketball-reference.com/boxscores...  0.557667  0.526333  ...
# 4  https://www.basketball-reference.com/boxscores...  0.566500  0.531500  ...
#
#    index_y  game_start_time_y         team_name_y team_pts_y opposing_team_y  \
# 0       13              7:30p  Washington Wizards         99   Atlanta Hawks
# 1     1160             12:30p  Philadelphia 76ers         72   Atlanta Hawks
# 2       41              7:30p    Sacramento Kings         95   Atlanta Hawks
# 3       56              7:30p  Los Angeles Lakers        123   Atlanta Hawks
# 4     1204              7:00p  Washington Wizards         95   Atlanta Hawks
#
#   opposing_pts_y                                        box_score_y    TS%_y  \
# 0            114  https://www.basketball-reference.com/boxscores...      NaN
# 1            104  https://www.basketball-reference.com/boxscores...  0.51100
# 2            106  https://www.basketball-reference.com/boxscores...  0.55800
# 3            116  https://www.basketball-reference.com/boxscores...  0.52925
# 4             92  https://www.basketball-reference.com/boxscores...  0.54700
#
#      eFG%_y      ORtg_y
# 0       NaN         NaN
# 1  0.470000   96.700000
# 2  0.500667  112.866667
# 3  0.483500  103.225000
# 4  0.510667  102.166667
#
# [5 rows x 21 columns]

# %%
dedupe_new_df.columns
# Out:
# Index(['index_x', 'date_game', 'game_start_time_x', 'team_name_x',
#        'team_pts_x', 'opposing_team_x', 'opposing_pts_x', 'box_score_x',
#        'TS%_x', 'eFG%_x', 'ORtg_x', 'index_y', 'game_start_time_y',
#        'team_name_y', 'team_pts_y', 'opposing_team_y', 'opposing_pts_y',
#        'box_score_y', 'TS%_y', 'eFG%_y', 'ORtg_y'],
#       dtype='object')

# %%
allowed_df = dedupe_new_df[['date_game','team_name_x','opposing_team_x','TS%_x','eFG%_x', 'ORtg_x','TS%_y', 'eFG%_y', 'ORtg_y']]

allowed_df.columns = ['date_game','team_name','opposing_team','Team TS%','Team eFG%','Team ORtg','Opp TS%', 'Opp eFG%', 'Opp ORtg']

# %%
export_csv = allowed_df.to_csv (r'C:\Users\jeromerufin\Desktop\Metis\advstats_16_17.csv') #Don't forget to add '.csv' at the end of the path
